# %% [markdown]
# # An Example for Optimising a 38 atom Lennard-Jones Nanocluster with Organisms using the Structure + Energy Fitness Operators

# %% [markdown]
# [Back To Table of Contents](../Organisms_Jupyter_Example.ipynb)

# %% [markdown]
# In this example, we will perform a genetic algorithm optimisation on the 38 atom Lennard-Jones (LJ<sub>38</sub>) cluster with the newly developed structure + ernergy fitness operator. Up to now, the examples have all used the energy fitness operator with no structural component to it. See [organisms.readthedocs.io/en/latest/Using_Run](https://organisms.readthedocs.io/en/latest/Using_Run.html) for more information on the *Run.py* file.
#
# To run this notebook step by step, press the $\blacktriangleright$ button sequentially on the python code you want to run. You can find the $\blacktriangleright$ button in the menu bar above. Make sure you have run $\blacktriangleright$ on every cell before running the ``GA_Program`` execution cell. Equivalently, press the $\blacktriangleright\blacktriangleright$ button to completely run this *Run.py* file from beginning to end. You can also find the $\blacktriangleright\blacktriangleright$ button in the menu bar above. Jupyter will display a box that will ask you if you want to restart the kernal. Press the <img src="../Images/Restart_button.svg" alt="Restart_Button" width="50"/> button to run the full Jupyter notebook in Python.
#
# Note: These are the vanilla settings for running Organisms on a LJ<sub>38</sub> nanocluster, but feel free to change the settings as you wish.
#
# Also note: This program makes files which are created and stored on the Binder server. If you want to rerun this example, you will need to remove these files. The following block code will do this. This is only needed for this notebook and is not apart of *Run.py* script.

# %%
import os
from shutil import rmtree
to_be_removed_before_restarting_Jupyter_example = []
to_be_removed_before_restarting_Jupyter_example += ['epoch_data','epoch_data.backup','GA_Run_Details.txt','ga_running.lock']
to_be_removed_before_restarting_Jupyter_example += ['Population','Recorded_Data','Initial_Population','Saved_Points_In_GA_Run','Memory_Operator_Data','Diversity_Information']
to_be_removed_before_restarting_Jupyter_example += ['__pycache__']
for example_file_or_folder in to_be_removed_before_restarting_Jupyter_example:
    if os.path.exists(example_file_or_folder):
        if os.path.isdir(example_file_or_folder):
            rmtree(example_file_or_folder)
        else:
            os.remove(example_file_or_folder)

# %% [markdown]
# The *Run.py* code begins below:

# %% [markdown]
# ## Fitness Operators
#
# The types of predation operators that are available are:
# * **Energy**: Here, the fitness of a cluster is determined by its energy as well as the energy of the lowest energetic and highest energetic cluster in the population and offspring pool.
# * **SCM + Energy**: This is the structure + energy fitness operator. In this operator, the fitness of a cluster is obtained from the energy of the cluster (obtained using the Energy fitness operator) as well as from the similarity of the cluster, as obtained using the structural comparison method (SCM).
#
# You can find out more about what they do, and how to use them in your Run.py file, at [Using Fitness Operators with the Genetic Algorithm.](https://organisms.readthedocs.io/en/latest/Using_Fitness_Operators_with_the_Genetic_Algorithm.html#using-fitness-operators).
#
# Below are the two fitness operators that can be used in the Organisms program. Currently, the energy fitness operator has been commented out so that you can use the structure + energy fitness operator (known in Organisms as **SCM + Energy**).

# %%
# This switch tells the genetic algorithm the type of fitness scheme they want to place on the genetic algoithm.
# fitness_information = {'Fitness Operator': 'Energy', 'fitness_function': {'function': 'exponential', 'alpha': 3.0}}
fitness_information = {'Fitness Operator': 'Structure + Energy', 'SCM Scheme': 'T-SCM', 'rCut': 1.3495, 'SCM_fitness_contribution': 0.8, 'Dynamic Mode': False, 'Use Predation Information': False, 'energy_fitness_function': {'function': 'exponential', 'alpha': 3.0}, 'SCM_fitness_function': {'function': 'exponential', 'alpha': 1.0}}

# %% [markdown]
# [Back To Table of Contents](../Organisms_Jupyter_Example.ipynb)

# %% [markdown]
# ## Running the rest of the *Run.py* Script
#
# Below is the rest of the settings for the *Run.py* script to run. Currently, the energy predation operator have been set in the script below:

# %%
from Organisms import GA_Program

# This details the elemental and number of atom composition of cluster that the user would like to investigate

cluster_makeup = {'Ne': 38}

# Surface details
surface_details = None

# These are the main variables of the genetic algorithm that with changes could affect the results of the Genetic Algorithm.
pop_size = 20
generations = 50
no_offspring_per_generation = 16

# These setting indicate how offspring should be made using the Mating and Mutation Proceedures
creating_offspring_mode = "Either_Mating_and_Mutation"
crossover_type = "CAS_random"
mutation_types = [['move', 1]]
chance_of_mutation = 0.1

# This parameter will tell the GGA if an epoch is desired, and how the user would like to proceed.
epoch_settings = {'epoch mode': 'same population', 'max repeat': 5}

# These are variables used by the algorithm to make and place clusters in.
r_ij = 1.5
cell_length = 4.1
vacuum_to_add_length = 10.0

# The RunMinimisation.py algorithm is one set by the user. It contain the def Minimisation_Function
# That is used for local optimisations. This can be written in whatever way the user wants to perform
# the local optimisations. This is meant to be as free as possible.
from RunMinimisation_LJ import Minimisation_Function

# This dictionary includes the information required to prevent clusters being placed in the population if they are too similar to clusters in this memory_operator
memory_operator_information = {'Method': 'Off'}

# This dictionary includes the information required by the predation scheme.
predation_information = {'Predation Operator': 'Energy', 'mode': 'comprehensive', 'type_of_comprehensive_scheme': 'energy', 'minimum_energy_diff': 0.01}

# This dictionary includes the information required by the fitness scheme
# This parameter has been address in the previous code of this Jupyter notebook

# Variables required for the Recording_Cluster.py class/For recording the history as required of the genetic algorithm.
ga_recording_information = {'ga_recording_scheme': 'Limit_energy_height', 'limit_number_of_clusters_recorded': 1, 'limit_energy_height_of_clusters_recorded': 1.0, 'exclude_recording_cluster_screened_by_diversity_scheme': False}

# These are last techinical points that the algorithm is designed in mind
force_replace_pop_clusters_with_offspring = True
user_initialised_population_folder = None
rounding_criteria = 10
print_details = True
no_of_cpus = 1
finish_algorithm_if_found_cluster_energy = {'cluster energy': -173.93, 'round': 2}
total_length_of_running_time = None

# %% [markdown]
# ## The Genetic Algorithm!
#
# You have got to the end of all the parameter setting stuff! Now on to the fun stuff! The next part of the Run.py file tells the genetic algorithm to run. This is written as follows in the Run.py. Note this may take a bit of time to run depending on your settings. Running the below code and good and get yourself a tea or coffee.

# %%
''' ---------------- '''
# This will execute the genetic algorithm program
GA_Program(cluster_makeup=cluster_makeup,
    pop_size=pop_size,
    generations=generations,
    no_offspring_per_generation=no_offspring_per_generation,
    creating_offspring_mode=creating_offspring_mode,
    crossover_type=crossover_type,
    mutation_types=mutation_types,
    chance_of_mutation=chance_of_mutation,
    r_ij=r_ij,
    vacuum_to_add_length=vacuum_to_add_length,
    Minimisation_Function=Minimisation_Function,
    surface_details=surface_details,
    epoch_settings=epoch_settings,
    cell_length=cell_length,
    memory_operator_information=memory_operator_information,
    predation_information=predation_information,
    fitness_information=fitness_information,
    ga_recording_information=ga_recording_information,
    force_replace_pop_clusters_with_offspring=force_replace_pop_clusters_with_offspring,
    user_initialised_population_folder=user_initialised_population_folder,
    rounding_criteria=rounding_criteria,
    print_details=print_details,
    no_of_cpus=no_of_cpus,
    finish_algorithm_if_found_cluster_energy=finish_algorithm_if_found_cluster_energy,
    total_length_of_running_time=total_length_of_running_time)
''' ---------------- '''
# Out:
# ############################################################
# ############################################################
# ############################################################
# The Otago Research Genetic Algorithm for Nanoclusters, Including Structural Methods and Similarity (Organisms) Program
#
# .--------------------------------------------------------------------------.
# |                             ,                                            |
# |              ,_     ,     .'<_                                           |
# |             _> `'-,'(__.-' __<                                           |
# |             >_.--(.. )  =;`                                   _          |
# |                  `V-'`'\/``                                  ('>         |
# |                                                              /))@@@@@.   |
# |         .----------------------------------.                /@"@@@@@()@  |
# |         | Welcome to the Organisms program |               .@@()@@()@@@@ |
# |         '----------------------------------'               @@@O@@@@()@@@ |
# |                  ^                                         @()@@\@@@()@@ |
# |  _     (\_/)     |                                          @()@||@@@@@' |
# | ( \    (0.o) ----'                 _                         '@@||@@@'   |
# |  ) )   (> <)                     _(_)_            wWWWw   _     ||       |
# | ( (  .-'''''-.  A.-.A      @@@@ (_)@(_)       _   (___) _(_)_   ||       |
# |  \ \/         \/ , , \    @@()@@  (_)\      _(_)_   Y  (_)@(_)  ||       |
# |   \   \        ;= t =/     @@@@      `|/   (_)@(_) \|/   (_)\   ||       |
# |    \   |'''''-   ,--'       /        \|     /(_)    |/      |   ||       |
# |     / //     | ||        \ |          | / \|/      \|      \|/  ||       |
# |    /_,))     |_'))       \\|//     \\\|// \|///   \\|//  \\\|// ||       |
# |^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^|
# '--------------------------------------------------------------------------'
#
# Version: 3.2.7
# ############################################################
# ############################################################
#
# This algorithm is designed to perform a genetic algorithm to obtain low energetic structures for a given cluster composition.
#
# This genetic algorithm will proceed with the following input parameters
#
# # This details the elemental and number of atom composition of cluster that the user would like to investigate
# cluster_makeup = {'Ne': 38}
#
# # This details the information used to perform a global optimisation upon a chosen surface
# surface_details = None
#
# # These are the main variables of the genetic algorithm that with changes could affect the results of the Genetic Algorithm.
# pop_size = 20
# generations = 50
# no_offspring_per_generation = 16
#
# # These setting indicate how offspring should be made using the Mating and Mutation Proceedures
# creating_offspring_mode = Either_Mating_and_Mutation
# crossover_type = CAS_random
# mutation_types = [['move', 1.0]]
# mutation_types = 0.1
#
# # These are variables used by the algorithm to make and place clusters in.
# r_ij = 1.5 Angstroms (This is the maximum possible bond length between two atoms in the cluster)
# cell_length = 4.1 Angstroms
# vacuum_to_add_length = 10.0 Angstroms
#
# # The RunMinimisation.py algorithm is one set by the user. It contain the def Minimisation_Function
# # That is used for local optimisations. This can be written in whatever way the user wants to perform
# # the local optimisations. This is meant to be as free as possible.
# Minimisation_Function = <function Minimisation_Function at 0x7f217c388700>
# Path of Minimisation_Function: /mnt/hgfs/GoogleDrive/PhDWork/Programs/OptimisationAlgorithms/GeneticAlgorithm/Organisms/Organisms_Jupyter_Examples/Notebooks/Using_the_SE_Fitness_Operator/RunMinimisation_LJ.py
#
# # This details the information about the memory operator used in this genetic algorithm.
# memory_operator = {'method': 'Off'}
#
# # This details the information about the predation operator used in this genetic algorithm.
# predation_operator = {'predation_information': {'Predation Operator': 'Energy', 'mode': 'comprehensive', 'type_of_comprehensive_scheme': 'energy', 'minimum_energy_diff': 0.01}, 'Predation_Switch': 'Energy', 'population': <Collection: Population> current size: 0; Clusters: [], 'print_details': False, 'mode': 'comprehensive', 'type_of_comprehensive_scheme': 'energy', 'minimum_energy_diff': 0.01, 'check_initial_population_imported': <function check_initial_population at 0x7f214a3155e0>, 'assess_for_violations_force_replacement_imported': <function assess_for_violations_force_replacement at 0x7f214a3158b0>, 'assess_for_violations_no_force_replacement_imported': <function assess_for_violations_no_force_replacement at 0x7f214a315820>}
#
# # This details the information about the fitness operator used in this genetic algorithm.
# fitness_operator = {'fitness_switch': 'Structure + Energy', 'fitness_information': {'Fitness Operator': 'Structure + Energy', 'SCM Scheme': 'T-SCM', 'rCut': 1.3495, 'SCM_fitness_contribution': 0.8, 'Dynamic Mode': False, 'Use Predation Information': False, 'energy_fitness_function': {'function': 'exponential', 'alpha': 3.0}, 'SCM_fitness_function': {'function': 'exponential', 'alpha': 1.0}}, 'population': <Collection: Population> current size: 0; Clusters: [], 'print_details': False, 'predation_switch': 'Energy', 'use_predation_information': False, 'rCut': 1.3495, 'cna_database': <Organisms.GA.SCM_Scripts.CNA_Database.CNA_Database object at 0x7f214a305820>, 'SCM_fitness_contribution': 0.8, 'dynamic_mode': False, 'energy_fitness_contribution': 0.19999999999999996, 'fitness_weights': [0.19999999999999996, 0.8], 'take_for_clusters_similarities': 'Maximum', 'collection_function': <built-in function max>, 'normalise_similarities': False, 'get_CNA_fitness_contribution': <function get_CNA_fitness_contribution at 0x7f214a32d820>, 'energy_fitness_function': <Organisms.GA.Fitness_Operators.Fitness_Function.Fitness_Function object at 0x7f214a3057c0>, 'cna_fitness_function': <Organisms.GA.Fitness_Operators.Fitness_Function.Fitness_Function object at 0x7f214a305b80>}
#
# # This parameter will tell the Organisms program if an epoch is desired, and how the user would like to proceed.
# epoch_settings: {'path': '/mnt/hgfs/GoogleDrive/PhDWork/Programs/OptimisationAlgorithms/GeneticAlgorithm/Organisms/Organisms_Jupyter_Examples/Notebooks/Using_the_SE_Fitness_Operator', 'epoch_data_name': 'epoch_data', 'backup_epoch_data_name': 'epoch_data.backup', 'epoch_settings': {'epoch mode': 'same population', 'max repeat': 5}, 'epoch_mode': 'same population', 'max_number_of_times_non_changing_population': 5, 'epoch_function': <bound method Epoch.should_epoch_using_same_population_epoch of {...}>, 'perform_epoch_function': <bound method Epoch.perform_epoch_same_population of {...}>, 'first_epoch_to_change_fitness_function': False}
#
# # Variables required for the GA_Recording_System.py class/For recording the history as required of the genetic algorithm.
# ga_recording_system = {'ga_recording_information': {'ga_recording_scheme': 'Limit_energy_height', 'limit_number_of_clusters_recorded': 1, 'limit_energy_height_of_clusters_recorded': 1.0, 'exclude_recording_cluster_screened_by_diversity_scheme': False}, 'ga_recording_scheme': 'Limit_energy_height', 'ga_recording_system_name': 'Recorded_Data', 'path_to_write_to': '/mnt/hgfs/GoogleDrive/PhDWork/Programs/OptimisationAlgorithms/GeneticAlgorithm/Organisms/Organisms_Jupyter_Examples/Notebooks/Using_the_SE_Fitness_Operator/Recorded_Data', 'exclude_recording_cluster_screened_by_diversity_scheme': False, 'limit_number_of_clusters_recorded': 1, 'limit_size_of_database': None, 'show_GA_Recording_Database_check_percentage': False, 'limit_energy_height_of_clusters_recorded': 1.0, 'clusters_database': <Collection: GA_Recording_Database> current size: 0; Clusters: [], 'directory': '/mnt/hgfs/GoogleDrive/PhDWork/Programs/OptimisationAlgorithms/GeneticAlgorithm/Organisms/Organisms_Jupyter_Examples/Notebooks/Using_the_SE_Fitness_Operator/Recorded_Data', 'RC_Information_TXT_name': 'Recorded_Data_Information.txt', 'record_initial_population': False, 'saving_points_of_GA': []}
#
# # These are last techinical points that the algorithm is designed in mind
# force_replace_pop_clusters_with_offspring = True
# user_initialised_population_folder = None
# rounding_criteria = 10
# print_details = True
# no_of_cpus = 1
# finish_algorithm_if_found_cluster_energy = -173.93
# total_length_of_running_time: Indefinitely
#
# ############################################################
# ############################################################
# ############################################################
# ################################################################################################################
# ################################################################################################################
# Initalising a Starting Population of Clusters if required to take pool up to a size of 20
# Pool size to begin = 0
# Checking to see if the user has any clusters in the folder None that the user would like to have inputted into the initalise population.
# ################################################################################################################
# Will now population the next 20 with randomly generated clusters.
# -----------------------------
# Processing CNA Profiles took 1.0166163444519043 seconds.
# Processing CNA similarities took 0.057411909103393555 seconds.
# Checking that the clusters in the population satisfies the Diversity Scheme
# *****************************
# *****************************
# Diversity Scheme located "duplicates" in creating population.
# Recreating clusters: [8]
# -----------------------------
# Processing CNA Profiles took 1.2120764255523682 seconds.
# Processing CNA similarities took 0.024633407592773438 seconds.
# Checking that the clusters in the population satisfies the Diversity Scheme
# *****************************
# *****************************
# Diversity Scheme located "duplicates" in creating population.
# Recreating clusters: [8]
# -----------------------------
# Processing CNA Profiles took 1.0334198474884033 seconds.
# Processing CNA similarities took 0.025620698928833008 seconds.
# Checking that the clusters in the population satisfies the Diversity Scheme
# Have finished populating the rest of the population with 0 randomly generated clusters.
# The population has been successfully initialised.
# ################################################################################################################
# ################################################################################################################
# Time elapsed: 00:00:17
# Date and Time: 2021-03-23 02:56:16.180833
# -----------------------------
# -----------------------------
# Starting Genetic Algorithm
# -----------------------------
# -----------------------------
#
#
#
# ----------------------------------------------------------
# ####################
# RUNNING GENERATION 1
# ####################
# -----------------------
# Making Offspring
# -----------------------
# Time taken to make offspring: 3.438969135284424 s.
# Details of created offsprings
# Time taken to add offspring to Offspring_Pool: 7.009506225585938e-05 s.
# -----------------------
# Processing CNA Profiles took 0.8486723899841309 seconds.
# Processing CNA similarities took 0.07057905197143555 seconds.
# -----------------------------
# ****---------------------****
# Natural Selection for Generation 1
# --------------------------------------------------------------------------
# <Collection: Population> current size: 20
# Cluster: 1; Energy: -164.2381535495; Fitness: 0.3821109830645792
# Cluster: 2; Energy: -164.5693290723; Fitness: 0.3626538829922784
# Cluster: 3; Energy: -165.6086431935; Fitness: 0.39873620852164837
# Cluster: 4; Energy: -167.3564439837; Fitness: 0.4088155937818203
# Cluster: 5; Energy: -166.4949455508; Fitness: 0.4230074428144516
# Cluster: 6; Energy: -166.6811489738; Fitness: 0.4056964512382081
# Cluster: 7; Energy: -163.6514286976; Fitness: 0.40211323786518866
# Cluster: 8; Energy: -162.0343538553; Fitness: 0.3537291024782522
# Cluster: 9; Energy: -163.7669548296; Fitness: 0.3621429788403808
# Cluster: 10; Energy: -170.0953727179; Fitness: 0.49240645914579195
# Cluster: 11; Energy: -160.7834438555; Fitness: 0.3631131566557736
# Cluster: 12; Energy: -169.1782986501; Fitness: 0.4977927909762637
# Cluster: 25; Energy: -168.8978230213; Fitness: 0.49207354708697737
# Cluster: 14; Energy: -164.590131858; Fitness: 0.39303721871166236
# Cluster: 15; Energy: -163.863374984; Fitness: 0.35128615378199934
# Cluster: 16; Energy: -159.2842762424; Fitness: 0.3617197183563466
# Cluster: 17; Energy: -169.2533170607; Fitness: 0.5067715438884222
# Cluster: 18; Energy: -161.1421595126; Fitness: 0.363592815543596
# Cluster: 19; Energy: -164.0501977603; Fitness: 0.42113185508904083
# Cluster: 20; Energy: -162.1696535643; Fitness: 0.37388147689244794
# --------------------------------------------------------------------------
#
# --------------------------------------------------------------------------
# <Collection: Offspring> current size: 15
# Cluster: 21; Energy: -168.3308177737; Fitness: 0.47536931803697624
# Cluster: 22; Energy: -164.7612742577; Fitness: 0.37182582675765297
# Cluster: 23; Energy: -163.4431674568; Fitness: 0.3579853017185623
# Cluster: 24; Energy: -166.4117391716; Fitness: 0.41558681429051525
# Cluster: 26; Energy: -162.7626323487; Fitness: 0.36753195158846397
# Cluster: 27; Energy: -168.9818370786; Fitness: 0.4847720041207031
# Cluster: 28; Energy: -167.1501670697; Fitness: 0.43724540384416033
# Cluster: 29; Energy: -163.4656009411; Fitness: 0.3708412175292169
# Cluster: 30; Energy: -170.1298281054; Fitness: 0.49430355293715383
# Cluster: 31; Energy: -165.4784178813; Fitness: 0.4047688097507195
# Cluster: 32; Energy: -166.5863440155; Fitness: 0.4266608199398448
# Cluster: 33; Energy: -162.5181743588; Fitness: 0.34405367272144777
# Cluster: 34; Energy: -168.1511382578; Fitness: 0.463737414992173
# Cluster: 35; Energy: -163.6399169891; Fitness: 0.3618720865112754
# Cluster: 36; Energy: -164.9876085454; Fitness: 0.39440387906443697
# --------------------------------------------------------------------------
#
# Offspring that replace clusters in population due to fitness.
# Replacing Cluster 15(fitness = 0.351) with Offspring 30(fitness = 0.494)
# Replacing Cluster 8(fitness = 0.353) with Offspring 27(fitness = 0.484)
# Replacing Cluster 16(fitness = 0.361) with Offspring 21(fitness = 0.475)
# Replacing Cluster 9(fitness = 0.362) with Offspring 34(fitness = 0.463)
# Replacing Cluster 2(fitness = 0.362) with Offspring 28(fitness = 0.437)
# Replacing Cluster 11(fitness = 0.363) with Offspring 32(fitness = 0.426)
# Replacing Cluster 18(fitness = 0.363) with Offspring 24(fitness = 0.415)
# Replacing Cluster 20(fitness = 0.373) with Offspring 31(fitness = 0.404)
# Replacing Cluster 1(fitness = 0.382) with Offspring 36(fitness = 0.394)
# ****---------------------****
# <Collection: Population> current size: 20; Clusters: [Cluster_36, Cluster_28, Cluster_3, Cluster_4, Cluster_5, Cluster_6, Cluster_7, Cluster_27, Cluster_34, Cluster_10, Cluster_32, Cluster_12, Cluster_25, Cluster_14, Cluster_30, Cluster_21, Cluster_17, Cluster_24, Cluster_19, Cluster_31]
# Time Information
# fitness_timer_1   = 0.922443151473999 seconds
# memory_operator_timer_1   = 2.1219253540039062e-05 seconds
# predation_timer_1 = 4.17130184173584 seconds
# fitness_timer_2   = 0.0006577968597412109 seconds
# ending_timer      = 0.039288997650146484 seconds
# The amount of time required for generation 1 is 10.041404724121094 seconds
# ----------------------------------------------------------
# Time elapsed: 00:00:27
# Date and Time: 2021-03-23 02:56:26.239581
#
#
# ----------------------------------------------------------
# ####################
# RUNNING GENERATION 2
# ####################
# -----------------------
# Making Offspring
# -----------------------
# Time taken to make offspring: 2.7377774715423584 s.
# Details of created offsprings
# Time taken to add offspring to Offspring_Pool: 0.00027108192443847656 s.
# -----------------------
# Processing CNA Profiles took 0.6897745132446289 seconds.
# Processing CNA similarities took 0.09468936920166016 seconds.
# -----------------------------
# ****---------------------****
# Natural Selection for Generation 2
# --------------------------------------------------------------------------
# <Collection: Population> current size: 20
# Cluster:
# --------------------------------------------------------------------------
#
# Offspring that replace clusters in population due to fitness.
# Replacing Cluster 5(fitness = 0.365) with Offspring 61(fitness = 0.533)
# Replacing Cluster 4(fitness = 0.365) with Offspring 56(fitness = 0.493)
# Replacing Cluster 39(fitness = 0.375) with Offspring 64(fitness = 0.466)
# Replacing Cluster 45(fitness = 0.376) with Offspring 67(fitness = 0.428)
# Replacing Cluster 28(fitness = 0.377) with Offspring 66(fitness = 0.422)
# Replacing Cluster 34(fitness = 0.382) with Offspring 59(fitness = 0.415)
# Replacing Cluster 46(fitness = 0.394) with Offspring 54(fitness = 0.406)
# ****---------------------****
# <Collection: Population> current size: 20; Clusters: [Cluster_51, Cluster_66, Cluster_3, Cluster_56, Cluster_61, Cluster_64, Cluster_38, Cluster_27, Cluster_59, Cluster_10, Cluster_49, Cluster_12, Cluster_25, Cluster_42, Cluster_30, Cluster_21, Cluster_17, Cluster_67, Cluster_50, Cluster_54]
# Time Information
# fitness_timer_1   = 0.9437961578369141 seconds
# memory_operator_timer_1   = 1.9311904907226562e-05 seconds
# predation_timer_1 = 3.227324962615967 seconds
# fitness_timer_2   = 0.0008165836334228516 seconds
# ending_timer      = 0.04139089584350586 seconds
# The amount of time required for generation 3 is 6.908720970153809 seconds
# ----------------------------------------------------------
# Time elapsed: 00:00:42
# Date and Time: 2021-03-23 02:56:40.932693
#
#
# ----------------------------------------------------------
# ####################
# RUNNING GENERATION 4
# ####################
# -----------------------
# Making Offspring
# -----------------------
# Time taken to make offspring: 2.832547426223755 s.
# Details of created offsprings
# Time taken to add offspring to Offspring_Pool: 0.00022363662719726562 s.
# -----------------------
# Processing CNA Profiles took 0.9315078258514404 seconds.
# Processing CNA similarities took 0.05238914489746094 seconds.
# -----------------------------
# ****---------------------****
# Natural Selection for Generation 4
# --------------------------------------------------------------------------
# <Collection: Population> current size: 20
# Cluster: 51; Energy: -168.9133567404; Fitness: 0.39823285891649884
# Cluster: 66; Energy: -168.8832744145; Fitness: 0.4249051433161046
# Cluster: 3; Energy: -165.6086431935; Fitness: 0.44851368575742867
# Cluster: 56; Energy: -169.6298783633; Fitness: 0.4877801532896493
# Cluster: 61; Energy: -170.47158632; Fitness: 0.525460355484878
# Cluster: 64; Energy: -169.7717052596; Fitness: 0.4737551479656092
# Cluster: 38; Energy: -168.7121787461; Fitness: 0.40438445890884067
# Cluster: 27; Energy: -168.9818370786; Fitness: 0.4627992925585383
# Cluster: 59; Energy: -169.1019245469; Fitness: 0.4157313157195465
# Cluster: 10; Energy: -170.0953727179; Fitness: 0.45287849425166493
# Cluster: 49; Energy: -169.7095586997; Fitness: 0.46002474106275826
# Cluster: 12; Energy: -169.1782986501; Fitness: 0.4388334983723256
# Cluster: 25; Energy: -168.8978230213; Fitness: 0.426338602802092
# Cluster: 42; Energy: -169.3213968051; Fitness: 0.4295391907950264
# Cluster: 30; Energy: -170.1298281054; Fitness: 0.45628522330975446
# Cluster: 21; Energy: -168.3308177737; Fitness: 0.40716657771689496
# Cluster: 17; Energy: -169.2533170607; Fitness: 0.424142052859824
# Cluster: 67; Energy: -169.0741386719; Fitness: 0.42833749096108187
# Cluster: 50; Energy: -169.8670150189; Fitness: 0.488220099379285
# Cluster: 54; Energy: -166.8271129813; Fitness: 0.3691540978158025
# --------------------------------------------------------------------------
#
# --------------------------------------------------------------------------
# <Collection: Offspring> current size: 14
# Cluster: 69; Energy: -169.2395090327; Fitness: 0.46849633527894124
# Cluster: 70; Energy: -167.958928042; Fitness: 0.37748311845558413
# Cluster: 71; Energy: -166.9785024319; Fitness: 0.3587629538336877
# Cluster: 72; Energy: -168.7487253934; Fitness: 0.3908467604791848
# Cluster: 73; Energy: -167.6167731083; Fitness: 0.3655364029573303
# Cluster: 74; Energy: -167.4619423629; Fitness: 0.40913128979536173
# Cluster: 76; Energy: -166.1696882914; Fitness: 0.4027406200860576
# Cluster: 77; Energy: -167.124069375; Fitness: 0.3733993371014104
# --------------------------------------------------------------------------
#
# --------------------------------------------------------------------------
# <Collection: Offspring> current size: 15
# Cluster: 85; Energy: -165.415625112; Fitness: 0.3491281472819974
# Cluster: 86; Energy: -169.4340835618; Fitness: 0.4610486043075786
# Cluster: 87; Energy: -166.6677988755; Fitness: 0.3782237566011908
# Cluster: 88; Energy: -169.6050461706; Fitness: 0.453617126013122
# Cluster: 89; Energy: -168.115131722; Fitness: 0.4192235319213561
# Cluster: 90; Energy: -167.8324664205; Fitness: 0.3692918091371068
# Cluster: 92; Energy: -169.6422730243; Fitness: 0.446478836987811
# Cluster: 93; Energy: -168.6938637813; Fitness: 0.41339243964781636
# Cluster: 94; Energy: -167.9685959446; Fitness: 0.41155937454191965
# Cluster: 95; Energy: -168.329278534; Fitness: 0.39559962211861127
# Cluster: 96; Energy: -166.4088464932; Fitness: 0.3454648766079811
# Cluster: 97; Energy: -168.9518515743; Fitness: 0.42155313445382153
# Cluster: 98; Energy: -169.4666745446; Fitness: 0.4631586616368631
# Cluster: 99; Energy: -168.6758036269; Fitness: 0.4084063656164213
# Cluster: 100; Energy: -169.9820460786; Fitness: 0.4979593475638374
# --------------------------------------------------------------------------
#
# Offspring that replace clusters in population due to fitness.
# Replacing Cluster 3(fitness = 0.35) with Offspring 100(fitness = 0.497)
# Replacing Cluster 66(fitness = 0.411) with Offspring 98(fitness = 0.463)
# Replacing Cluster 59(fitness = 0.418) with Offspring 86(fitness = 0.461)
# Replacing Cluster 80(fitness = 0.42) with Offspring 88(fitness = 0.453)
# Replacing Cluster 74(fitness = 0.423) with Offspring 92(fitness = 0.446)
# ****---------------------****
# <Collection: Population> current size: 20; Clusters: [Cluster_69, Cluster_98, Cluster_100, Cluster_56, Cluster_61, Cluster_64, Cluster_88, Cluster_27, Cluster_86, Cluster_10, Cluster_49, Cluster_12, Cluster_25, Cluster_42, Cluster_30, Cluster_92, Cluster_17, Cluster_67, Cluster_50, Cluster_84]
# Time Information
# fitness_timer_1   = 0.5404543876647949 seconds
# memory_operator_timer_1   = 2.2411346435546875e-05 seconds
# predation_timer_1 = 2.977418899536133 seconds
# fitness_timer_2   = 0.0007009506225585938 seconds
# ending_timer      = 0.038770437240600586 seconds
# The amount of time required for generation 5 is 6.523434638977051 seconds
# ----------------------------------------------------------
# Time elapsed: 00:00:56
# Date and Time: 2021-03-23 02:56:55.807601
#
#
# ----------------------------------------------------------
# ####################
# RUNNING GENERATION 6
# ####################
# -----------------------
# Making Offspring
# -----------------------
# Time taken to make offspring: 1.9899606704711914 s.
# Details of created offsprings
# Time taken to add offspring to Offspring_Pool: 7.271766662597656e-05 s.
# -----------------------
# Processing CNA Profiles took 0.7164015769958496 seconds.
# Processing CNA similarities took 0.07659626007080078 seconds.
# -----------------------------
# ****---------------------****
# Natural Selection for Generation 6
# --------------------------------------------------------------------------
# <Collection: Population> current size: 20
# Cluster: 69; Energy: -169.2395090327; Fitness: 0.39260808551992854
# Cluster: 98; Energy: -169.4666745446; Fitness: 0.4344016252944862
# Cluster: 116; Energy: -169.982088187; Fitness: 0.44981707552367634
# Cluster: 56; Energy: -169.6298783633; Fitness: 0.4118753589836636
# Cluster: 61; Energy: -170.47158632; Fitness: 0.44810688003538157
# Cluster: 64; Energy: -169.7717052596; Fitness: 0.4181465690643553
# Cluster: 88; Energy: -169.6050461706; Fitness: 0.43436434967042437
# Cluster: 27; Energy: -168.9818370786; Fitness: 0.4387716774470878
# Cluster: 86; Energy: -169.4340835618; Fitness: 0.433207579453619
# Cluster: 10; Energy: -170.0953727179; Fitness: 0.402567693047019
# Cluster: 49; Energy: -169.7095586997; Fitness: 0.4218180677958614
# Cluster: 12; Energy: -169.1782986501; Fitness: 0.4191164740099404
# Cluster: 25; Energy: -168.8978230213; Fitness: 0.4158948355021692
# Cluster: 42; Energy: -169.3213968051; Fitness: 0.41512955547766683
# Cluster: 30; Energy: -170.1298281054; Fitness: 0.40427205172196357
# Cluster: 92; Energy: -169.6422730243; Fitness: 0.41236934567764905
# Cluster: 17; Energy: -169.2533170607; Fitness: 0.41520853099481336
# Cluster: 67; Energy: -169.0741386719; Fitness: 0.4120256400424093
# Cluster: 50; Energy: -169.8670150189; Fitness: 0.4445895131689298
# Cluster: 84; Energy: -170.3273251159; Fitness: 0.4930436620547909
# --------------------------------------------------------------------------
#
# --------------------------------------------------------------------------
# <Collection: Offspring> current size: 13
# Cluster: 101; Energy: -167.391901679; Fitness: 0.39258169686418287
# Cluster: 103; Energy: -167.9867057051; Fitness: 0.3725484762493782
# Cluster: 104; Energy: -167.761402094; Fitness: 0.389191975462648
# Cluster: 105; Energy: -169.8554337892; Fitness: 0.41681570614330854
# Cluster: 106; Energy: -169.0384271159; Fitness: 0.3982161681286873
# Cluster: 107; Energy: -164.8316358941; Fitness: 0.35157093745310025
# Cluster: 108; Energy: -168.133912967; Fitness: 0.40076662358065146
# Cluster: 109; Energy: -167.2342841531; Fitness: 0.34875288957207384
# Cluster: 110; Energy: -168.317816412; Fitness: 0.38966249439432843
# Cluster: 111; Energy: -167.8196893436; Fitness: 0.3632447551554026
# Cluster: 113; Energy: -168.5839687831; Fitness: 0.41083718816411463
# Cluster: 114; Energy: -171.4492018185; Fitness: 0.7455729942984792
# Cluster: 115; Energy: -166.2414412946; Fitness: 0.3774441295342563
# --------------------------------------------------------------------------
#
# Offspring that replace clusters in population due to fitness.
# Replacing Cluster 69(fitness = 0.392) with Offspring 114(fitness = 0.745)
# Replacing Cluster 10(fitness = 0.402) with Offspring 105(fitness = 0.416)
# Replacing Cluster 30(fitness = 0.404) with Offspring 113(fitness = 0.41)
# ****---------------------****
# <Collection: Population> current size: 20; Clusters: [Cluster_114, Cluster_98, Cluster_116, Cluster_56, Cluster_61, Cluster_64, Cluster_88, Cluster_27, Cluster_86, Cluster_105, Cluster_49, Cluster_12, Cluster_25, Cluster_42, Cluster_113, Cluster_92, Cluster_17, Cluster_67, Cluster_50, Cluster_84]
# Time Information
# fitness_timer_1   = 0.7986166477203369 seconds
# memory_operator_timer_1   = 1.9788742065429688e-05 seconds
# predation_timer_1 = 4.3306262493133545 seconds
# fitness_timer_2   = 0.0005724430084228516 seconds
# ending_timer      = 0.028174161911010742 seconds
# The amount of time required for generation 6 is 7.643877029418945 seconds
# ----------------------------------------------------------
# Time elapsed: 00:01:04
# Date and Time: 2021-03-23 02:57:03.494406
#
#
# ----------------------------------------------------------
# ####################
# RUNNING GENERATION 7
# ####################
# -----------------------
# Making Offspring
# -----------------------
# Time taken to make offspring: 1.9671411514282227 s.
# Details of created offsprings
# Time taken to add offspring to Offspring_Pool: 0.00014710426330566406 s.
# -----------------------
# Processing CNA Profiles took 0.7522768974304199 seconds.
# Processing CNA similarities took 0.08607959747314453 seconds.
# -----------------------------
# ****---------------------****
# Natural Selection for Generation 7
# --------------------------------------------------------------------------
# <Collection: Population> current size: 20
# Cluster: 121; Energy: -171.4524113311; Fitness: 0.7455729942984792
# Cluster: 98; Energy: -169.4666745446; Fitness: 0.42701878461526266
# Cluster: 116; Energy: -169.982088187; Fitness: 0.4457225391885924
# Cluster: 56; Energy: -169.6298783633; Fitness: 0.4098123713374644
# Cluster: 61; Energy: -170.47158632; Fitness: 0.4463867532636696
# Cluster: 64; Energy: -169.7717052596; Fitness: 0.435330516965282
# Cluster: 88; Energy: -169.6050461706; Fitness: 0.4086272535895005
# Cluster: 27; Energy: -168.9818370786; Fitness: 0.4355520815790127
# Cluster: 86; Energy: -169.4340835618; Fitness: 0.4182542370277097
# Cluster: 86; Energy: -169.4340835618; Fitness: 0.4211165372980808
# Cluster: 105; Energy: -169.8554337892; Fitness: 0.4050150148252602
# Cluster: 49; Energy: -169.7095586997; Fitness: 0.4021465057644424
# Cluster: 118; Energy: -169.6915649198; Fitness: 0.41499415549250046
# Cluster: 134; Energy: -168.9021761193; Fitness: 0.4000297459569945
# Cluster: 122; Energy: -170.1450397228; Fitness: 0.4250198808479928
# Cluster: 113; Energy: -168.5839687831; Fitness: 0.46116275004759133
# Cluster: 92; Energy: -169.6422730243; Fitness: 0.4003425402678497
# Cluster: 17; Energy: -169.2533170607; Fitness: 0.3992619471275876
# Cluster: 67; Energy: -169.0741386719; Fitness: 0.40010782802829004
# Cluster: 50; Energy: -169.8670150189; Fitness: 0.4289214423101685
# Cluster: 84; Energy: -170.3273251159; Fitness: 0.4660993339684133
# --------------------------------------------------------------------------
#
# --------------------------------------------------------------------------
# <Collection: Offspring> current size: 11
# Cluster: 133; Energy: -168.5694302692; Fitness: 0.3845650840081778
# Cluster: 137; Energy: -168.4576098247; Fitness: 0.36369311083797334
# Cluster: 138; Energy: -170.1891919508; Fitness: 0.42739313671403284
# Cluster: 139; Energy: -165.829804657; Fitness: 0.3940501088006321
# Cluster: 141; Energy: -167.0733919528; Fitness: 0.3735106775624745
# Cluster: 142; Energy: -168.7020585475; Fitness: 0.40123350485934844
# Cluster: 143; Energy: -168.2305464801; Fitness: 0.41899266165659743
# Cluster: 144; Energy: -168.3125595497; Fitness: 0.3826493375789172
# Cluster: 145; Energy: -167.8013390808; Fitness: 0.3787169864307532
# Cluster: 146; Energy: -170.8677406109; Fitness: 0.5555565360833419
# Cluster: 147; Energy: -167.8143818834; Fitness: 0.3735723260782704
# --------------------------------------------------------------------------
#
# Offspring that replace clusters in population due to fitness.
# Replacing Cluster 136(fitness = 0.373) with Offspring 146(fitness = 0.555)
# Replacing Cluster 17(fitness = 0.399) with Offspring 138(fitness = 0.427)
# Replacing Cluster 56(fitness = 0.399) with Offspring 143(fitness = 0.418)
# Replacing Cluster 134(fitness = 0.4) with Offspring 142(fitness = 0.401)
# ****---------------------****
# <Collection: Population> current size: 20; Clusters: [Cluster_121, Cluster_98, Cluster_116, Cluster_143, Cluster_61, Cluster_64, Cluster_140, Cluster_146, Cluster_86, Cluster_105, Cluster_49, Cluster_118, Cluster_142, Cluster_122, Cluster_113, Cluster_92, Cluster_138, Cluster_67, Cluster_50, Cluster_84]
# Time Information
# fitness_timer_1   = 0.723334789276123 seconds
# memory_operator_timer_1   = 1.7404556274414062e-05 seconds
# predation_timer_1 = 5.0381762981414795 seconds
# fitness_timer_2   = 0.0010402202606201172 seconds
# ending_timer      = 0.041398048400878906 seconds
# The amount of time required for generation 8 is 8.6586012840271 seconds
# ----------------------------------------------------------
# Time elapsed: 00:01:19
# Date and Time: 2021-03-23 02:57:18.086100
#
#
# ----------------------------------------------------------
# ####################
# RUNNING GENERATION 9
# ####################
# -----------------------
# Making Offspring
# -----------------------
# Time taken to make offspring: 2.49249267578125 s.
# Details of created offsprings
# Time taken to add offspring to Offspring_Pool: 0.0001327991485595703 s.
# -----------------------
# Processing CNA Profiles took 0.6439435482025146 seconds.
# Processing CNA similarities took 0.07740926742553711 seconds.
# -----------------------------
# ****---------------------****
# Natural Selection for Generation 9
# --------------------------------------------------------------------------
# <Collection: Population> current size: 20
# Cluster: 121; Energy: -171.4524113311; Fitness: 0.5831457283737775
# Cluster: 98; Energy: -169.4666745446; Fitness: 0.44175443920877033
# Cluster: 116; Energy: -169.982088187; Fitness: 0.4544660705903567
# Cluster: 143; Energy: -168.2305464801; Fitness: 0.43668259025966216
# Cluster: 61; Energy: -170.47158632; Fitness: 0.45361058548171335
# Cluster: 64; Energy: -169.7717052596; Fitness: 0.4444473858579782
# Cluster: 140; Energy: -169.6051679188; Fitness: 0.44771690450120205
# Cluster: 146; Energy: -170.8677406109; Fitness: 0.5753333299829344
# Cluster: 86; Energy: -169.4340835618; Fitness: 0.4405788589271999
# Cluster: 105; Energy: -169.8554337892; Fitness: 0.4237787922543459
# Cluster: 49; Energy: -169.7095586997; Fitness: 0.43487136172509033
# Cluster: 118; Energy: -169.6915649198; Fitness: 0.43415237484753266
# Cluster: 142; Energy: -168.7020585475; Fitness: 0.42046545407613
# Cluster: 122; Energy: -170.1450397228; Fitness: 0.44261789383261063
# Cluster: 113; Energy: -168.5839687831; Fitness: 0.4797409663348736
# Cluster: 92; Energy: -169.6422730243; Fitness: 0.4601738116303953
# Cluster: 163; Energy: -170.1892182687; Fitness: 0.4447543914863794
# ...
# Cluster: 628; Energy: -172.3154154378; Fitness: 0.4559410646888382
# --------------------------------------------------------------------------
#
# --------------------------------------------------------------------------
# <Collection: Offspring> current size: 13
# Cluster: 677; Energy: -167.3251444332; Fitness: 0.5052424883608821
# Cluster: 678; Energy: -171.1114345109; Fitness: 0.43541523103172214
# Cluster: 679; Energy: -168.5517134228; Fitness: 0.38161346101869686
# Cluster: 680; Energy: -162.0517690763; Fitness: 0.370361587496885
# Cluster: 681; Energy: -169.0261140469; Fitness: 0.41468643174644215
# Cluster: 683; Energy: -166.7431149904; Fitness: 0.38458554298452136
# Cluster: 684; Energy: -170.3012455187; Fitness: 0.419381791458655
# Cluster: 686; Energy: -167.1504268499; Fitness: 0.3993617286320217
# Cluster: 687; Energy: -165.7553716988; Fitness: 0.37924001523675155
# Cluster: 688; Energy: -165.9263163576; Fitness: 0.37771152913563477
# Cluster: 689; Energy: -169.76803724; Fitness: 0.372957906264745
# Cluster: 691; Energy: -168.1216848578; Fitness: 0.40081461842303273
# Cluster: 692; Energy: -169.7315354278; Fitness: 0.3721926698289171
# --------------------------------------------------------------------------
#
# Offspring that replace clusters in population due to fitness.
# Replacing Cluster 676(fitness = 0.369) with Offspring 677(fitness = 0.505)
# Replacing Cluster 668(fitness = 0.417) with Offspring 678(fitness = 0.435)
# ****---------------------****
# <Collection: Population> current size: 20; Clusters: [Cluster_121, Cluster_401, Cluster_593, Cluster_580, Cluster_599, Cluster_637, Cluster_652, Cluster_517, Cluster_397, Cluster_678, Cluster_573, Cluster_682, Cluster_648, Cluster_674, Cluster_347, Cluster_677, Cluster_456, Cluster_690, Cluster_616, Cluster_628]
# Time Information
# fitness_timer_1   = 0.679126501083374 seconds
# memory_operator_timer_1   = 2.0742416381835938e-05 seconds
# predation_timer_1 = 2.6258132457733154 seconds
# fitness_timer_2   = 0.0006766319274902344 seconds
# ending_timer      = 0.026947736740112305 seconds
# The amount of time required for generation 42 is 5.091683387756348 seconds
# ----------------------------------------------------------
# Time elapsed: 00:05:49
# Date and Time: 2021-03-23 03:01:48.862607
#
#
# ----------------------------------------------------------
# #####################
# RUNNING GENERATION 43
# #####################
# -----------------------
# Making Offspring
# -----------------------
# Time taken to make offspring: 2.0439186096191406 s.
# Details of created offsprings
# Time taken to add offspring to Offspring_Pool: 0.00013446807861328125 s.
# -----------------------
# Processing CNA Profiles took 0.7436721324920654 seconds.
# Processing CNA similarities took 0.09939861297607422 seconds.
# -----------------------------
# ****---------------------****
# Natural Selection for Generation 43
# --------------------------------------------------------------------------
# <Collection: Population> current size: 20
# Cluster: 121; Energy: -171.4524113311; Fitness: 0.42821568229963425
# Cluster: 401; Energy: -173.2523756512; Fitness: 0.5388770538851513
# Cluster: 593; Energy: -171.8862167053; Fitness: 0.4265103469888505
# Cluster: 580; Energy: -172.877727624; Fitness: 0.4798300713406729
# Cluster: 599; Energy: -170.891427358; Fitness: 0.4244361756956001
# Cluster: 637; Energy: -170.9924495869; Fitness: 0.45121945100700667
# Cluster: 702; Energy: -170.0886774544; Fitness: 0.40920026363598216
# Cluster: 517; Energy: -170.7491580531; Fitness: 0.4201861160441883
# Cluster: 397; Energy: -171.8560100493; Fitness: 0.45296880662255845
# Cluster: 678; Energy: -171.1114345109; Fitness: 0.4174248200115582
# Cluster: 573; Energy: -171.3836081052; Fitness: 0.45875237368679056
# Cluster: 682; Energy: -170.8096289035; Fitness: 0.407953142191282
# Cluster: 648; Energy: -170.2660970937; Fitness: 0.41929542275405685
# Cluster: 674; Energy: -168.1445376474; Fitness: 0.41894774196566553
# Cluster: 347; Energy: -171.7734079673; Fitness: 0.42171689169120696
# Cluster: 677; Energy: -167.3251444332; Fitness: 0.4014216464551061
# Cluster: 456; Energy: -173.1343161706; Fitness: 0.4882379528424333
# Cluster: 704; Energy: -172.1109070295; Fitness: 0.4305853593933484
# Cluster: 616; Energy: -169.0600833897; Fitness: 0.4512917742530095
# Cluster: 628; Energy: -172.3154154378; Fitness: 0.44453858104854105
# --------------------------------------------------------------------------
#
# --------------------------------------------------------------------------
# <Collection: Offspring> current size: 12
# Cluster: 693; Energy: -167.8750755323; Fitness: 0.41592890422690687
# Cluster: 694; Energy: -169.4757804126; Fitness: 0.37641477955732633
# Cluster: 695; Energy: -168.4418671616; Fitness: 0.3588218976236414
# Cluster: 696; Energy: -169.3415352946; Fitness: 0.3899468311868169
# Cluster: 697; Energy: -164.6579059267; Fitness: 0.4191113658691744
# Cluster: 699; Energy: -167.7679582731; Fitness: 0.3677019980124941
# Cluster: 700; Energy: -167.6789048052; Fitness: 0.4047420399757077
# Cluster: 701; Energy: -167.9568889455; Fitness: 0.38744812815078045
# Cluster: 703; Energy: -170.9758732026; Fitness: 0.42856473125810046
# Cluster: 706; Energy: -166.8499731738; Fitness: 0.35152871653770784
# Cluster: 707; Energy: -171.0672450811; Fitness: 0.4161717817201494
# Cluster: 708; Energy: -166.8033589056; Fitness: 0.37700853278342156
# --------------------------------------------------------------------------
#
# Offspring that replace clusters in population due to fitness.
# Replacing Cluster 677(fitness = 0.401) with Offspring 703(fitness = 0.428)
# Replacing Cluster 682(fitness = 0.407) with Offspring 697(fitness = 0.419)
# Replacing Cluster 702(fitness = 0.409) with Offspring 707(fitness = 0.416)
# ****---------------------****
# <Collection: Population> current size: 20; Clusters: [Cluster_121, Cluster_401, Cluster_593, Cluster_580, Cluster_599, Cluster_637, Cluster_707, Cluster_517, Cluster_397, Cluster_678, Cluster_573, Cluster_697, Cluster_648, Cluster_674, Cluster_347, Cluster_703, Cluster_456, Cluster_704, Cluster_616, Cluster_628]
# Time Information
# fitness_timer_1   = 0.8482284545898438 seconds
# memory_operator_timer_1   = 1.7404556274414062e-05 seconds
# predation_timer_1 = 3.6088225841522217 seconds
# fitness_timer_2   = 0.0005731582641601562 seconds
# ending_timer      = 0.03225398063659668 seconds
# The amount of time required for generation 43 is 7.122910499572754 seconds
# ----------------------------------------------------------
# Time elapsed: 00:05:57
# Date and Time: 2021-03-23 03:01:56.011415
#
#
# ----------------------------------------------------------
# #####################
# RUNNING GENERATION 44
# #####################
# -----------------------
# Making Offspring
# -----------------------
# Time taken to make offspring: 2

# ****---------------------****
# <Collection: Population> current size: 20; Clusters: [Cluster_121, Cluster_401, Cluster_593, Cluster_580, Cluster_599, Cluster_637, Cluster_707, Cluster_517, Cluster_397, Cluster_678, Cluster_573, Cluster_714, Cluster_711, Cluster_722, Cluster_347, Cluster_703, Cluster_456, Cluster_704, Cluster_616, Cluster_628]
# Time Information
# fitness_timer_1   = 0.867821216583252 seconds
# memory_operator_timer_1   = 2.3365020751953125e-05 seconds
# predation_timer_1 = 3.257251262664795 seconds
# fitness_timer_2   = 0.0006573200225830078 seconds
# ending_timer      = 0.03438282012939453 seconds
# The amount of time required for generation 44 is 7.1057822704315186 seconds
# ----------------------------------------------------------
# Time elapsed: 00:06:04
# Date and Time: 2021-03-23 03:02:03.166054
#
#
# ----------------------------------------------------------
# #####################
# RUNNING GENERATION 45
# #####################
# -----------------------
# Making Offspring
# -----------------------
# Time taken to make offspring: 2.42204213142395 s.
# Details of created offsprings
# Time taken to add offspring to Offspring_Pool: 9.417533874511719e-05 s.
# -----------------------
# Processing CNA Profiles took 1.0556871891021729 seconds.
# Processing CNA similarities took 0.06780600547790527 seconds.
# -----------------------------
# ****---------------------****
# Natural Selection for Generation 45
# --------------------------------------------------------------------------
# <Collection: Population> current size: 20
# Cluster: 121; Energy: -171.4524113311; Fitness: 0.41762919179038793
# Cluster: 401; Energy: -173.2523756512; Fitness: 0.505444589634155
# Cluster: 593; Energy: -171.8862167053; Fitness: 0.4062874891860879
# Cluster: 580; Energy: -172.877727624; Fitness: 0.4471535725058212
# Cluster: 599; Energy: -170.891427358; Fitness: 0.4122565781793697
# Cluster: 637; Energy: -170.9924495869; Fitness: 0.4383778428408869
# Cluster: 707; Energy: -171.0672450811; Fitness: 0.4045436992316601
# Cluster: 517; Energy: -170.7491580531; Fitness: 0.40888848958781576
# Cluster: 397; Energy: -171.8560100493; Fitness: 0.42861540836910006
# Cluster: 678; Energy: -171.1114345109; Fitness: 0.4831853531808298
# Cluster: 573; Energy: -171.3836081052; Fitness: 0.43760499069553754
# Cluster: 714; Energy: -171.3048232139; Fitness: 0.4313547335614123
# Cluster: 711; Energy: -170.5580784109; Fitness: 0.4188622885982559
# Cluster: 722; Energy: -171.4275196711; Fitness: 0.4212730693475153
# Cluster: 347; Energy: -171.7734079673; Fitness: 0.4025964249572802
# Cluster: 703; Energy: -170.9758732026; Fitness: 0.41360141146711715
# Cluster: 456; Energy: -173.1343161706; Fitness: 0.45136235473509295
# Cluster: 704; Energy: -172.1109070295; Fitness: 0.4079954797790969
# Cluster: 616; Energy: -169.0600833897; Fitness: 0.4404726056324123
# Cluster: 628; Energy: -172.3154154378; Fitness: 0.4195804622222464
# --------------------------------------------------------------------------
#
# --------------------------------------------------------------------------
# <Collection: Offspring> current size: 16
# Cluster: 725; Energy: -173.9284144982; Fitness: 0.5272001269012718
# Cluster: 726; Energy: -169.3217194322; Fitness: 0.4173946744647823
# Cluster: 727; Energy: -171.9074370762; Fitness: 0.4311561164056853
# Cluster: 728; Energy: -169.0472162006; Fitness: 0.37780931093111775
# Cluster: 729; Energy: -168.8803095109; Fitness: 0.40363133293609904
# Cluster: 730; Energy: -167.5606686661; Fitness: 0.47472978107191893
# Cluster: 731; Energy: -168.5520900696; Fitness: 0.4494916105666841
# Cluster: 732; Energy: -168.220476821; Fitness: 0.3577834685975733
# Cluster: 733; Energy: -166.1813724426; Fitness: 0.37523813949121054
# Cluster: 734; Energy: -170.0251384689; Fitness: 0.3758726780013381
# Cluster: 735; Energy: -169.0758271769; Fitness: 0.4061958627555689
# Cluster: 736; Energy: -172.1249770914; Fitness: 0.41455409278340316
# Cluster: 737; Energy: -170.0012153905; Fitness: 0.3984990912178599
# Cluster: 738; Energy: -169.2818610495; Fitness: 0.3901979262286965
# Cluster: 739; Energy: -166.0147847821; Fitness: 0.3875431203349424
# Cluster: 740; Energy: -164.5703115865; Fitness: 0.3896151347328027
# --------------------------------------------------------------------------
#
# Offspring that replace clusters in population due to fitness.
# Replacing Cluster 347(fitness = 0.402) with Offspring 725(fitness = 0.527)
# Replacing Cluster 707(fitness = 0.404) with Offspring 730(fitness = 0.474)
# Replacing Cluster 593(fitness = 0.406) with Offspring 731(fitness = 0.449)
# Replacing Cluster 704(fitness = 0.407) with Offspring 727(fitness = 0.431)
# Replacing Cluster 517(fitness = 0.408) with Offspring 726(fitness = 0.417)
# Replacing Cluster 599(fitness = 0.412) with Offspring 736(fitness = 0.414)
# ****---------------------****
# <Collection: Population> current size: 20; Clusters: [Cluster_121, Cluster_401, Cluster_731, Cluster_580, Cluster_736, Cluster_637, Cluster_730, Cluster_726, Cluster_397, Cluster_678, Cluster_573, Cluster_714, Cluster_711, Cluster_722, Cluster_725, Cluster_703, Cluster_456, Cluster_727, Cluster_616, Cluster_628]
# Time Information
# fitness_timer_1   = 1.1263344287872314 seconds
# memory_operator_timer_1   = 2.2411346435546875e-05 seconds
# predation_timer_1 = 3.2604808807373047 seconds
# fitness_timer_2   = 0.0006108283996582031 seconds
# ending_timer      = 0.06901383399963379 seconds
# The amount of time required for generation 45 is 9.211200475692749 seconds
# ----------------------------------------------------------
# Time elapsed: 00:06:13
# Date and Time: 2021-03-23 03:02:12.414914
# Finishing by finding the energy of the desired LES cluster
# ----------------------------------------------------------
# Time elapsed: 00:06:13
# Date and Time: 2021-03-23 03:02:12.422965
# ----------------------------------------------------------
# Finishing the Garden Group Genetic Algorithm Successfully.
# ----------------------------------------------------------
# ----------------------------------------------------------
# ' ---------------- '

# %% [markdown]
# [Back To Table of Contents](../Organisms_Jupyter_Example.ipynb)

# %% [markdown]
# ## Post-processing data from your global optimisation
#
# Once the genetic algorithm is finished, we generally would like to get data from it, such as the global minimum. We can get this from the Database that is recorded based on our settings for the ``ga_recording_information`` variable. The following code is a simple way of extracting the lowest energy cluster that was obtained during the genetic algorithm. This is not to be included in the *Run.py* file, this is just so you can see the fruits of your global optimisation work!

# %%
from ase.io import read
database_path = 'Recorded_Data/GA_Recording_Database.db'
lowest_energy_cluster_found = read(database_path)
if isinstance(lowest_energy_cluster_found, list):
    lowest_energy_cluster_found = lowest_energy_cluster_found[0]
lowest_energy_cluster_found.center(about=0.,vacuum=0.0)
from ase.visualize import view
view(lowest_energy_cluster_found,viewer='x3d')
# Out:
# <html>
#
#  <head>
#
#   <title>ASE atomic visualization</title>
#
#   <link rel="stylesheet" type="text/css"
#
#    href="https://www.x3dom.org/x3dom/release/x3dom.css">
#
#   </link>
#
#   <script type="text/javascript"
#
#    src="https://www.x3dom.org/x3dom/release/x3dom.js">
#
#   </script>
#
#  </head>
#
#  <body>
#
#   <X3D>
#
#    <Scene>
#
#     <Transform translation="-0.39 -0.35 1.67">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.702 0.890 0.961" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.58">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.74 0.67 1.44">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.702 0.890 0.961" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.58">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="0.67 -0.63 1.49">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.702 0.890 0.961" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.58">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="0.32 0.39 1.25">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.702 0.890 0.961" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.58">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.03 1.42 1.02">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.702 0.890 0.961" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.58">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="1.37 0.11 1.08">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.702 0.890 0.961" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.58">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-1.19 -0.77 1.03">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.702 0.890 0.961" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.58">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="1.02 1.14 0.84">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.702 0.890 0.961" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.58">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-1.54 0.26 0.80">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.702 0.890 0.961" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.58">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.13 -1.04 0.85">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.702 0.890 0.961" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.58">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.48 -0.02 0.61">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.702 0.890 0.961" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.58">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="0.92 -1.33 0.67">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.702 0.890 0.961" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.58">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.83 1.00 0.38">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.702 0.890 0.961" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.58">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="0.57 -0.30 0.43">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.702 0.890 0.961" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.58">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="0.22 0.71 0.20">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.702 0.890 0.961" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.58">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.93 -1.47 0.21">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.702 0.890 0.961" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.58">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="1.63 -0.58 0.26">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.702 0.890 0.961" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.58">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.12 1.75 -0.03">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.702 0.890 0.961" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.58">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="1.28 0.44 0.02">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.702 0.890 0.961" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.58">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-1.28 -0.44 -0.02">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.702 0.890 0.961" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.58">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="0.12 -1.75 0.03">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.702 0.890 0.961" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.58">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="0.93 1.47 -0.21">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.702 0.890 0.961" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.58">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.22 -0.71 -0.20">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.702 0.890 0.961" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.58">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-1.63 0.58 -0.26">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.702 0.890 0.961" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.58">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.57 0.30 -0.43">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.702 0.890 0.961" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.58">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="0.83 -1.00 -0.38">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.702 0.890 0.961" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.58">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="0.48 0.02 -0.61">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.702 0.890 0.961" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.58">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="0.13 1.04 -0.85">
#
#      <Shape>

# %% [markdown]
# [Back To Table of Contents](../Organisms_Jupyter_Example.ipynb)
