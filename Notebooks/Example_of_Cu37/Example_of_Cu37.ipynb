# %% [markdown]
# # A Basic Example for Optimising a 37 atom Copper Cluster with Organisms

# %% [markdown]
# [Back To Table of Contents](../Organisms_Jupyter_Example.ipynb)

# %% [markdown]
# In this example, we will perform a genetic algorithm optimisation on the 37 atom Lennard-Jones (Cu<sub>37</sub>) cluster. In this example, we will perform a genetic algorithm with a simple energy predation operator, the energy fitness operator, and a population-based epoch method. We will go through step by step all the components of the *Run.py* files required to run Organisms on LJ<sub>38</sub>. See [organisms.readthedocs.io/en/latest/Using_Run](https://organisms.readthedocs.io/en/latest/Using_Run.html) for more information on the *Run.py* file.
#
# To run this notebook step by step, press the $\blacktriangleright$ button sequentially on the python code you want to run. You can find the $\blacktriangleright$ button in the menu bar above. Make sure you have run $\blacktriangleright$ on every cell before running the final cell. Equivalently, press the $\blacktriangleright\blacktriangleright$ button to completely run this *Run.py* file beginning to end. You can also find the $\blacktriangleright\blacktriangleright$ button in the menu bar above.
#
# Note: These are the vanilla settings for running Organisms on a Cu<sub>37</sub> nanocluster, but feel free to change the settings as you wish.
#
# Also note: This program makes files which are created and stored on the Binder server. If you want to rerun this example, you will need to remove these files. The following block code will do this. This is only needed for this notebook and is not apart of *Run.py* script.

# %%
import os
from shutil import rmtree
to_be_removed_before_restarting_Jupyter_example = ['__pycache__','Population','epoch_data','epoch_data.backup','GA_Run_Details.txt','ga_running.lock','Recorded_Data','Initial_Population','Saved_Points_In_GA_Run']
for example_file_or_folder in to_be_removed_before_restarting_Jupyter_example:
    if os.path.exists(example_file_or_folder):
        if os.path.isdir(example_file_or_folder):
            rmtree(example_file_or_folder)
        else:
            os.remove(example_file_or_folder)

# %% [markdown]
# ## Setting up the *Run.py* Script for a Global Optimisation of a 37 atom Copper Nanocluster

# %% [markdown]
# The following contains all the options that you desire to set up the Organisms program to global optimise a Cu<sub>37</sub> nanocluster. These are the vanilla settings, but feel free to change them as you wish.

# %%
from Organisms import GA_Program

# This details the elemental and number of atom composition of cluster that the user would like to investigate
cluster_makeup = {"Cu": 37}

# Surface details
surface_details = None #{'surface': 'surface.xyz', 'place_cluster_where': 'center'}

# These are the main variables of the genetic algorithm that with changes could affect the results of the Genetic Algorithm.
pop_size = 20
generations = 200
no_offspring_per_generation = 16

# These setting indicate how offspring should be made using the Mating and Mutation Proceedures
creating_offspring_mode = "Either_Mating_and_Mutation" 
crossover_type = "CAS_weighted"
mutation_types = [['random', 1.0]]
chance_of_mutation = 0.1

# This parameter will tell the Organisms program if an epoch is desired, and how the user would like to proceed.
epoch_settings = {'epoch mode': 'same population', 'max repeat': 5}

# These are variables used by the algorithm to make and place clusters in.
r_ij = 3.4
cell_length = r_ij * (sum([float(noAtoms) for noAtoms in list(cluster_makeup.values())]) ** (1.0/3.0))
vacuum_to_add_length = 10.0

# The RunMinimisation.py algorithm is one set by the user. It contain the def Minimisation_Function
# That is used for local optimisations. This can be written in whatever way the user wants to perform
# the local optimisations. This is meant to be as free as possible.
from RunMinimisation_Cu import Minimisation_Function

# This dictionary includes the information required to prevent clusters being placed in the population if they are too similar to clusters in this memory_operator
memory_operator_information = {'Method': 'Off'}

# This switch tells the genetic algorithm the type of predation scheme they want to place on the genetic algoithm.
#predation_information = {'Predation Operator':'Off'}
#predation_information = {'Predation Operator':'Energy', 'mode': 'simple', 'round_energy': 2}
#predation_information = {'Predation Operator':'Energy', 'mode': 'comprehensive', 'minimum_energy_diff': 0.025, 'type_of_comprehensive_scheme': 'energy'}
predation_information = {'Predation Operator':'Energy', 'mode': 'comprehensive', 'minimum_energy_diff': 0.025, 'type_of_comprehensive_scheme': 'fitness'}
#predation_information = {'Predation Operator': 'IDCM', 'percentage_diff': 5.0}
#predation_information = {'Predation Operator': 'SCM', 'CNA Scheme': 'T-SCM', 'rCut_high': 3.2, 'rCut_low': 2.9, 'rCut_resolution': 0.05}

# This switch tells the genetic algorithm the type of fitness scheme they want to place on the genetic algoithm.
energy_fitness_function = {'function': 'exponential', 'alpha': 3.0}
#SCM_fitness_function = {'function': 'exponential', 'alpha': 1.0}
fitness_information = {'Fitness Operator': 'Energy', 'fitness_function': energy_fitness_function}
#fitness_information = {'Fitness Operator': 'SCM + Energy', 'Use Predation Information': True, 'SCM_fitness_contribution': 0.5, 'normalise_similarities': False, 'Dynamic Mode': False, 'energy_fitness_function': energy_fitness_function, 'SCM_fitness_function': SCM_fitness_function}
#fitness_information = {'Fitness Operator': 'SCM + Energy', 'CNA Scheme': 'T-SCM', 'rCut_high': 3.2, 'rCut_low': 2.9, 'rCut_resolution': 0.05, 'SCM_fitness_contribution': 0.5, 'normalise_similarities': False, 'Dynamic Mode': False, 'energy_fitness_function': energy_fitness_function, 'SCM_fitness_function': SCM_fitness_function}
#fitness_information = {'Fitness Operator': 'SCM + Energy', 'CNA Scheme': 'T-SCM', 'rCut': 3.05, 'SCM_fitness_contribution': 0.5, 'normalise_similarities': False, 'Dynamic Mode': False, 'energy_fitness_function': energy_fitness_function, 'SCM_fitness_function': SCM_fitness_function}

# Variables required for the Recording_Cluster.py class/For recording the history as required of the genetic algorithm.
ga_recording_information = {}
#ga_recording_information['ga_recording_scheme'] = 'Limit_energy_height' # float('inf')
#ga_recording_information['limit_number_of_clusters_recorded'] = 5 # float('inf')
#ga_recording_information['limit_energy_height_of_clusters_recorded'] = 1.5 #eV
#ga_recording_information['exclude_recording_cluster_screened_by_diversity_scheme'] = True
#ga_recording_information['record_initial_population'] = True
#ga_recording_information['saving_points_of_GA'] = [3,5]
ga_recording_information = {'ga_recording_scheme': 'Limit_energy_height', 'limit_number_of_clusters_recorded': 1, 'limit_energy_height_of_clusters_recorded': 1.0, 'exclude_recording_cluster_screened_by_diversity_scheme': False}

# These are last techinical points that the algorithm is designed in mind
force_replace_pop_clusters_with_offspring = True
user_initialised_population_folder = None 
rounding_criteria = 10
print_details = True
no_of_cpus = 1
finish_algorithm_if_found_cluster_energy = None
total_length_of_running_time = 70.0

# %% [markdown]
# [Back To Table of Contents](../Organisms_Jupyter_Example.ipynb)

# %% [markdown]
# ## The Genetic Algorithm!
#
# You have got to the end of all the parameter setting stuff! Now on to the fun stuff! The next part of the Run.py file tells the genetic algorithm to run. This is written as follows in the Run.py. Note this may take a bit of time to run depending on your settings. Running the below code and good and get yourself a tea or coffee.

# %%
''' ---------------- '''
# This will execute the genetic algorithm program
GA_Program(cluster_makeup=cluster_makeup,
    pop_size=pop_size,
    generations=generations,
    no_offspring_per_generation=no_offspring_per_generation,
    creating_offspring_mode=creating_offspring_mode,
    crossover_type=crossover_type,
    mutation_types=mutation_types,
    chance_of_mutation=chance_of_mutation,
    r_ij=r_ij,
    vacuum_to_add_length=vacuum_to_add_length,
    Minimisation_Function=Minimisation_Function,
    surface_details=surface_details,
    epoch_settings=epoch_settings,
    cell_length=cell_length,
    memory_operator_information=memory_operator_information,
    predation_information=predation_information,
    fitness_information=fitness_information,
    ga_recording_information=ga_recording_information,
    force_replace_pop_clusters_with_offspring=force_replace_pop_clusters_with_offspring,
    user_initialised_population_folder=user_initialised_population_folder,
    rounding_criteria=rounding_criteria,
    print_details=print_details,
    no_of_cpus=no_of_cpus,
    finish_algorithm_if_found_cluster_energy=finish_algorithm_if_found_cluster_energy,
    total_length_of_running_time=total_length_of_running_time)
''' ---------------- '''
# Out:
# ############################################################
# ############################################################
# ############################################################
# The Garden Group Genetic Algorithm for Clusters
#
# .--------------------------------------------------------------------------.
# |                             ,                                            |
# |              ,_     ,     .'<_                                           |
# |             _> `'-,'(__.-' __<                                           |
# |             >_.--(.. )  =;`                                   _          |
# |                  `V-'`'\/``                                  ('>         |
# |                                                              /))@@@@@.   |
# |         .----------------------------------.                /@"@@@@@()@  |
# |         | Welcome to the Organisms program |               .@@()@@()@@@@ |
# |         '----------------------------------'               @@@O@@@@()@@@ |
# |                  ^                                         @()@@\@@@()@@ |
# |  _     (\_/)     |                                          @()@||@@@@@' |
# | ( \    (0.o) ----'                 _                         '@@||@@@'   |
# |  ) )   (> <)                     _(_)_            wWWWw   _     ||       |
# | ( (  .-'''''-.  A.-.A      @@@@ (_)@(_)       _   (___) _(_)_   ||       |
# |  \ \/         \/ , , \    @@()@@  (_)\      _(_)_   Y  (_)@(_)  ||       |
# |   \   \        ;= t =/     @@@@      `|/   (_)@(_) \|/   (_)\   ||       |
# |    \   |'''''-   ,--'       /        \|     /(_)    |/      |   ||       |
# |     / //     | ||        \ |          | / \|/      \|      \|/  ||       |
# |    /_,))     |_'))       \\|//     \\\|// \|///   \\|//  \\\|// ||       |
# |^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^|
# '--------------------------------------------------------------------------'
#
# Version: 3.2.1
# ############################################################
# ############################################################
#
# This algorithm is designed to perform a genetic algorithm to obtain low energetic structures for a given cluster composition.
#
# This genetic algorithm will proceed with the following input parameters
#
# # This details the elemental and number of atom composition of cluster that the user would like to investigate
# cluster_makeup = {'Cu': 37}
#
# # This details the information used to perform a global optimisation upon a chosen surface
# surface_details = None
#
# # These are the main variables of the genetic algorithm that with changes could affect the results of the Genetic Algorithm.
# pop_size = 20
# generations = 200
# no_offspring_per_generation = 16
#
# # These setting indicate how offspring should be made using the Mating and Mutation Proceedures
# creating_offspring_mode = Either_Mating_and_Mutation
# crossover_type = CAS_weighted
# mutation_types = [['random', 1.0]]
# mutation_types = 0.1
#
# # These are variables used by the algorithm to make and place clusters in.
# r_ij = 3.4 Angstroms (This is the maximum possible bond length between two atoms in the cluster)
# cell_length = 11.329554295596239 Angstroms
# vacuum_to_add_length = 10.0 Angstroms
#
# # The RunMinimisation.py algorithm is one set by the user. It contain the def Minimisation_Function
# # That is used for local optimisations. This can be written in whatever way the user wants to perform
# # the local optimisations. This is meant to be as free as possible.
# Minimisation_Function = <function Minimisation_Function at 0x7f62240cdd90>
# Path of Minimisation_Function: /mnt/hgfs/GoogleDrive/PhDWork/Programs/OptimisationAlgorithms/GeneticAlgorithm/Organisms/Organisms_Jupyter_Examples/Notebooks/Example_of_Cu37/RunMinimisation_Cu.py
#
# # This details the information about the memory operator used in this genetic algorithm.
# memory_operator = {'method': 'Off'}
#
# # This details the information about the predation operator used in this genetic algorithm.
# predation_operator = {'predation_information': {'Predation Operator': 'Energy', 'mode': 'comprehensive', 'minimum_energy_diff': 0.025, 'type_of_comprehensive_scheme': 'fitness'}, 'Predation_Switch': 'Energy', 'population': <Collection: Population> current size: 0; Clusters: [], 'print_details': False, 'mode': 'comprehensive', 'type_of_comprehensive_scheme': 'fitness', 'minimum_energy_diff': 0.025, 'check_initial_population_imported': <function check_initial_population at 0x7f61f1406158>, 'assess_for_violations_force_replacement_imported': <function assess_for_violations_force_replacement at 0x7f61f1406400>, 'assess_for_violations_no_force_replacement_imported': <function assess_for_violations_no_force_replacement at 0x7f61f1406378>}
#
# # This details the information about the fitness operator used in this genetic algorithm.
# fitness_operator = {'fitness_switch': 'Energy', 'fitness_information': {'Fitness Operator': 'Energy', 'fitness_function': {'function': 'exponential', 'alpha': 3.0}, 'Use Predation Information': False}, 'population': <Collection: Population> current size: 0; Clusters: [], 'print_details': False, 'previous_max_energy': -inf, 'previous_min_energy': inf, 'energy_fitness_function': <Organisms.GA.Fitness_Operators.Fitness_Function.Fitness_Function object at 0x7f6224096a58>}
#
# # This parameter will tell the Organisms program if an epoch is desired, and how the user would like to proceed.
# epoch_settings: {'path': '/mnt/hgfs/GoogleDrive/PhDWork/Programs/OptimisationAlgorithms/GeneticAlgorithm/Organisms/Organisms_Jupyter_Examples/Notebooks/Example_of_Cu37', 'epoch_data_name': 'epoch_data', 'backup_epoch_data_name': 'epoch_data.backup', 'epoch_settings': {'epoch mode': 'same population', 'max repeat': 5}, 'epoch_mode': 'same population', 'max_number_of_times_non_changing_population': 5, 'epoch_function': <bound method Epoch.should_epoch_using_same_population_epoch of {...}>, 'perform_epoch_function': <bound method Epoch.perform_epoch_same_population of {...}>, 'first_epoch_to_change_fitness_function': False}
#
# # Variables required for the GA_Recording_System.py class/For recording the history as required of the genetic algorithm.
# ga_recording_system = {'ga_recording_information': {'ga_recording_scheme': 'Limit_energy_height', 'limit_number_of_clusters_recorded': 1, 'limit_energy_height_of_clusters_recorded': 1.0, 'exclude_recording_cluster_screened_by_diversity_scheme': False}, 'ga_recording_scheme': 'Limit_energy_height', 'ga_recording_system_name': 'Recorded_Data', 'path_to_write_to': '/mnt/hgfs/GoogleDrive/PhDWork/Programs/OptimisationAlgorithms/GeneticAlgorithm/Organisms/Organisms_Jupyter_Examples/Notebooks/Example_of_Cu37/Recorded_Data', 'exclude_recording_cluster_screened_by_diversity_scheme': False, 'limit_number_of_clusters_recorded': 1, 'limit_size_of_database': None, 'show_GA_Recording_Database_check_percentage': False, 'limit_energy_height_of_clusters_recorded': 1.0, 'clusters_database': <Collection: GA_Recording_Database> current size: 0; Clusters: [], 'directory': '/mnt/hgfs/GoogleDrive/PhDWork/Programs/OptimisationAlgorithms/GeneticAlgorithm/Organisms/Organisms_Jupyter_Examples/Notebooks/Example_of_Cu37/Recorded_Data', 'RC_Information_TXT_name': 'Recorded_Data_Information.txt', 'record_initial_population': False, 'saving_points_of_GA': []}
#
# # These are last techinical points that the algorithm is designed in mind
# force_replace_pop_clusters_with_offspring = True
# user_initialised_population_folder = None
# rounding_criteria = 10
# print_details = True
# no_of_cpus = 1
# finish_algorithm_if_found_cluster_energy = None
# total_length_of_running_time: 70.0 hours
#
# ############################################################
# ############################################################
# ############################################################
# ################################################################################################################
# ################################################################################################################
# Initalising a Starting Population of Clusters if required to take pool up to a size of 20
# Pool size to begin = 0
# Checking to see if the user has any clusters in the folder None that the user would like to have inputted into the initalise population.
# ################################################################################################################
# Will now population the next 20 with randomly generated clusters.
# -----------------------------
# Checking that the clusters in the population satisfies the Diversity Scheme
# *****************************
# *****************************
# Diversity Scheme located "duplicates" in creating population.
# Recreating clusters: [4, 7, 8]
# -----------------------------
# Checking that the clusters in the population satisfies the Diversity Scheme
# *****************************
# *****************************
# Diversity Scheme located "duplicates" in creating population.
# Recreating clusters: [2, 7, 8]
# -----------------------------
# Checking that the clusters in the population satisfies the Diversity Scheme
# *****************************
# *****************************
# Diversity Scheme located "duplicates" in creating population.
# Recreating clusters: [4, 15]
# -----------------------------
# Checking that the clusters in the population satisfies the Diversity Scheme
# *****************************
# *****************************
# Diversity Scheme located "duplicates" in creating population.
# Recreating clusters: [2, 15]
# -----------------------------
# Checking that the clusters in the population satisfies the Diversity Scheme
# Have finished populating the rest of the population with 0 randomly generated clusters.
# The population has been successfully initalised.
# ################################################################################################################
# ################################################################################################################
# Time elapsed: 00:00:25
# Date and Time: 2021-02-08 00:19:16.078450
# -----------------------------
# -----------------------------
# Starting Genetic Algorithm
# -----------------------------
# -----------------------------
#
#
#
# ----------------------------------------------------------
# ####################
# RUNNING GENERATION 1
# ####################
# -----------------------
# Making Offspring
# -----------------------
# Time taken to make offspring: 2.6952083110809326 s.
# Details of created offsprings
# Time taken to add offspring to Offspring_Pool: 0.00012922286987304688 s.
# -----------------------
# **********************************************************
# **********************************************************
# Offspring removed from the Offspring Pool due to violating the Comprehensive Energy Diversity Scheme.
# NOTE: energy difference minimum = 0.025 eV.
# **********************************************************
# **********************************************************
# Assessing which structures to remove to comply with the Energy Diversity Scheme
# Start assessing for Energy Diversity
# Removing offspring that violate the Energy Diversity Scheme
# 1. Clusters in the Population that have been replaced by Offspring, due to the cluster in the offspring being energetically similar and having a lower energy than a offspring.
# 1. Clusters in the Population that have been replaced by Offspring, due to the cluster in the offspring being energetically similar and having a lower energy than a offspring.
#  --> Population Cluster removed 11 (Energy: -104.377539 eV, fitness = 0.451848) {Replaced with Offspring 24 (Energy: -104.381407 eV, fitness = 0.453562)}.
#  --> Population Cluster removed 2 (Energy: -105.039 eV, fitness = 0.863306) {Replaced with Offspring 32 (Energy: -105.039097 eV, fitness = 0.863388)}.
# *****************************
# 2. These offspring have a better energy and are energetically similar to two or more clusters in the population.
# 2. No offspring need to be removed from the offsprings list
# *****************************
# 3. The following offspring were removed from the offspring pool (and because they are energetically similar and have a lower energy to which cluster in the population):
# 3. The following offspring were removed from the offspring pool (and because they are energetically similar and have a lower energy to which cluster in the population):
#  --> Offspring 31 (Energy: -104.593338052 eV, fitness = 0.558115) {Similar to Population Cluster 17 (Energy: -104.594033 eV, fitness = 0.558495)}.
#  --> Offspring 26 (Energy: -104.4870193096 eV, fitness = 0.502956) {Similar to Population Cluster 6 (Energy: -104.498163 eV, fitness = 0.508472)}.
#  --> Offspring 35 (Energy: -104.2850442312 eV, fitness = 0.412739) {Similar to Population Cluster 16 (Energy: -104.300364 eV, fitness = 0.418974)}.
#  --> Offspring 30 (Energy: -104.1068270146 eV, fitness = 0.346672) {Similar to Population Cluster 13 (Energy: -104.120092 eV, fitness = 0.351202)}.
# *****************************
# 4. Offspring that have have been removed for being energetically similar and have a lower energy to the rest of the other Offspring
# 4. Offspring that have have been removed for being energetically similar and have a lower energy to the rest of the other Offspring
#  --> Offspring 22 (Energy: -105.0052282314eV, fitness = 0.835236) {Similar to Offspring 29 (Energy: -105.0124452445 eV, fitness = 0.841157)}.
#  --> Offspring 27 (Energy: -104.9777308802eV, fitness = 0.813056) {Similar to Offspring 33 (Energy: -104.9799949788 eV, fitness = 0.81486)}.
#  --> Offspring 25 (Energy: -104.7941245474eV, fitness = 0.679319) {Similar to Offspring 23 (Energy: -104.8148060434 eV, fitness = 0.69321)}.
# **********************************************************
# **********************************************************
# -----------------------------
# ****---------------------****
# Natural Selection for Generation 1
# --------------------------------------------------------------------------
# <Collection: Population> current size: 20
# Cluster: 1; Energy: -104.0925846349; Fitness: 0.3418730825520829
# Cluster: 32; Energy: -105.0390966412; Fitness: 0.863387673525283
# Cluster: 3; Energy: -102.1241238301; Fitness: 0.049787068367863944
# Cluster: 4; Energy: -104.2646592177; Fitness: 0.40458514927144335
# Cluster: 5; Energy: -103.3466304008; Fitness: 0.16473146611033723
# Cluster: 6; Energy: -104.498163255; Fitness: 0.5084722365202348
# Cluster: 7; Energy: -102.9850913907; Fitness: 0.1156363761666019
# Cluster: 8; Energy: -104.0152756045; Fitness: 0.3169586294214481
# Cluster: 9; Energy: -103.7901131552; Fitness: 0.25426764124104706
# Cluster: 10; Energy: -105.0783720792; Fitness: 0.8972241364111212
# Cluster: 24; Energy: -104.3814067843; Fitness: 0.45356203858091815
# Cluster: 12; Energy: -102.9282044423; Fitness: 0.10937375252981431
# Cluster: 13; Energy: -104.120091733; Fitness: 0.3512024652473424
# Cluster: 14; Energy: -103.7226561146; Fitness: 0.23802173995363685
# Cluster: 15; Energy: -102.4056532408; Fitness: 0.06558256012110872
# Cluster: 16; Energy: -104.3003637042; Fitness: 0.4189740361539912
# Cluster: 17; Energy: -104.5940329606; Fitness: 0.5584950101632393
# Cluster: 18; Energy: -102.6843543009; Fitness: 0.08615052128967637
# Cluster: 19; Energy: -104.6470272046; Fitness: 0.588228356925815
# Cluster: 20; Energy: -104.785090601; Fitness: 0.6733387325198046
# --------------------------------------------------------------------------
#
# --------------------------------------------------------------------------
# <Collection: Offspring> current size: 7
# Cluster: 21; Energy: -104.2032518502; Fitness: 0.380984273176237
# Cluster: 23; Energy: -104.8148060434; Fitness: 0.6932102288593952
# Cluster: 28; Energy: -105.1891731787; Fitness: 1.0
# Cluster: 29; Energy: -105.0124452445; Fitness: 0.8411567522699571
# Cluster: 33; Energy: -104.9799949788; Fitness: 0.8148601103756801
# Cluster: 34; Energy: -103.9209911036; Fitness: 0.2890176479754488
# Cluster: 36; Energy: -104.8757074653; Fitness: 0.7357881433661033
# --------------------------------------------------------------------------
#
# Offspring that replace clusters in population due to fitness.
# Replacing Cluster 3(fitness = 0.049) with Offspring 28(fitness = 1.0)
# Replacing Cluster 15(fitness = 0.065) with Offspring 29(fitness = 0.841)
# Replacing Cluster 18(fitness = 0.086) with Offspring 33(fitness = 0.814)
# Replacing Cluster 12(fitness = 0.109) with Offspring 36(fitness = 0.735)
# Replacing Cluster 7(fitness = 0.115) with Offspring 23(fitness = 0.693)
# Replacing Cluster 5(fitness = 0.164) with Offspring 21(fitness = 0.38)
# Replacing Cluster 14(fitness = 0.238) with Offspring 34(fitness = 0.289)
# ****---------------------****
# <Collection: Population> current size: 20; Clusters: [Cluster_1, Cluster_32, Cluster_28, Cluster_4, Cluster_21, Cluster_6, Cluster_23, Cluster_8, Cluster_9, Cluster_10, Cluster_24, Cluster_36, Cluster_13, Cluster_34, Cluster_29, Cluster_16, Cluster_17, Cluster_33, Cluster_19, Cluster_20]
# Time Information
# fitness_timer_1   = 0.00018477439880371094 seconds
# memory_operator_timer_1   = 1.2874603271484375e-05 seconds
# predation_timer_1 = 8.255570650100708 seconds
# fitness_timer_2   = 8.654594421386719e-05 seconds
# ending_timer      = 0.19977164268493652 seconds
# The amount of time required for generation 1 is 15.279648065567017 seconds
# ----------------------------------------------------------
# Time elapsed: 00:00:40
# Date and Time: 2021-02-08 00:19:31.471615
#
#
# ----------------------------------------------------------
# ####################
# RUNNING GENERATION 2
# ####################
# -----------------------
# Making Offspring
# -----------------------
# Time taken to make offspring: 3.4230353832244873 s.
# Details of created offsprings
# Time taken to add offspring to Offspring_Pool: 0.00010323524475097656 s.
# -----------------------
# **********************************************************
# **********************************************************
# Offspring removed from the Offspring Pool due to violating the Comprehensive Energy Diversity Scheme.
# NOTE: energy difference minimum = 0.025 eV.
# **********************************************************
# **********************************************************
# Assessing which structures to remove to comply with the Energy Diversity Scheme
# Start assessing for Energy Diversity
# Removing offspring that violate the Energy Diversity Scheme
# 1. Clusters in the Population that have been replaced by Offspring, due to the cluster in the offspring being energetically similar and having a lower energy than a offspring.
# 1. Clusters in the Population that have been replaced by Offspring, due to the cluster in the offspring being energetically similar and having a lower energy than a offspring.
#  --> Population Cluster removed 23 (Energy: -104.814806 eV, fitness = 0.418797) {Replaced with Offspring 37 (Energy: -104.834746 eV, fitness = 0.430324)}.
#  --> Population Cluster removed 16 (Energy: -104.300364 eV, fitness = 0.207869) {Replaced with Offspring 38 (Energy: -104.314662 eV, fitness = 0.211955)}.
#  --> Population Cluster removed 24 (Energy: -104.381407 eV, fitness = 0.232121) {Replaced with Offspring 41 (Energy: -104.386226 eV, fitness = 0.233649)}.
# *****************************
# 2. These offspring have a better energy and are energetically similar to two or more clusters in the population.
# 2. No offspring need to be removed from the offsprings list
# *****************************
# 3. The following offspring were removed from the offspring pool (and because they are energetically similar and have a lower energy to which cluster in the population):
# 3. The following offspring were removed from the offspring pool (and because they are energetically similar and have a lower energy to which cluster in the population):
#  --> Offspring 39 (Energy: -105.0157947806 eV, fitness = 0.550628) {Similar to Population Cluster 32 (Energy: -105.039097 eV, fitness = 0.568379)}.
#  --> Offspring 52 (Energy: -104.571471668 eV, fitness = 0.300683) {Similar to Population Cluster 17 (Energy: -104.594033 eV, fitness = 0.310063)}.
# *****************************
# 4. Offspring that have have been removed for being energetically similar and have a lower energy to the rest of the other Offspring
# 4. Offspring that have have been removed for being energetically similar and have a lower energy to the rest of the other Offspring
#  --> Offspring 43 (Energy: -105.119840118eV, fitness = 0.634432) {Similar to Offspring 49 (Energy: -105.1351454072 eV, fitness = 0.647793)}.
# **********************************************************
# **********************************************************
# -----------------------------
# ****---------------------****
# Natural Selection for Generation 2
# --------------------------------------------------------------------------
# <Collection: Population> current size: 20
# Cluster: 1; Energy: -104.0925846349; Fitness: 0.15664584718083543
# Cluster: 32; Energy: -105.0390966412; Fitness: 0.5683786728051179
# Cluster: 28; Energy: -105.1891731787; Fitness: 0.6972449501126076
# Cluster: 4; Energy: -104.2646592177; Fitness: 0.19800447740190838
# Cluster: 21; Energy: -104.2032518502; Fitness: 0.1821217556253178
# Cluster: 6; Energy: -104.498163255; Fitness: 0.2721180686040485
# Cluster: 37; Energy: -104.8347457353; Fitness: 0.4303235147933834
# Cluster: 8; Energy: -104.0152756045; Fitness: 0.1409945323305038
# Cluster: 9; Energy: -103.7901131552; Fitness: 0.10376543040027424
# Cluster: 10; Energy: -105.0783720792; Fitness: 0.5996022624580529
# Cluster: 41; Energy: -104.3862260793; Fitness: 0.2336487423606357
# Cluster: 36; Energy: -104.8757074653; Fitness: 0.4550066613548301
# Cluster: 13; Energy: -104.120091733; Fitness: 0.16262420242331457
# Cluster: 34; Energy: -103.9209911036; Fitness: 0.12400729381162315
# Cluster: 29; Energy: -105.0124452445; Fitness: 0.54812233347858
# Cluster: 38; Energy: -104.3146615304; Fitness: 0.2119550782741608
# Cluster: 17; Energy: -104.5940329606; Fitness: 0.310062918280426
# Cluster: 33; Energy: -104.9799949788; Fitness: 0.5244306516400233
# Cluster: 19; Energy: -104.6470272046; Fitness: 0.3332636305411987
# Cluster: 20; Energy: -104.785090601; Fitness: 0.40219027641790206
# --------------------------------------------------------------------------
#
# --------------------------------------------------------------------------
# <Collection: Offspring> current size: 10
# Cluster: 40; Energy: -104.7560940056; Fitness: 0.38662012792165856
# Cluster: 42; Energy: -103.2507765525; Fitness: 0.049787068367863944
# Cluster: 44; Energy: -104.954028282; Fitness: 0.5062122937239671
# Cluster: 45; Energy: -104.1676913434; Fitness: 0.17351345581253227
# Cluster: 46; Energy: -105.2625360245; Fitness: 0.7704925074978707
# Cluster: 47; Energy: -105.4540161629; Fitness: 1.0
# Cluster: 48; Energy: -103.6801041486; Fitness: 0.08933033866536426
# Cluster: 49; Energy: -105.1351454072; Fitness: 0.6477927918325184
# Cluster: 50; Energy: -105.2173256119; Fitness: 0.7244914916439817
# Cluster: 51; Energy: -104.9210670898; Fitness: 0.483995274554755
# --------------------------------------------------------------------------
#
# Offspring that replace clusters in population due to fitness.
# Replacing Cluster 9(fitness = 0.103) with Offspring 47(fitness = 1.0)
# Replacing Cluster 34(fitness = 0.124) with Offspring 46(fitness = 0.77)
# Replacing Cluster 8(fitness = 0.14) with Offspring 50(fitness = 0.724)
# Replacing Cluster 1(fitness = 0.156) with Offspring 49(fitness = 0.647)
# Replacing Cluster 13(fitness = 0.162) with Offspring 44(fitness = 0.506)
# Replacing Cluster 21(fitness = 0.182) with Offspring 51(fitness = 0.483)
# Replacing Cluster 4(fitness = 0.198) with Offspring 40(fitness = 0.386)
# ****---------------------****
# <Collection: Population> current size: 20; Clusters: [Cluster_49, Cluster_32, Cluster_28, Cluster_40, Cluster_51, Cluster_6, Cluster_37, Cluster_50, Cluster_47, Cluster_10, Cluster_41, Cluster_36, Cluster_44, Cluster_46, Cluster_29, Cluster_38, Cluster_17, Cluster_33, Cluster_19, Cluster_20]
# Time Information
# fitness_timer_1   = 0.00014138221740722656 seconds
# memory_operator_timer_1   = 1.0251998901367188e-05 seconds
# predation_timer_1 = 8.483215093612671 seconds
# fitness_timer_2   = 8.225440979003906e-05 seconds
# ending_timer      = 0.07503652572631836 seconds
# The amount of time required for generation 2 is 15.61234974861145 seconds
# ----------------------------------------------------------
# Time elapsed: 00:00:56
# Date and Time: 2021-02-08 00:19:47.164107
#
#
# ----------------------------------------------------------
# ####################
# RUNNING GENERATION 3
# ####################
# -----------------------
# Making Offspring
# -----------------------
# Time taken to make offspring: 3.346681594848633 s.
# Details of created offsprings
# Time taken to add offspring to Offspring_Pool: 2.6226043701171875e-05 s.
# -----------------------
# **********************************************************
# **********************************************************
# Offspring removed from the Offspring Pool due to violating the Comprehensive Energy Diversity Scheme.
# NOTE: energy difference minimum = 0.025 eV.
# **********************************************************
# **********************************************************
# Assessing which structures to remove to comply with the Energy Diversity Scheme
# Start assessing for Energy Diversity
# Removing offspring that violate the Energy Diversity Scheme
# 1. Clusters in the Population that have been replaced by Offspring, due to the cluster in the offspring being energetically similar and having a lower energy than a offspring.
# 1. Clusters in the Population that have been replaced by Offspring, due to the cluster in the offspring being energetically similar and having a lower energy than a offspring.
#  --> Population Cluster removed 20 (Energy: -104.785091 eV, fitness = 0.171817) {Replaced with Offspring 55 (Energy: -104.7925 eV, fitness = 0.175201)}.
#  --> Population Cluster removed 40 (Energy: -104.756094 eV, fitness = 0.159187) {Replaced with Offspring 60 (Energy: -104.759661 eV, fitness = 0.160689)}.
#  --> Population Cluster removed 46 (Energy: -105.262536 eV, fitness = 0.604) {Replaced with Offspring 67 (Energy: -105.270583 eV, fitness = 0.616934)}.
# *****************************
# 2. These offspring have a better energy and are energetically similar to two or more clusters in the population.
# 2. No offspring need to be removed from the offsprings list
# *****************************
# 3. The following offspring were removed from the offspring pool (and because they are energetically similar and have a lower energy to which cluster in the population):
# 3. The following offspring were removed from the offspring pool (and because they are energetically similar and have a lower energy to which cluster in the population):
#  --> Offspring 66 (Energy: -105.4312893353 eV, fitness = 0.941914) {Similar to Population Cluster 47 (Energy: -105.454016 eV, fitness = 1.0)}.
#  --> Offspring 53 (Energy: -105.1970440815 eV, fitness = 0.50833) {Similar to Population Cluster 50 (Energy: -105.217326 eV, fitness = 0.536214)}.
#  --> Offspring 58 (Energy: -105.1946830962 eV, fitness = 0.505179) {Similar to Population Cluster 50 (Energy: -105.217326 eV, fitness = 0.536214)}.
#  --> Offspring 54 (Energy: -105.1765954109 eV, fitness = 0.481683) {Similar to Population Cluster 28 (Energy: -105.189173 eV, fitness = 0.497903)}.
#  --> Offspring 63 (Energy: -105.022131274 eV, fitness = 0.320721) {Similar to Population Cluster 32 (Energy: -105.039097 eV, fitness = 0.335373)}.
#  --> Offspring 59 (Energy: -104.9940714337 eV, fitness = 0.297879) {Similar to Population Cluster 29 (Energy: -105.012445 eV, fitness = 0.312645)}.
#  --> Offspring 57 (Energy: -104.873863531 eV, fitness = 0.21706) {Similar to Population Cluster 36 (Energy: -104.875707 eV, fitness = 0.218116)}.
#  --> Offspring 64 (Energy: -104.6374922174 eV, fitness = 0.116488) {Similar to Population Cluster 19 (Energy: -104.647027 eV, fitness = 0.11945)}.
# *****************************
# 4. Offspring that have have been removed for being energetically similar and have a lower energy to the rest of the other Offspring
# 4. Offspring that have have been removed for being energetically similar and have a lower energy to the rest of the other Offspring
#  --> Offspring 61 (Energy: -104.7573879676eV, fitness = 0.15973) {Similar to Offspring 60 (Energy: -104.7596612283 eV, fitness = 0.160689)}.
# **********************************************************
# **********************************************************
# -----------------------------
# ****---------------------****
# Natural Selection for Generation 3
# --------------------------------------------------------------------------
# <Collection: Population> current size: 20
# Cluster: 49; Energy: -105.1351454072; Fitness: 0.43187940700403693
# Cluster: 32; Energy: -105.0390966412; Fitness: 0.33537299047895003
# Cluster: 28; Energy: -105.1891731787; Fitness: 0.49790300018622047
# Cluster: 60; Energy: -104.7596612283; Fitness: 0.16068893853906424
# Cluster: 51; Energy: -104.9210670898; Fitness: 0.24578650615991327
# Cluster: 6; Energy: -104.498163255; Fitness: 0.08071529481066637
# Cluster: 37; Energy: -104.8347457353; Fitness: 0.19581555439074788
# Cluster: 50; Energy: -105.2173256119; Fitness: 0.5362136027008392
# Cluster: 47; Energy: -105.4540161629; Fitness: 1.0
# Cluster: 10; Energy: -105.0783720792; Fitness: 0.3719123756086577
# Cluster: 41; Energy: -104.3862260793; Fitness: 0.06011081131973076
# Cluster: 36; Energy: -104.8757074653; Fitness: 0.2181162661311054
# Cluster: 44; Energy: -104.954028282; Fitness: 0.2680711444915032
# Cluster: 67; Energy: -105.2705827932; Fitness: 0.6169342517712514
# Cluster: 29; Energy: -105.0124452445; Fitness: 0.31264499185292227
# Cluster: 38; Energy: -104.3146615304; Fitness: 0.049787068367863944
# Cluster: 17; Energy: -104.5940329606; Fitness: 0.10389280927314005
# Cluster: 33; Energy: -104.9799949788; Fitness: 0.28704084672023367
# Cluster: 19; Energy: -104.6470272046; Fitness: 0.11944992169795482
# Cluster: 55; Energy: -104.7924997827; Fitness: 0.1752014816455453
# --------------------------------------------------------------------------
#
# --------------------------------------------------------------------------
# <Collection: Offspring> current size: 4
# Cluster: 56; Energy: -104.6736676142; Fitness: 0.12812973045214104
# Cluster: 62; Energy: -104.5369418827; Fitness: 0.08939233213844648
# Cluster: 65; Energy: -104.7291733827; Fitness: 0.1482935594809646
# Cluster: 68; Energy: -104.4434282045; Fitness: 0.06988191498504581
# --------------------------------------------------------------------------
#
# Offspring that replace clusters in population due to fitness.
# Replacing Cluster 38(fitness = 0.049) with Offspring 65(fitness = 0.148)
# Replacing Cluster 41(fitness = 0.06) with Offspring 56(fitness = 0.128)
# Replacing Cluster 6(fitness = 0.08) with Offspring 62(fitness = 0.089)
# ****---------------------****
# <Collection: Population> current size: 20; Clusters: [Cluster_49, Cluster_32, Cluster_28, Cluster_60, Cluster_51, Cluster_62, Cluster_37, Cluster_50, Cluster_47, Cluster_10, Cluster_56, Cluster_36, Cluster_44, Cluster_67, Cluster_29, Cluster_65, Cluster_17, Cluster_33, Cluster_19, Cluster_55]
# Time Information
# fitness_timer_1   = 0.0002372264862060547 seconds
# memory_operator_timer_1   = 1.430511474609375e-05 seconds
# predation_timer_1 = 9.82785940170288 seconds
# fitness_timer_2   = 7.128715515136719e-05 seconds
# ending_timer      = 0.10540056228637695 seconds
# The amount of time required for generation 3 is 15.279818296432495 seconds
# ----------------------------------------------------------
# Time elapsed: 00:01:11
# Date and Time: 2021-02-08 00:20:02.520781
#
#
# ----------------------------------------------------------
# ####################
# RUNNING GENERATION 4
# ####################
# -----------------------
# Making Offspring
# -----------------------
# Time taken to make offspring: 2.6988635063171387 s.
# Details of created offsprings
# Time taken to add offspring to Offspring_Pool: 8.893013000488281e-05 s.
# -----------------------
# **********************************************************
# **********************************************************
# Offspring removed from the Offspring Pool due to violating the Comprehensive Energy Diversity Scheme.
# NOTE: energy difference minimum = 0.025 eV.
# **********************************************************
# **********************************************************
# Assessing which structures to remove to comply with the Energy Diversity Scheme
# Start assessing for Energy Diversity
# Removing offspring that violate the Energy Diversity Scheme
# 1. Clusters in the Population that have been replaced by Offspring, due to the cluster in the offspring being energetically similar and having a lower energy than a offspring.
# 1. Clusters in the Population that have been replaced by Offspring, due to the cluster in the offspring being energetically similar and having a lower energy than a offspring.
#  --> Population Cluster removed 19 (Energy: -104.647027 eV, fitness = 0.098808) {Replaced with Offspring 70 (Energy: -104.648031 eV, fitness = 0.099051)}.
#  --> Population Cluster removed 65 (Energy: -104.729173 eV, fitness = 0.120762) {Replaced with Offspring 71 (Energy: -104.734472 eV, fitness = 0.122335)}.
#  --> Population Cluster removed 67 (Energy: -105.270583 eV, fitness = 0.453148) {Replaced with Offspring 73 (Energy: -105.276688 eV, fitness = 0.459956)}.
#  --> Population Cluster removed 50 (Energy: -105.217326 eV, fitness = 0.397875) {Replaced with Offspring 76 (Energy: -105.228656 eV, fitness = 0.40904)}.
# *****************************
# 2. These offspring have a better energy and are energetically similar to two or more clusters in the population.
# 2. No offspring need to be removed from the offsprings list
# *****************************
# 3. The following offspring were removed from the offspring pool (and because they are energetically similar and have a lower energy to which cluster in the population):
# 3. The following offspring were removed from the offspring pool (and because they are energetically similar and have a lower energy to which cluster in the population):
#  --> Offspring 79 (Energy: -105.4534815395 eV, fitness = 0.708358) {Similar to Population Cluster 47 (Energy: -105.454016 eV, fitness = 0.709284)}.
#  --> Offspring 69 (Energy: -105.1843173026 eV, fitness = 0.367056) {Similar to Population Cluster 28 (Energy: -105.189173 eV, fitness = 0.371435)}.
#  --> Offspring 75 (Energy: -105.1700177636 eV, fitness = 0.354457) {Similar to Population Cluster 28 (Energy: -105.189173 eV, fitness = 0.371435)}.
#  --> Offspring 83 (Energy: -104.9527416207 eV, fitness = 0.20849) {Similar to Population Cluster 44 (Energy: -104.954028 eV, fitness = 0.209146)}.
#  --> Offspring 77 (Energy: -104.8341444354 eV, fitness = 0.156056) {Similar to Population Cluster 37 (Energy: -104.834746 eV, fitness = 0.156285)}.
#  --> Offspring 74 (Energy: -104.8316967755 eV, fitness = 0.155126) {Similar to Population Cluster 37 (Energy: -104.834746 eV, fitness = 0.156285)}.
#  --> Offspring 81 (Energy: -104.8206135054 eV, fitness = 0.150983) {Similar to Population Cluster 37 (Energy: -104.834746 eV, fitness = 0.156285)}.
#  --> Offspring 82 (Energy: -104.6734998431 eV, fitness = 0.105408) {Similar to Population Cluster 56 (Energy: -104.673668 eV, fitness = 0.105451)}.
#  --> Offspring 78 (Energy: -104.657273979 eV, fitness = 0.101312) {Similar to Population Cluster 56 (Energy: -104.673668 eV, fitness = 0.105451)}.
# *****************************
# 4. Offspring that have have been removed for being energetically similar and have a lower energy to the rest of the other Offspring
# 4. No offspring have been removed from the rest of the offsprings list for being too similar
# **********************************************************
# **********************************************************
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-a9c28b2557b0> in <module>
#      25     no_of_cpus=no_of_cpus,
#      26     finish_algorithm_if_found_cluster_energy=finish_algorithm_if_found_cluster_energy,
# ---> 27     total_length_of_running_time=total_length_of_running_time)
#      28 ''' ---------------- '''
#
# ~/Desktop/Organisms/Organisms_v3.2.1/Organisms/GA/GA_Program.py in __init__(self, cluster_makeup, pop_size, generations, no_offspring_per_generation, creating_offspring_mode, crossover_type, mutation_types, chance_of_mutation, r_ij, vacuum_to_add_length, Minimisation_Function, surface_details, epoch_settings, cell_length, memory_operator_information, predation_information, fitness_information, ga_recording_information, force_replace_pop_clusters_with_offspring, user_initialised_population_folder, rounding_criteria, print_details, no_of_cpus, finish_algorithm_if_found_cluster_energy, total_length_of_running_time)
#      88                 GA_Initiate(self)
#      89                 # Run the main component of the GA
# ---> 90                 self.run_GA()
#      91                 ##########################################################################################################
#      92                 ##########################################################################################################
#
# ~/Desktop/Organisms/Organisms_v3.2.1/Organisms/GA/GA_Program.py in run_GA(self)
#     163                         self.ga_recording_system.add_collection(self.offspring_pool, offspring_to_remove_violated_predation_operator)
#     164                         # Remove offspring that violate the predation operator, and replace clusters in the population with offspring to comply with the predation operator.
# --> 165                         self.predation_operator.remove_offspring_and_replace_with_population_that_violate_predation_operator(self.population, self.offspring_pool, offspring_to_remove_violated_predation_operator, population_to_be_replaced_by_offspring)
#     166                         predation_timer_1_end = time()
#     167                         ##############################################################################
#
# ~/Desktop/Organisms/Organisms_v3.2.1/Organisms/GA/Predation_Operators/Predation_Operator.py in remove_offspring_and_replace_with_population_that_violate_predation_operator(self, population, offspring_pool, offspring_to_remove, population_to_be_replaced_by_offspring)
#     128                 self.remove_offspring_that_violate_the_predation_operator(offspring_pool, offspring_to_remove)
#     129                 # Replace clusters in the population with offspring to comply with the predation Operator.
# --> 130                 self.replace_population_with_offspring(population, offspring_pool, population_to_be_replaced_by_offspring)
#     131                 #import pdb; pdb.set_trace()
#     132
#
# ~/Desktop/Organisms/Organisms_v3.2.1/Organisms/GA/Predation_Operators/Predation_Operator.py in replace_population_with_offspring(self, population, offspring_pool, population_to_be_replaced_by_offspring)
#     162                         off_to_swap_in_index = offspring_pool.get_index(offspring_name)
#     163                         offspring = offspring_pool.pop(off_to_swap_in_index)
# --> 164                         population.replace(pop_to_swap_out_index, offspring)
#     165
#
# ~/Desktop/Organisms/Organisms_v3.2.1/Organisms/GA/Collection.py in replace(self, index, new_cluster)
#     302                         new_cluster (Organisms.GA.Cluster): The new cluster to add at the ith position in the Collection
#     303 		"""
# --> 304                 self.remove(index)
#     305                 self.add(index, new_cluster)
#     306
#
# ~/Desktop/Organisms/Organisms_v3.2.1/Organisms/GA/Collection.py in remove(self, index)
#     287                 # remove the cluster in the collection from the disk
#     288                 if self.have_database:
# --> 289                         self.remove_to_database(self.clusters[index])
#     290                 # Deletes the cluster from the Collection
#     291                 if self.write_cluster_in_RAM:
#
# ~/Desktop/Organisms/Organisms_v3.2.1/Organisms/GA/Collection.py in remove_to_database(self, cluster)
#     408                         cluster (Organisms.GA.Cluster): The cluster to remove from the database.
#     409 		"""
# --> 410                 with connect(self.database_path) as database:
#     411                         cluster_id_to_remove = database.get(name=cluster.name).id
#     412                         del database[cluster_id_to_remove]
#
# ~/.local/lib/python3.6/site-packages/ase/db/sqlite.py in __enter__(self)
#     176         assert self.connection is None
#     177         self.change_count = 0
# --> 178         self.connection = self._connect()
#     179         return self
#     180
#
# ~/.local/lib/python3.6/site-packages/ase/db/sqlite.py in _connect(self)
#     171
#     172     def _connect(self):
# --> 173         return sqlite3.connect(self.filename, timeout=20)
#     174
#     175     def __enter__(self):
#
# KeyboardInterrupt:

# %% [markdown]
# [Back To Table of Contents](../Organisms_Jupyter_Example.ipynb)

# %% [markdown]
# ## Post-processing data from your global optimisation
#
# Once the genetic algorithm is finished, we generally would like to get data from it, such as the global minimum. We can get this from the Database that is recorded based on our settings for the ``ga_recording_information`` variable. The following code is a simple way of extracting the lowest energy cluster that was obtained during the genetic algorithm. This is not to be included in the *Run.py* file, this is just so you can see the fruits of your global optimisation work!

# %%
from ase.io import read
database_path = 'Recorded_Data/GA_Recording_Database.db'
lowest_energy_cluster_found = read(database_path)
if isinstance(lowest_energy_cluster_found, list):
    lowest_energy_cluster_found = lowest_energy_cluster_found[0]
lowest_energy_cluster_found.center(about=0.,vacuum=0.0)
from ase.visualize import view
view(lowest_energy_cluster_found,viewer='x3d')

# %%
[Back To Table of Contents](../Organisms_Jupyter_Example.ipynb)
