# %% [markdown]
# # A Basic Example for Optimising a 37 atom Copper Cluster with Organisms

# %% [markdown]
# [Back To Table of Contents](../Organisms_Jupyter_Example.ipynb)

# %% [markdown]
# In this example, we will perform a genetic algorithm optimisation on the 37 atom Lennard-Jones (Cu<sub>37</sub>) cluster. In this example, we will perform a genetic algorithm with a simple energy predation operator, the energy fitness operator, and a population-based epoch method. We will go through step by step all the components of the *Run.py* files required to run Organisms on LJ<sub>38</sub>. See [organisms.readthedocs.io/en/latest/Using_Run](https://organisms.readthedocs.io/en/latest/Using_Run.html) for more information on the *Run.py* file.
#
# To run this notebook step by step, press the $\blacktriangleright$ button sequentially on the python code you want to run. You can find the $\blacktriangleright$ button in the menu bar above. Make sure you have run $\blacktriangleright$ on every cell before running the final cell. Equivalently, press the $\blacktriangleright\blacktriangleright$ button to completely run this *Run.py* file beginning to end. You can also find the $\blacktriangleright\blacktriangleright$ button in the menu bar above.
#
# Note: These are the vanilla settings for running Organisms on a Cu<sub>37</sub> nanocluster, but feel free to change the settings as you wish.
#
# Also note: This program makes files which are created and stored on the Binder server. If you want to rerun this example, you will need to remove these files. The following block code will do this. This is only needed for this notebook and is not apart of *Run.py* script.

# %%
import os
from shutil import rmtree
to_be_removed_before_restarting_Jupyter_example = ['__pycache__','Population','epoch_data','epoch_data.backup','GA_Run_Details.txt','ga_running.lock','Recorded_Data','Initial_Population','Saved_Points_In_GA_Run']
for example_file_or_folder in to_be_removed_before_restarting_Jupyter_example:
    if os.path.exists(example_file_or_folder):
        if os.path.isdir(example_file_or_folder):
            rmtree(example_file_or_folder)
        else:
            os.remove(example_file_or_folder)

# %% [markdown]
# ## Setting up the *Run.py* Script for a Global Optimisation of a 37 atom Copper Nanocluster

# %% [markdown]
# The following contains all the options that you desire to set up the Organisms program to global optimise a Cu<sub>37</sub> nanocluster. These are the vanilla settings, but feel free to change them as you wish.

# %%
from Organisms import GA_Program

# This details the elemental and number of atom composition of cluster that the user would like to investigate
cluster_makeup = {"Cu": 37}

# Surface details
surface_details = None #{'surface': 'surface.xyz', 'place_cluster_where': 'center'}

# These are the main variables of the genetic algorithm that with changes could affect the results of the Genetic Algorithm.
pop_size = 20
generations = 200
no_offspring_per_generation = 16

# These setting indicate how offspring should be made using the Mating and Mutation Proceedures
creating_offspring_mode = "Either_Mating_and_Mutation" 
crossover_type = "CAS_weighted"
mutation_types = [['random', 1.0]]
chance_of_mutation = 0.1

# This parameter will tell the Organisms program if an epoch is desired, and how the user would like to proceed.
epoch_settings = {'epoch mode': 'same population', 'max repeat': 5}

# These are variables used by the algorithm to make and place clusters in.
r_ij = 3.4
cell_length = r_ij * (sum([float(noAtoms) for noAtoms in list(cluster_makeup.values())]) ** (1.0/3.0))
vacuum_to_add_length = 10.0

# The RunMinimisation.py algorithm is one set by the user. It contain the def Minimisation_Function
# That is used for local optimisations. This can be written in whatever way the user wants to perform
# the local optimisations. This is meant to be as free as possible.
from RunMinimisation_Cu import Minimisation_Function

# This dictionary includes the information required to prevent clusters being placed in the population if they are too similar to clusters in this memory_operator
memory_operator_information = {'Method': 'Off'}

# This switch tells the genetic algorithm the type of predation scheme they want to place on the genetic algoithm.
#predation_information = {'Predation Operator':'Off'}
#predation_information = {'Predation Operator':'Energy', 'mode': 'simple', 'round_energy': 2}
#predation_information = {'Predation Operator':'Energy', 'mode': 'comprehensive', 'minimum_energy_diff': 0.025, 'type_of_comprehensive_scheme': 'energy'}
predation_information = {'Predation Operator':'Energy', 'mode': 'comprehensive', 'minimum_energy_diff': 0.025, 'type_of_comprehensive_scheme': 'fitness'}
#predation_information = {'Predation Operator': 'IDCM', 'percentage_diff': 5.0}
#predation_information = {'Predation Operator': 'SCM', 'CNA Scheme': 'T-SCM', 'rCut_high': 3.2, 'rCut_low': 2.9, 'rCut_resolution': 0.05}

# This switch tells the genetic algorithm the type of fitness scheme they want to place on the genetic algoithm.
energy_fitness_function = {'function': 'exponential', 'alpha': 3.0}
#SCM_fitness_function = {'function': 'exponential', 'alpha': 1.0}
fitness_information = {'Fitness Operator': 'Energy', 'fitness_function': energy_fitness_function}
#fitness_information = {'Fitness Operator': 'SCM + Energy', 'Use Predation Information': True, 'SCM_fitness_contribution': 0.5, 'normalise_similarities': False, 'Dynamic Mode': False, 'energy_fitness_function': energy_fitness_function, 'SCM_fitness_function': SCM_fitness_function}
#fitness_information = {'Fitness Operator': 'SCM + Energy', 'CNA Scheme': 'T-SCM', 'rCut_high': 3.2, 'rCut_low': 2.9, 'rCut_resolution': 0.05, 'SCM_fitness_contribution': 0.5, 'normalise_similarities': False, 'Dynamic Mode': False, 'energy_fitness_function': energy_fitness_function, 'SCM_fitness_function': SCM_fitness_function}
#fitness_information = {'Fitness Operator': 'SCM + Energy', 'CNA Scheme': 'T-SCM', 'rCut': 3.05, 'SCM_fitness_contribution': 0.5, 'normalise_similarities': False, 'Dynamic Mode': False, 'energy_fitness_function': energy_fitness_function, 'SCM_fitness_function': SCM_fitness_function}

# Variables required for the Recording_Cluster.py class/For recording the history as required of the genetic algorithm.
ga_recording_information = {}
#ga_recording_information['ga_recording_scheme'] = 'Limit_energy_height' # float('inf')
#ga_recording_information['limit_number_of_clusters_recorded'] = 5 # float('inf')
#ga_recording_information['limit_energy_height_of_clusters_recorded'] = 1.5 #eV
#ga_recording_information['exclude_recording_cluster_screened_by_diversity_scheme'] = True
#ga_recording_information['record_initial_population'] = True
#ga_recording_information['saving_points_of_GA'] = [3,5]
ga_recording_information = {'ga_recording_scheme': 'Limit_energy_height', 'limit_number_of_clusters_recorded': 1, 'limit_energy_height_of_clusters_recorded': 1.0, 'exclude_recording_cluster_screened_by_diversity_scheme': False}

# These are last techinical points that the algorithm is designed in mind
force_replace_pop_clusters_with_offspring = True
user_initialised_population_folder = None 
rounding_criteria = 10
print_details = True
no_of_cpus = 1
finish_algorithm_if_found_cluster_energy = None
total_length_of_running_time = 70.0

# %% [markdown]
# [Back To Table of Contents](../Organisms_Jupyter_Example.ipynb)

# %% [markdown]
# ## The Genetic Algorithm!
#
# You have got to the end of all the parameter setting stuff! Now on to the fun stuff! The next part of the Run.py file tells the genetic algorithm to run. This is written as follows in the Run.py. Note this may take a bit of time to run depending on your settings. Running the below code and good and get yourself a tea or coffee.

# %%
''' ---------------- '''
# This will execute the genetic algorithm program
GA_Program(cluster_makeup=cluster_makeup,
    pop_size=pop_size,
    generations=generations,
    no_offspring_per_generation=no_offspring_per_generation,
    creating_offspring_mode=creating_offspring_mode,
    crossover_type=crossover_type,
    mutation_types=mutation_types,
    chance_of_mutation=chance_of_mutation,
    r_ij=r_ij,
    vacuum_to_add_length=vacuum_to_add_length,
    Minimisation_Function=Minimisation_Function,
    surface_details=surface_details,
    epoch_settings=epoch_settings,
    cell_length=cell_length,
    memory_operator_information=memory_operator_information,
    predation_information=predation_information,
    fitness_information=fitness_information,
    ga_recording_information=ga_recording_information,
    force_replace_pop_clusters_with_offspring=force_replace_pop_clusters_with_offspring,
    user_initialised_population_folder=user_initialised_population_folder,
    rounding_criteria=rounding_criteria,
    print_details=print_details,
    no_of_cpus=no_of_cpus,
    finish_algorithm_if_found_cluster_energy=finish_algorithm_if_found_cluster_energy,
    total_length_of_running_time=total_length_of_running_time)
''' ---------------- '''
# Out:
# ############################################################
# ############################################################
# ############################################################
# The Garden Group Genetic Algorithm for Clusters
#
# .--------------------------------------------------------------------------.
# |                             ,                                            |
# |              ,_     ,     .'<_                                           |
# |             _> `'-,'(__.-' __<                                           |
# |             >_.--(.. )  =;`                                   _          |
# |                  `V-'`'\/``                                  ('>         |
# |                                                              /))@@@@@.   |
# |         .----------------------------------.                /@"@@@@@()@  |
# |         | Welcome to the Organisms program |               .@@()@@()@@@@ |
# |         '----------------------------------'               @@@O@@@@()@@@ |
# |                  ^                                         @()@@\@@@()@@ |
# |  _     (\_/)     |                                          @()@||@@@@@' |
# | ( \    (0.o) ----'                 _                         '@@||@@@'   |
# |  ) )   (> <)                     _(_)_            wWWWw   _     ||       |
# | ( (  .-'''''-.  A.-.A      @@@@ (_)@(_)       _   (___) _(_)_   ||       |
# |  \ \/         \/ , , \    @@()@@  (_)\      _(_)_   Y  (_)@(_)  ||       |
# |   \   \        ;= t =/     @@@@      `|/   (_)@(_) \|/   (_)\   ||       |
# |    \   |'''''-   ,--'       /        \|     /(_)    |/      |   ||       |
# |     / //     | ||        \ |          | / \|/      \|      \|/  ||       |
# |    /_,))     |_'))       \\|//     \\\|// \|///   \\|//  \\\|// ||       |
# |^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^|
# '--------------------------------------------------------------------------'
#
# Version: 3.2.1
# ############################################################
# ############################################################
#
# This algorithm is designed to perform a genetic algorithm to obtain low energetic structures for a given cluster composition.
#
# This genetic algorithm will proceed with the following input parameters
#
# # This details the elemental and number of atom composition of cluster that the user would like to investigate
# cluster_makeup = {'Cu': 37}
#
# # This details the information used to perform a global optimisation upon a chosen surface
# surface_details = None
#
# # These are the main variables of the genetic algorithm that with changes could affect the results of the Genetic Algorithm.
# pop_size = 20
# generations = 200
# no_offspring_per_generation = 16
#
# # These setting indicate how offspring should be made using the Mating and Mutation Proceedures
# creating_offspring_mode = Either_Mating_and_Mutation
# crossover_type = CAS_weighted
# mutation_types = [['random', 1.0]]
# mutation_types = 0.1
#
# # These are variables used by the algorithm to make and place clusters in.
# r_ij = 3.4 Angstroms (This is the maximum possible bond length between two atoms in the cluster)
# cell_length = 11.329554295596239 Angstroms
# vacuum_to_add_length = 10.0 Angstroms
#
# # The RunMinimisation.py algorithm is one set by the user. It contain the def Minimisation_Function
# # That is used for local optimisations. This can be written in whatever way the user wants to perform
# # the local optimisations. This is meant to be as free as possible.
# Minimisation_Function = <function Minimisation_Function at 0x7f2e1450db70>
# Path of Minimisation_Function: /mnt/hgfs/GoogleDrive/PhDWork/Programs/OptimisationAlgorithms/GeneticAlgorithm/Organisms/Organisms_Jupyter_Examples/Notebooks/Example_of_Cu37/RunMinimisation_Cu.py
#
# # This details the information about the memory operator used in this genetic algorithm.
# memory_operator = {'method': 'Off'}
#
# # This details the information about the predation operator used in this genetic algorithm.
# predation_operator = {'predation_information': {'Predation Operator': 'Energy', 'mode': 'comprehensive', 'minimum_energy_diff': 0.025, 'type_of_comprehensive_scheme': 'fitness'}, 'Predation_Switch': 'Energy', 'population': <Collection: Population> current size: 0; Clusters: [], 'print_details': False, 'mode': 'comprehensive', 'type_of_comprehensive_scheme': 'fitness', 'minimum_energy_diff': 0.025, 'check_initial_population_imported': <function check_initial_population at 0x7f2de0838730>, 'assess_for_violations_force_replacement_imported': <function assess_for_violations_force_replacement at 0x7f2de08389d8>, 'assess_for_violations_no_force_replacement_imported': <function assess_for_violations_no_force_replacement at 0x7f2de0838950>}
#
# # This details the information about the fitness operator used in this genetic algorithm.
# fitness_operator = {'fitness_switch': 'Energy', 'fitness_information': {'Fitness Operator': 'Energy', 'fitness_function': {'function': 'exponential', 'alpha': 3.0}, 'Use Predation Information': False}, 'population': <Collection: Population> current size: 0; Clusters: [], 'print_details': False, 'previous_max_energy': -inf, 'previous_min_energy': inf, 'energy_fitness_function': <Organisms.GA.Fitness_Operators.Fitness_Function.Fitness_Function object at 0x7f2e144d7be0>}
#
# # This parameter will tell the Organisms program if an epoch is desired, and how the user would like to proceed.
# epoch_settings: {'path': '/mnt/hgfs/GoogleDrive/PhDWork/Programs/OptimisationAlgorithms/GeneticAlgorithm/Organisms/Organisms_Jupyter_Examples/Notebooks/Example_of_Cu37', 'epoch_data_name': 'epoch_data', 'backup_epoch_data_name': 'epoch_data.backup', 'epoch_settings': {'epoch mode': 'same population', 'max repeat': 5}, 'epoch_mode': 'same population', 'max_number_of_times_non_changing_population': 5, 'epoch_function': <bound method Epoch.should_epoch_using_same_population_epoch of {...}>, 'perform_epoch_function': <bound method Epoch.perform_epoch_same_population of {...}>, 'first_epoch_to_change_fitness_function': False}
#
# # Variables required for the GA_Recording_System.py class/For recording the history as required of the genetic algorithm.
# ga_recording_system = {'ga_recording_information': {'ga_recording_scheme': 'Limit_energy_height', 'limit_number_of_clusters_recorded': 1, 'limit_energy_height_of_clusters_recorded': 1.0, 'exclude_recording_cluster_screened_by_diversity_scheme': False}, 'ga_recording_scheme': 'Limit_energy_height', 'ga_recording_system_name': 'Recorded_Data', 'path_to_write_to': '/mnt/hgfs/GoogleDrive/PhDWork/Programs/OptimisationAlgorithms/GeneticAlgorithm/Organisms/Organisms_Jupyter_Examples/Notebooks/Example_of_Cu37/Recorded_Data', 'exclude_recording_cluster_screened_by_diversity_scheme': False, 'limit_number_of_clusters_recorded': 1, 'limit_size_of_database': None, 'show_GA_Recording_Database_check_percentage': False, 'limit_energy_height_of_clusters_recorded': 1.0, 'clusters_database': <Collection: GA_Recording_Database> current size: 0; Clusters: [], 'directory': '/mnt/hgfs/GoogleDrive/PhDWork/Programs/OptimisationAlgorithms/GeneticAlgorithm/Organisms/Organisms_Jupyter_Examples/Notebooks/Example_of_Cu37/Recorded_Data', 'RC_Information_TXT_name': 'Recorded_Data_Information.txt', 'record_initial_population': False, 'saving_points_of_GA': []}
#
# # These are last techinical points that the algorithm is designed in mind
# force_replace_pop_clusters_with_offspring = True
# user_initialised_population_folder = None
# rounding_criteria = 10
# print_details = True
# no_of_cpus = 1
# finish_algorithm_if_found_cluster_energy = None
# total_length_of_running_time: 70.0 hours
#
# ############################################################
# ############################################################
# ############################################################
# ################################################################################################################
# ################################################################################################################
# Initalising a Starting Population of Clusters if required to take pool up to a size of 20
# Pool size to begin = 0
# Checking to see if the user has any clusters in the folder None that the user would like to have inputted into the initalise population.
# ################################################################################################################
# Will now population the next 20 with randomly generated clusters.
# -----------------------------
# Checking that the clusters in the population satisfies the Diversity Scheme
# *****************************
# *****************************
# Diversity Scheme located "duplicates" in creating population.
# Recreating clusters: [4, 9, 12, 16]
# -----------------------------
# Checking that the clusters in the population satisfies the Diversity Scheme
# *****************************
# *****************************
# Diversity Scheme located "duplicates" in creating population.
# Recreating clusters: [10]
# -----------------------------
# Checking that the clusters in the population satisfies the Diversity Scheme
# Have finished populating the rest of the population with 0 randomly generated clusters.
# The population has been successfully initalised.
# ################################################################################################################
# ################################################################################################################
# Time elapsed: 00:00:12
# Date and Time: 2021-02-08 00:21:15.863496
# -----------------------------
# -----------------------------
# Starting Genetic Algorithm
# -----------------------------
# -----------------------------
#
#
#
# ----------------------------------------------------------
# ####################
# RUNNING GENERATION 1
# ####################
# -----------------------
# Making Offspring
# -----------------------
# Time taken to make offspring: 1.488325834274292 s.
# Details of created offsprings
# Time taken to add offspring to Offspring_Pool: 3.600120544433594e-05 s.
# -----------------------
# **********************************************************
# **********************************************************
# Offspring removed from the Offspring Pool due to violating the Comprehensive Energy Diversity Scheme.
# NOTE: energy difference minimum = 0.025 eV.
# **********************************************************
# **********************************************************
# Assessing which structures to remove to comply with the Energy Diversity Scheme
# Start assessing for Energy Diversity
# Removing offspring that violate the Energy Diversity Scheme
# 1. Clusters in the Population that have been replaced by Offspring, due to the cluster in the offspring being energetically similar and having a lower energy than a offspring.
# 1. Clusters in the Population that have been replaced by Offspring, due to the cluster in the offspring being energetically similar and having a lower energy than a offspring.
#  --> Population Cluster removed 18 (Energy: -104.653311 eV, fitness = 0.614247) {Replaced with Offspring 24 (Energy: -104.656837 eV, fitness = 0.615995)}.
#  --> Population Cluster removed 8 (Energy: -105.072518 eV, fitness = 0.861018) {Replaced with Offspring 26 (Energy: -105.074309 eV, fitness = 0.862262)}.
# *****************************
# 2. These offspring have a better energy and are energetically similar to two or more clusters in the population.
# 2. No offspring need to be removed from the offsprings list
# *****************************
# 3. The following offspring were removed from the offspring pool (and because they are energetically similar and have a lower energy to which cluster in the population):
# 3. No offspring need to be removed from the offsprings list
# *****************************
# 4. Offspring that have have been removed for being energetically similar and have a lower energy to the rest of the other Offspring
# 4. Offspring that have have been removed for being energetically similar and have a lower energy to the rest of the other Offspring
#  --> Offspring 28 (Energy: -105.0584672286eV, fitness = 0.851327) {Similar to Offspring 26 (Energy: -105.0743087276 eV, fitness = 0.862262)}.
#  --> Offspring 30 (Energy: -105.0433762632eV, fitness = 0.84104) {Similar to Offspring 35 (Energy: -105.0475549111 eV, fitness = 0.843876)}.
#  --> Offspring 29 (Energy: -104.8805888427eV, fitness = 0.737669) {Similar to Offspring 21 (Energy: -104.8898388415 eV, fitness = 0.743187)}.
#  --> Offspring 27 (Energy: -104.865177101eV, fitness = 0.728567) {Similar to Offspring 21 (Energy: -104.8898388415 eV, fitness = 0.743187)}.
#  --> Offspring 25 (Energy: -104.7168185072eV, fitness = 0.646491) {Similar to Offspring 36 (Energy: -104.7413564416 eV, fitness = 0.659399)}.
# **********************************************************
# **********************************************************
# -----------------------------
# ****---------------------****
# Natural Selection for Generation 1
# --------------------------------------------------------------------------
# <Collection: Population> current size: 20
# Cluster:
# --------------------------------------------------------------------------
#
# --------------------------------------------------------------------------
# <Collection: Offspring> current size: 7
# Cluster: 37; Energy: -104.1958841875; Fitness: 0.08686826304355137
# Cluster: 38; Energy: -104.6984494443; Fitness: 0.22357323793961661
# Cluster: 40; Energy: -104.6001981345; Fitness: 0.18584708626766364
# Cluster: 41; Energy: -104.8510307629; Fitness: 0.297897925744449
# Cluster: 43; Energy: -105.365156185; Fitness: 0.7835558527940475
# Cluster: 48; Energy: -105.4948252458; Fitness: 1.0
# Cluster: 50; Energy: -104.0527435861; Fitness: 0.06636297448051134
# --------------------------------------------------------------------------
#
# Offspring that replace clusters in population due to fitness.
# Replacing Cluster 10(fitness = 0.049) with Offspring 48(fitness = 1.0)
# Replacing Cluster 5(fitness = 0.056) with Offspring 43(fitness = 0.783)
# Replacing Cluster 15(fitness = 0.081) with Offspring 41(fitness = 0.297)
# Replacing Cluster 6(fitness = 0.096) with Offspring 38(fitness = 0.223)
# Replacing Cluster 20(fitness = 0.103) with Offspring 40(fitness = 0.185)
# ****---------------------****
# <Collection: Population> current size: 20; Clusters: [Cluster_1, Cluster_23, Cluster_31, Cluster_22, Cluster_43, Cluster_38, Cluster_32, Cluster_52, Cluster_42, Cluster_48, Cluster_36, Cluster_34, Cluster_21, Cluster_14, Cluster_41, Cluster_35, Cluster_45, Cluster_24, Cluster_19, Cluster_40]
# Time Information
# fitness_timer_1   = 0.00016641616821289062 seconds
# memory_operator_timer_1   = 1.430511474609375e-05 seconds
# predation_timer_1 = 3.750035285949707 seconds
# fitness_timer_2   = 0.00011205673217773438 seconds
# ending_timer      = 0.026476383209228516 seconds
# The amount of time required for generation 2 is 6.590140104293823 seconds
# ----------------------------------------------------------
# Time elapsed: 00:00:25
# Date and Time: 2021-02-08 00:21:28.880992
#
#
# ----------------------------------------------------------
# ####################
# RUNNING GENERATION 3
# ####################
# -----------------------
# Making Offspring
# -----------------------
# Time taken to make offspring: 1.8510956764221191 s.
# Details of created offsprings
# Time taken to add offspring to Offspring_Pool: 0.00030541419982910156 s.
# -----------------------
# **********************************************************
# **********************************************************
# Offspring removed from the Offspring Pool due to violating the Comprehensive Energy Diversity Scheme.
# NOTE: energy difference minimum = 0.025 eV.
# **********************************************************
# **********************************************************
# Assessing which structures to remove to comply with the Energy Diversity Scheme
# Start assessing for Energy Diversity
# Removing offspring that violate the Energy Diversity Scheme
# 1. Clusters in the Population that have been replaced by Offspring, due to the cluster in the offspring being energetically similar and having a lower energy than a offspring.
# 1. Clusters in the Population that have been replaced by Offspring, due to the cluster in the offspring being energetically similar and having a lower energy than a offspring.
#  --> Population Cluster removed 21 (Energy: -104.889839 eV, fitness = 0.459095) {Replaced with Offspring 54 (Energy: -104.905398 eV, fitness = 0.46838)}.
#  --> Population Cluster removed 42 (Energy: -104.508642 eV, fitness = 0.281106) {Replaced with Offspring 59 (Energy: -104.52432 eV, fitness = 0.286835)}.
#  --> Population Cluster removed 40 (Energy: -104.600198 eV, fitness = 0.316255) {Replaced with Offspring 61 (Energy: -104.601096 eV, fitness = 0.31662)}.
#  --> Population Cluster removed 43 (Energy: -105.365156 eV, fitness = 0.846319) {Replaced with Offspring 62 (Energy: -105.380664 eV, fitness = 0.863378)}.
#  --> Population Cluster removed 52 (Energy: -105.092684 eV, fitness = 0.596023) {Replaced with Offspring 63 (Energy: -105.104141 eV, fitness = 0.604875)}.
# *****************************
# 2. These offspring have a better energy and are energetically similar to two or more clusters in the population.
# 2. No offspring need to be removed from the offsprings list
# *****************************
# 3. The following offspring were removed from the offspring pool (and because they are energetically similar and have a lower energy to which cluster in the population):
# 3. The following offspring were removed from the offspring pool (and because they are energetically similar and have a lower energy to which cluster in the population):
#  --> Offspring 57 (Energy: -105.2428401115 eV, fitness = 0.723066) {Similar to Population Cluster 34 (Energy: -105.258264 eV, fitness = 0.73756)}.
#  --> Offspring 66 (Energy: -104.9597201041 eV, fitness = 0.502292) {Similar to Population Cluster 1 (Energy: -104.962446 eV, fitness = 0.504056)}.
#  --> Offspring 55 (Energy: -104.9464360319 eV, fitness = 0.493779) {Similar to Population Cluster 1 (Energy: -104.962446 eV, fitness = 0.504056)}.
#  --> Offspring 64 (Energy: -104.8403025565 eV, fitness = 0.430744) {Similar to Population Cluster 41 (Energy: -104.851031 eV, fitness = 0.436732)}.
#  --> Offspring 67 (Energy: -104.7191185783 eV, fitness = 0.368549) {Similar to Population Cluster 36 (Energy: -104.741356 eV, fitness = 0.379248)}.
#  --> Offspring 65 (Energy: -104.6805537857 eV, fitness = 0.350706) {Similar to Population Cluster 38 (Energy: -104.698449 eV, fitness = 0.358876)}.
# *****************************
# 4. Offspring that have have been removed for being energetically similar and have a lower energy to the rest of the other Offspring
# 4. Offspring that have have been removed for being energetically similar and have a lower energy to the rest of the other Offspring
#  --> Offspring
# --------------------------------------------------------------------------
#
# --------------------------------------------------------------------------
# <Collection: Offspring> current size: 4
# Cluster: 70; Energy: -105.285140875; Fitness: 0.5527546981449648
# Cluster: 72; Energy: -104.8194643896; Fitness: 0.14845181660967655
# Cluster: 80; Energy: -105.432010904; Fitness: 0.8367655440422984
# Cluster: 81; Energy: -105.353836166; Fitness: 0.6710531729170638
# --------------------------------------------------------------------------
#
# Offspring that replace clusters in population due to fitness.
# Replacing Cluster 68(fitness = 0.049) with Offspring 80(fitness = 0.836)
# Replacing Cluster 59(fitness = 0.064) with Offspring 81(fitness = 0.671)
# Replacing Cluster 19(fitness = 0.074) with Offspring 70(fitness = 0.552)
# Replacing Cluster 61(fitness = 0.08) with Offspring 72(fitness = 0.148)
# ****---------------------****
# <Collection: Population> current size: 20; Clusters: [Cluster_69, Cluster_23, Cluster_31, Cluster_56, Cluster_62, Cluster_38, Cluster_32, Cluster_63, Cluster_81, Cluster_79, Cluster_36, Cluster_34, Cluster_75, Cluster_80, Cluster_41, Cluster_35, Cluster_82, Cluster_77, Cluster_70, Cluster_72]
# Time Information
# fitness_timer_1   = 0.000152587890625 seconds
# memory_operator_timer_1   = 1.4781951904296875e-05 seconds
# predation_timer_1 = 3.7327616214752197 seconds
# fitness_timer_2   = 6.961822509765625e-05 seconds
# ending_timer      = 0.04217672348022461 seconds
# The amount of time required for generation 4 is 6.209992170333862 seconds
# ----------------------------------------------------------
# Time elapsed: 00:00:37
# Date and Time: 2021-02-08 00:21:41.302222
#
#
# ----------------------------------------------------------
# ####################
# RUNNING GENERATION 5
# ####################
# -----------------------
# Making Offspring
# -----------------------
# Time taken to make offspring: 1.4486868381500244 s.
# Details of created offsprings
# Time taken to add offspring to Offspring_Pool: 0.00017976760864257812 s.
# -----------------------
# **********************************************************
# **********************************************************
# Offspring removed from the Offspring Pool due to violating the Comprehensive Energy Diversity Scheme.
# NOTE: energy difference minimum = 0.025 eV.
# **********************************************************
# **********************************************************
# Assessing which structures to remove to comply with the Energy Diversity Scheme
# Start assessing for Energy Diversity
# Removing offspring that violate the Energy Diversity Scheme
# 1. Clusters in the Population that have been replaced by Offspring, due to the cluster in the offspring being energetically similar and having a lower energy than a offspring.
# 1. Clusters in the Population that have been replaced by Offspring, due to the cluster in the offspring being energetically similar and having a lower energy than a offspring.
#  --> Population Cluster removed 63 (Energy: -105.104141 eV, fitness = 0.611015) {Replaced with Offspring 89 (Energy: -105.106044 eV, fitness = 0.612481)}.
#  --> Population Cluster removed 82 (Energy: -105.014685 eV, fitness = 0.545886) {Replaced with Offspring 92 (Energy: -105.024451 eV, fitness = 0.552645)}.
#  --> Population Cluster removed 80 (Energy: -105.432011 eV, fitness = 0.923545) {Replaced with Offspring 93 (Energy: -105.432827 eV, fitness = 0.924495)}.
#  --> Population Cluster removed 75 (Energy: -104.92684 eV, fitness = 0.488691) {Replaced with Offspring 96 (Energy: -104.939847 eV, fitness = 0.496766)}.
#  --> Population Cluster removed 35 (Energy: -105.047555 eV, fitness = 0.568968) {Replaced with Offspring 97 (Energy: -105.0512 eV, fitness = 0.571587)}.
# *****************************
# 2. These offspring have a better energy and are energetically similar to two or more clusters in the population.
# 2. No offspring need to be removed from the offsprings list
# *****************************
# 3. The following offspring were removed from the offspring pool (and because they are energetically similar and have a lower energy to which cluster in the population):
# 3. The following offspring were removed from the offspring pool (and because they are energetically similar and have a lower energy to which cluster in the population):
#  --> Offspring 90 (Energy: -105.3119545648 eV, fitness = 0.793898) {Similar to Population Cluster 56 (Energy: -105.316509 eV, fitness = 0.798466)}.
#  --> Offspring 87 (Energy: -104.8326164241 eV, fitness = 0.433987) {Similar to Population Cluster 41 (Energy: -104.851031 eV, fitness = 0.444173)}.
#  --> Offspring 94 (Energy: -104.8189276439 eV, fitness = 0.426566) {Similar to Population Cluster 72 (Energy: -104.819464 eV, fitness = 0.426854)}.
#  --> Offspring 91 (Energy: -104.7633923866 eV, fitness = 0.397738) {Similar to Population Cluster 31 (Energy: -104.766678 eV, fitness = 0.399388)}.
#  --> Offspring 88 (Energy: -104.7631403147 eV, fitness = 0.397612) {Similar to Population Cluster 31 (Energy: -104.766678 eV, fitness = 0.399388)}.
# *****************************
# 4. Offspring that have have been removed for being energetically similar and have a lower energy to the rest of the other Offspring
# 4. Offspring that have have been removed for being energetically similar and have a lower energy to the rest of the other Offspring
#  --> Offspring 98 (Energy: -104.9381413206eV, fitness = 0.495699) {Similar to Offspring 96 (Energy: -104.9398469344 eV, fitness = 0.496766)}.
#  --> Offspring 100 (Energy: -104.9198552851eV, fitness = 0.484409) {Similar to Offspring 96 (Energy: -104.9398469344 eV, fitness = 0.496766)}.
# **********************************************************
# **********************************************************
# -----------------------------
# ****---------------------****
# Natural Selection for Generation 5
# --------------------------------------------------------------------------
# <Collection: Population> current size: 20
# Cluster:
}.
# *****************************
# 2. These offspring have a better energy and are energetically similar to two or more clusters in the population.
# 2. No offspring need to be removed from the offsprings list
# *****************************
# 3. The following offspring were removed from the offspring pool (and because they are energetically similar and have a lower energy to which cluster in the population):
# 3. The following offspring were removed from the offspring pool (and because they are energetically similar and have a lower energy to which cluster in the population):
#  --> Offspring 101 (Energy: -105.1006799148 eV, fitness = 0.384933) {Similar to Population Cluster 89 (Energy: -105.106044 eV, fitness = 0.389955)}.
#  --> Offspring 113 (Energy: -105.0041651698 eV, fitness = 0.304845) {Similar to Population Cluster 92 (Energy: -105.024451 eV, fitness = 0.320164)}.
#  --> Offspring 112 (Energy: -105.0040919414 eV, fitness = 0.304791) {Similar to Population Cluster 92 (Energy: -105.024451 eV, fitness = 0.320164)}.
#  --> Offspring 108 (Energy: -104.848803824 eV, fitness = 0.209415) {Similar to Population Cluster 41 (Energy: -104.851031 eV, fitness = 0.210545)}.
# ...
#
# --------------------------------------------------------------------------
# <Collection: Offspring> current size: 7
# Cluster: 3195; Energy: -103.4182202786; Fitness: 0.09462373278521856
# Cluster: 3196; Energy: -104.018161721; Fitness: 0.18108540722933628
# Cluster: 3199; Energy: -104.940991165; Fitness: 0.49144649141067387
# Cluster: 3201; Energy: -103.127900872; Fitness: 0.06911830384532477
# Cluster: 3204; Energy: -104.4383065595; Fitness: 0.2852916957451408
# Cluster: 3206; Energy: -104.7726194971; Fitness: 0.40960623671580926
# Cluster: 3208; Energy: -102.8246635251; Fitness: 0.049787068367863944
# --------------------------------------------------------------------------
#
# Offspring that replace clusters in population due to fitness.
# ****---------------------****
# <Collection: Population> current size: 20; Clusters: [Cluster_3190, Cluster_3182, Cluster_3123, Cluster_3194, Cluster_3197, Cluster_3138, Cluster_3139, Cluster_2734, Cluster_3200, Cluster_3104, Cluster_2838, Cluster_3096, Cluster_2800, Cluster_2690, Cluster_3207, Cluster_2947, Cluster_2867, Cluster_2668, Cluster_3205, Cluster_2784]
# Time Information
# fitness_timer_1   = 0.00015592575073242188 seconds
# memory_operator_timer_1   = 1.1682510375976562e-05 seconds
# predation_timer_1 = 3.1695895195007324 seconds
# fitness_timer_2   = 0.0001266002655029297 seconds
# ending_timer      = 0.022480249404907227 seconds
# The amount of time required for generation 198 is 4.9020421504974365 seconds
# ----------------------------------------------------------
# Time elapsed: 00:16:17
# Date and Time: 2021-02-08 00:37:21.120072
#
#
# ----------------------------------------------------------
# ######################
# RUNNING GENERATION 199
# ######################
# -----------------------
# Making Offspring
# -----------------------
# Time taken to make offspring: 1.1977996826171875 s.
# Details of created offsprings
# Time taken to add offspring to Offspring_Pool: 6.413459777832031e-05 s.
# -----------------------
# **********************************************************
# **********************************************************
# Offspring removed from the Offspring Pool due to violating the Comprehensive Energy Diversity Scheme.
# NOTE: energy difference minimum = 0.025 eV.
# **********************************************************
# **********************************************************
# Assessing which structures to remove to comply with the Energy Diversity Scheme
# Start assessing for Energy Diversity
# Removing offspring that violate the Energy Diversity Scheme
# 1. Clusters in the Population that have been replaced by Offspring, due to the cluster in the offspring being energetically similar and having a lower energy than a offspring.
# 1. Clusters in the Population that have been replaced by Offspring, due to the cluster in the offspring being energetically similar and having a lower energy than a offspring.
#  --> Population Cluster removed 2800 (Energy: -105.364747 eV, fitness = 0.674928) {Replaced with Offspring 3209 (Energy: -105.365195 eV, fitness = 0.675439)}.
#  --> Population Cluster removed 3190 (Energy: -105.281637 eV, fitness = 0.586577) {Replaced with Offspring 3215 (Energy: -105.284553 eV, fitness = 0.589471)}.
# *****************************
# 2. These offspring have a better energy and are energetically similar to two or more clusters in the population.
# 2. No offspring need to be removed from the offsprings list
# *****************************
# 3. The following offspring were removed from the offspring pool (and because they are energetically similar and have a lower energy to which cluster in the population):
# 3. The following offspring were removed from the offspring pool (and because they are energetically similar and have a lower energy to which cluster in the population):
#  --> Offspring 3216 (Energy: -105.5974709178 eV, fitness = 0.999728) {Similar to Population Cluster 3182 (Energy: -105.597632 eV, fitness = 1.0)}.
#  --> Offspring 3221 (Energy: -105.5957898976 eV, fitness = 0.996895) {Similar to Population Cluster 3182 (Energy: -105.597632 eV, fitness = 1.0)}.
#  --> Offspring 3213 (Energy: -105.453297332 eV, fitness = 0.783753) {Similar to Population Cluster 2867 (Energy: -105.454411 eV, fitness = 0.785228)}.
#  --> Offspring 3223 (Energy: -105.383404191 eV, fitness = 0.696524) {Similar to Population Cluster 2690 (Energy: -105.400736 eV, fitness = 0.717205)}.
#  --> Offspring 3217 (Energy: -105.3376650424 eV, fitness = 0.644766) {Similar to Population Cluster 3138 (Energy: -105.338351 eV, fitness = 0.645513)}.
#  --> Offspring 3224 (Energy: -105.2979715187 eV, fitness = 0.602976) {Similar to Population Cluster 3194 (Energy: -105.310171 eV, fitness = 0.615524)}.
#  --> Offspring 3218 (Energy: -105.1168304545 eV, fitness = 0.444114) {Similar to Population Cluster 3205 (Energy: -105.119468 eV, fitness = 0.446096)}.
# *****************************
# 4. Offspring that have have been removed for being energetically similar and have a lower energy to the rest of the other Offspring
# 4
# --------------------------------------------------------------------------
#
# --------------------------------------------------------------------------
# <Collection: Offspring> current size: 6
# Cluster: 3232; Energy: -104.5412519367; Fitness: 0.19620321876221092
# Cluster: 3234; Energy: -104.1124128537; Fitness: 0.10129293693599865
# Cluster: 3236; Energy: -104.6585424433; Fitness: 0.23509174134464175
# Cluster: 3237; Energy: -104.9422010131; Fitness: 0.36404869967890896
# Cluster: 3239; Energy: -103.6517078734; Fitness: 0.049787068367863944
# Cluster: 3240; Energy: -104.4884254741; Fitness: 0.18085746788626383
# --------------------------------------------------------------------------
#
# Offspring that replace clusters in population due to fitness.
# ****---------------------****
# <Collection: Population> current size: 20; Clusters: [Cluster_3215, Cluster_3182, Cluster_3123, Cluster_3194, Cluster_3197, Cluster_3138, Cluster_3139, Cluster_2734, Cluster_3200, Cluster_3104, Cluster_2838, Cluster_3229, Cluster_3209, Cluster_2690, Cluster_3207, Cluster_2947, Cluster_2867, Cluster_2668, Cluster_3205, Cluster_3228]
# Time Information
# fitness_timer_1   = 0.000171661376953125 seconds
# memory_operator_timer_1   = 1.3589859008789062e-05 seconds
# predation_timer_1 = 3.7739505767822266 seconds
# fitness_timer_2   = 0.0002071857452392578 seconds
# ending_timer      = 0.05642867088317871 seconds
# The amount of time required for generation 200 is 6.943605422973633 seconds
# ----------------------------------------------------------
# Time elapsed: 00:16:28
# Date and Time: 2021-02-08 00:37:32.048497
# ----------------------------------------------------------
# ----------------------------------------------------------
# The maximum generation set by the user has been reached! The genetic algorithm process has completed!
# The Algorithm will finish now.
# ----------------------------------------------------------
# Time elapsed: 00:16:28
# Date and Time: 2021-02-08 00:37:32.050689
# ----------------------------------------------------------
# Finishing the Garden Group Genetic Algorithm Successfully.
# ----------------------------------------------------------
# ----------------------------------------------------------
# ' ---------------- '

# %% [markdown]
# [Back To Table of Contents](../Organisms_Jupyter_Example.ipynb)

# %% [markdown]
# ## Post-processing data from your global optimisation
#
# Once the genetic algorithm is finished, we generally would like to get data from it, such as the global minimum. We can get this from the Database that is recorded based on our settings for the ``ga_recording_information`` variable. The following code is a simple way of extracting the lowest energy cluster that was obtained during the genetic algorithm. This is not to be included in the *Run.py* file, this is just so you can see the fruits of your global optimisation work!

# %%
from ase.io import read
database_path = 'Recorded_Data/GA_Recording_Database.db'
lowest_energy_cluster_found = read(database_path)
if isinstance(lowest_energy_cluster_found, list):
    lowest_energy_cluster_found = lowest_energy_cluster_found[0]
lowest_energy_cluster_found.center(about=0.,vacuum=0.0)
from ase.visualize import view
view(lowest_energy_cluster_found,viewer='x3d')
# Out:
# <html>
#
#  <head>
#
#   <title>ASE atomic visualization</title>
#
#   <link rel="stylesheet" type="text/css"
#
#    href="https://www.x3dom.org/x3dom/release/x3dom.css">
#
#   </link>
#
#   <script type="text/javascript"
#
#    src="https://www.x3dom.org/x3dom/release/x3dom.js">
#
#   </script>
#
#  </head>
#
#  <body>
#
#   <X3D>
#
#    <Scene>
#
#     <Transform translation="-0.17 -0.22 4.28">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-2.38 0.31 3.46">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="0.95 -1.96 3.03">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.29 1.96 3.01">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="1.73 0.37 2.68">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-1.59 -2.06 2.68">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.58 -0.10 1.84">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-2.49 2.05 1.70">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.51 3.87 1.50">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="2.66 -1.60 1.19">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="1.53 2.41 1.23">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="3.48 0.78 0.91">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-2.99 -0.41 1.17">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="0.27 -2.19 0.75">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="1.21 0.11 0.24">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.64 1.74 0.23">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-2.14 -2.67 0.25">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-2.13 3.65 -0.29">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-1.20 -0.55 -0.51">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="2.24 -3.12 -0.82">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.21 -3.87 -0.89">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="0.48 3.56 -0.84">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-2.86 1.30 -0.77">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="3.08 -0.64 -1.16">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="2.40 1.85 -1.10">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-3.48 -1.11 -1.23">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="0.75 -1.47 -1.60">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="1.22 2.85 -3.07">
#
#      <Shape>

# %% [markdown]
# [Back To Table of Contents](../Organisms_Jupyter_Example.ipynb)
