# %% [markdown]
# # A Basic Example for Optimising a 37 atom Copper Cluster with Organisms

# %% [markdown]
# [Back To Table of Contents](../Organisms_Jupyter_Example.ipynb)

# %% [markdown]
# In this example, we will perform a genetic algorithm optimisation on the 37 atom Lennard-Jones (Cu<sub>37</sub>) cluster. In this example, we will perform a genetic algorithm with a simple energy predation operator, the energy fitness operator, and a population-based epoch method. We will go through step by step all the components of the *Run.py* files required to run Organisms on LJ<sub>38</sub>. See [organisms.readthedocs.io/en/latest/Using_Run](https://organisms.readthedocs.io/en/latest/Using_Run.html) for more information on the *Run.py* file.
#
# To run this notebook step by step, press the $\blacktriangleright$ button sequentially on the python code you want to run. You can find the $\blacktriangleright$ button in the menu bar above. Make sure you have run $\blacktriangleright$ on every cell before running the final cell. Equivalently, press the $\blacktriangleright\blacktriangleright$ button to completely run this *Run.py* file beginning to end. You can also find the $\blacktriangleright\blacktriangleright$ button in the menu bar above.
#
# Note: These are the vanilla settings for running Organisms on a Cu<sub>37</sub> nanocluster, but feel free to change the settings as you wish.
#
# Also note: This program makes files which are created and stored on the Binder server. If you want to rerun this example, you will need to remove these files. The following block code will do this. This is only needed for this notebook and is not apart of *Run.py* script.

# %%
import os
from shutil import rmtree
to_be_removed_before_restarting_Jupyter_example = ['__pycache__','Population','epoch_data','epoch_data.backup','GA_Run_Details.txt','ga_running.lock','Recorded_Data','Initial_Population','Saved_Points_In_GA_Run']
for example_file_or_folder in to_be_removed_before_restarting_Jupyter_example:
    if os.path.exists(example_file_or_folder):
        if os.path.isdir(example_file_or_folder):
            rmtree(example_file_or_folder)
        else:
            os.remove(example_file_or_folder)

# %% [markdown]
# ## Setting up the *Run.py* Script for a Global Optimisation of a 37 atom Copper Nanocluster

# %% [markdown]
# The following contains all the options that you desire to set up the Organisms program to global optimise a Cu<sub>37</sub> nanocluster. These are the vanilla settings, but feel free to change them as you wish.

# %%
from Organisms import GA_Program

# This details the elemental and number of atom composition of cluster that the user would like to investigate
cluster_makeup = {"Cu": 37}

# Surface details
surface_details = None #{'surface': 'surface.xyz', 'place_cluster_where': 'center'}

# These are the main variables of the genetic algorithm that with changes could affect the results of the Genetic Algorithm.
pop_size = 20
generations = 30
no_offspring_per_generation = 16

# These setting indicate how offspring should be made using the Mating and Mutation Proceedures
creating_offspring_mode = "Either_Mating_and_Mutation" 
crossover_type = "CAS_weighted"
mutation_types = [['random', 1.0]]
chance_of_mutation = 0.1

# This parameter will tell the Organisms program if an epoch is desired, and how the user would like to proceed.
epoch_settings = {'epoch mode': 'same population', 'max repeat': 5}

# These are variables used by the algorithm to make and place clusters in.
r_ij = 3.4
cell_length = r_ij * (sum([float(noAtoms) for noAtoms in list(cluster_makeup.values())]) ** (1.0/3.0))
vacuum_to_add_length = 10.0

# The RunMinimisation.py algorithm is one set by the user. It contain the def Minimisation_Function
# That is used for local optimisations. This can be written in whatever way the user wants to perform
# the local optimisations. This is meant to be as free as possible.
from RunMinimisation_Cu import Minimisation_Function

# This dictionary includes the information required to prevent clusters being placed in the population if they are too similar to clusters in this memory_operator
memory_operator_information = {'Method': 'Off'}

# This switch tells the genetic algorithm the type of predation scheme they want to place on the genetic algoithm.
#predation_information = {'Predation Operator':'Off'}
#predation_information = {'Predation Operator':'Energy', 'mode': 'simple', 'round_energy': 2}
#predation_information = {'Predation Operator':'Energy', 'mode': 'comprehensive', 'minimum_energy_diff': 0.025, 'type_of_comprehensive_scheme': 'energy'}
predation_information = {'Predation Operator':'Energy', 'mode': 'comprehensive', 'minimum_energy_diff': 0.025, 'type_of_comprehensive_scheme': 'fitness'}
#predation_information = {'Predation Operator': 'IDCM', 'percentage_diff': 5.0}
#predation_information = {'Predation Operator': 'SCM', 'CNA Scheme': 'T-SCM', 'rCut_high': 3.2, 'rCut_low': 2.9, 'rCut_resolution': 0.05}

# This switch tells the genetic algorithm the type of fitness scheme they want to place on the genetic algoithm.
energy_fitness_function = {'function': 'exponential', 'alpha': 3.0}
#SCM_fitness_function = {'function': 'exponential', 'alpha': 1.0}
fitness_information = {'Fitness Operator': 'Energy', 'fitness_function': energy_fitness_function}
#fitness_information = {'Fitness Operator': 'SCM + Energy', 'Use Predation Information': True, 'SCM_fitness_contribution': 0.5, 'normalise_similarities': False, 'Dynamic Mode': False, 'energy_fitness_function': energy_fitness_function, 'SCM_fitness_function': SCM_fitness_function}
#fitness_information = {'Fitness Operator': 'SCM + Energy', 'CNA Scheme': 'T-SCM', 'rCut_high': 3.2, 'rCut_low': 2.9, 'rCut_resolution': 0.05, 'SCM_fitness_contribution': 0.5, 'normalise_similarities': False, 'Dynamic Mode': False, 'energy_fitness_function': energy_fitness_function, 'SCM_fitness_function': SCM_fitness_function}
#fitness_information = {'Fitness Operator': 'SCM + Energy', 'CNA Scheme': 'T-SCM', 'rCut': 3.05, 'SCM_fitness_contribution': 0.5, 'normalise_similarities': False, 'Dynamic Mode': False, 'energy_fitness_function': energy_fitness_function, 'SCM_fitness_function': SCM_fitness_function}

# Variables required for the Recording_Cluster.py class/For recording the history as required of the genetic algorithm.
ga_recording_information = {}
#ga_recording_information['ga_recording_scheme'] = 'Limit_energy_height' # float('inf')
#ga_recording_information['limit_number_of_clusters_recorded'] = 5 # float('inf')
#ga_recording_information['limit_energy_height_of_clusters_recorded'] = 1.5 #eV
#ga_recording_information['exclude_recording_cluster_screened_by_diversity_scheme'] = True
#ga_recording_information['record_initial_population'] = True
#ga_recording_information['saving_points_of_GA'] = [3,5]
ga_recording_information = {'ga_recording_scheme': 'Limit_energy_height', 'limit_number_of_clusters_recorded': 1, 'limit_energy_height_of_clusters_recorded': 1.0, 'exclude_recording_cluster_screened_by_diversity_scheme': False}

# These are last techinical points that the algorithm is designed in mind
force_replace_pop_clusters_with_offspring = True
user_initialised_population_folder = None 
rounding_criteria = 10
print_details = True
no_of_cpus = 1
finish_algorithm_if_found_cluster_energy = None
total_length_of_running_time = 70.0

# %% [markdown]
# [Back To Table of Contents](../Organisms_Jupyter_Example.ipynb)

# %% [markdown]
# ## The Genetic Algorithm!
#
# You have got to the end of all the parameter setting stuff! Now on to the fun stuff! The next part of the Run.py file tells the genetic algorithm to run. This is written as follows in the Run.py. Note this may take a bit of time to run depending on your settings. Running the below code and good and get yourself a tea or coffee.

# %%
''' ---------------- '''
# This will execute the genetic algorithm program
GA_Program(cluster_makeup=cluster_makeup,
    pop_size=pop_size,
    generations=generations,
    no_offspring_per_generation=no_offspring_per_generation,
    creating_offspring_mode=creating_offspring_mode,
    crossover_type=crossover_type,
    mutation_types=mutation_types,
    chance_of_mutation=chance_of_mutation,
    r_ij=r_ij,
    vacuum_to_add_length=vacuum_to_add_length,
    Minimisation_Function=Minimisation_Function,
    surface_details=surface_details,
    epoch_settings=epoch_settings,
    cell_length=cell_length,
    memory_operator_information=memory_operator_information,
    predation_information=predation_information,
    fitness_information=fitness_information,
    ga_recording_information=ga_recording_information,
    force_replace_pop_clusters_with_offspring=force_replace_pop_clusters_with_offspring,
    user_initialised_population_folder=user_initialised_population_folder,
    rounding_criteria=rounding_criteria,
    print_details=print_details,
    no_of_cpus=no_of_cpus,
    finish_algorithm_if_found_cluster_energy=finish_algorithm_if_found_cluster_energy,
    total_length_of_running_time=total_length_of_running_time)
''' ---------------- '''
# Out:
# ############################################################
# ############################################################
# ############################################################
# The Garden Group Genetic Algorithm for Clusters
#
# .--------------------------------------------------------------------------.
# |                             ,                                            |
# |              ,_     ,     .'<_                                           |
# |             _> `'-,'(__.-' __<                                           |
# |             >_.--(.. )  =;`                                   _          |
# |                  `V-'`'\/``                                  ('>         |
# |                                                              /))@@@@@.   |
# |         .----------------------------------.                /@"@@@@@()@  |
# |         | Welcome to the Organisms program |               .@@()@@()@@@@ |
# |         '----------------------------------'               @@@O@@@@()@@@ |
# |                  ^                                         @()@@\@@@()@@ |
# |  _     (\_/)     |                                          @()@||@@@@@' |
# | ( \    (0.o) ----'                 _                         '@@||@@@'   |
# |  ) )   (> <)                     _(_)_            wWWWw   _     ||       |
# | ( (  .-'''''-.  A.-.A      @@@@ (_)@(_)       _   (___) _(_)_   ||       |
# |  \ \/         \/ , , \    @@()@@  (_)\      _(_)_   Y  (_)@(_)  ||       |
# |   \   \        ;= t =/     @@@@      `|/   (_)@(_) \|/   (_)\   ||       |
# |    \   |'''''-   ,--'       /        \|     /(_)    |/      |   ||       |
# |     / //     | ||        \ |          | / \|/      \|      \|/  ||       |
# |    /_,))     |_'))       \\|//     \\\|// \|///   \\|//  \\\|// ||       |
# |^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^|
# '--------------------------------------------------------------------------'
#
# Version: 3.2.1
# ############################################################
# ############################################################
#
# This algorithm is designed to perform a genetic algorithm to obtain low energetic structures for a given cluster composition.
#
# This genetic algorithm will proceed with the following input parameters
#
# # This details the elemental and number of atom composition of cluster that the user would like to investigate
# cluster_makeup = {'Cu': 37}
#
# # This details the information used to perform a global optimisation upon a chosen surface
# surface_details = None
#
# # These are the main variables of the genetic algorithm that with changes could affect the results of the Genetic Algorithm.
# pop_size = 20
# generations = 30
# no_offspring_per_generation = 16
#
# # These setting indicate how offspring should be made using the Mating and Mutation Proceedures
# creating_offspring_mode = Either_Mating_and_Mutation
# crossover_type = CAS_weighted
# mutation_types = [['random', 1.0]]
# mutation_types = 0.1
#
# # These are variables used by the algorithm to make and place clusters in.
# r_ij = 3.4 Angstroms (This is the maximum possible bond length between two atoms in the cluster)
# cell_length = 11.329554295596239 Angstroms
# vacuum_to_add_length = 10.0 Angstroms
#
# # The RunMinimisation.py algorithm is one set by the user. It contain the def Minimisation_Function
# # That is used for local optimisations. This can be written in whatever way the user wants to perform
# # the local optimisations. This is meant to be as free as possible.
# Minimisation_Function = <function Minimisation_Function at 0x7faccc231f28>
# Path of Minimisation_Function: /mnt/hgfs/GoogleDrive/PhDWork/Programs/OptimisationAlgorithms/GeneticAlgorithm/Organisms/Organisms_Jupyter_Examples/Notebooks/Example_of_Cu37/RunMinimisation_Cu.py
#
# # This details the information about the memory operator used in this genetic algorithm.
# memory_operator = {'method': 'Off'}
#
# # This details the information about the predation operator used in this genetic algorithm.
# predation_operator = {'predation_information': {'Predation Operator': 'Energy', 'mode': 'comprehensive', 'minimum_energy_diff': 0.025, 'type_of_comprehensive_scheme': 'fitness'}, 'Predation_Switch': 'Energy', 'population': <Collection: Population> current size: 0; Clusters: [], 'print_details': False, 'mode': 'comprehensive', 'type_of_comprehensive_scheme': 'fitness', 'minimum_energy_diff': 0.025, 'check_initial_population_imported': <function check_initial_population at 0x7fac98d766a8>, 'assess_for_violations_force_replacement_imported': <function assess_for_violations_force_replacement at 0x7fac98d809d8>, 'assess_for_violations_no_force_replacement_imported': <function assess_for_violations_no_force_replacement at 0x7fac98d80950>}
#
# # This details the information about the fitness operator used in this genetic algorithm.
# fitness_operator = {'fitness_switch': 'Energy', 'fitness_information': {'Fitness Operator': 'Energy', 'fitness_function': {'function': 'exponential', 'alpha': 3.0}, 'Use Predation Information': False}, 'population': <Collection: Population> current size: 0; Clusters: [], 'print_details': False, 'previous_max_energy': -inf, 'previous_min_energy': inf, 'energy_fitness_function': <Organisms.GA.Fitness_Operators.Fitness_Function.Fitness_Function object at 0x7faccc1fac88>}
#
# # This parameter will tell the Organisms program if an epoch is desired, and how the user would like to proceed.
# epoch_settings: {'path': '/mnt/hgfs/GoogleDrive/PhDWork/Programs/OptimisationAlgorithms/GeneticAlgorithm/Organisms/Organisms_Jupyter_Examples/Notebooks/Example_of_Cu37', 'epoch_data_name': 'epoch_data', 'backup_epoch_data_name': 'epoch_data.backup', 'epoch_settings': {'epoch mode': 'same population', 'max repeat': 5}, 'epoch_mode': 'same population', 'max_number_of_times_non_changing_population': 5, 'epoch_function': <bound method Epoch.should_epoch_using_same_population_epoch of {...}>, 'perform_epoch_function': <bound method Epoch.perform_epoch_same_population of {...}>, 'first_epoch_to_change_fitness_function': False}
#
# # Variables required for the GA_Recording_System.py class/For recording the history as required of the genetic algorithm.
# ga_recording_system = {'ga_recording_information': {'ga_recording_scheme': 'Limit_energy_height', 'limit_number_of_clusters_recorded': 1, 'limit_energy_height_of_clusters_recorded': 1.0, 'exclude_recording_cluster_screened_by_diversity_scheme': False}, 'ga_recording_scheme': 'Limit_energy_height', 'ga_recording_system_name': 'Recorded_Data', 'path_to_write_to': '/mnt/hgfs/GoogleDrive/PhDWork/Programs/OptimisationAlgorithms/GeneticAlgorithm/Organisms/Organisms_Jupyter_Examples/Notebooks/Example_of_Cu37/Recorded_Data', 'exclude_recording_cluster_screened_by_diversity_scheme': False, 'limit_number_of_clusters_recorded': 1, 'limit_size_of_database': None, 'show_GA_Recording_Database_check_percentage': False, 'limit_energy_height_of_clusters_recorded': 1.0, 'clusters_database': <Collection: GA_Recording_Database> current size: 0; Clusters: [], 'directory': '/mnt/hgfs/GoogleDrive/PhDWork/Programs/OptimisationAlgorithms/GeneticAlgorithm/Organisms/Organisms_Jupyter_Examples/Notebooks/Example_of_Cu37/Recorded_Data', 'RC_Information_TXT_name': 'Recorded_Data_Information.txt', 'record_initial_population': False, 'saving_points_of_GA': []}
#
# # These are last techinical points that the algorithm is designed in mind
# force_replace_pop_clusters_with_offspring = True
# user_initialised_population_folder = None
# rounding_criteria = 10
# print_details = True
# no_of_cpus = 1
# finish_algorithm_if_found_cluster_energy = None
# total_length_of_running_time: 70.0 hours
#
# ############################################################
# ############################################################
# ############################################################
# ################################################################################################################
# ################################################################################################################
# Initalising a Starting Population of Clusters if required to take pool up to a size of 20
# Pool size to begin = 0
# Checking to see if the user has any clusters in the folder None that the user would like to have inputted into the initalise population.
# ################################################################################################################
# Will now population the next 20 with randomly generated clusters.
# -----------------------------
# Checking that the clusters in the population satisfies the Diversity Scheme
# *****************************
# *****************************
# Diversity Scheme located "duplicates" in creating population.
# Recreating clusters: [6, 16]
# -----------------------------
# Checking that the clusters in the population satisfies the Diversity Scheme
# *****************************
# *****************************
# Diversity Scheme located "duplicates" in creating population.
# Recreating clusters: [16]
# -----------------------------
# Checking that the clusters in the population satisfies the Diversity Scheme
# Have finished populating the rest of the population with 0 randomly generated clusters.
# The population has been successfully initalised.
# ################################################################################################################
# ################################################################################################################
# Time elapsed: 00:00:07
# Date and Time: 2021-02-08 03:20:40.141682
# -----------------------------
# -----------------------------
# Starting Genetic Algorithm
# -----------------------------
# -----------------------------
#
#
#
# ----------------------------------------------------------
# ####################
# RUNNING GENERATION 1
# ####################
# -----------------------
# Making Offspring
# -----------------------
# Time taken to make offspring: 1.2919723987579346 s.
# Details of created offsprings
# Time taken to add offspring to Offspring_Pool: 0.0063130855560302734 s.
# -----------------------
# **********************************************************
# **********************************************************
# Offspring removed from the Offspring Pool due to violating the Comprehensive Energy Diversity Scheme.
# NOTE: energy difference minimum = 0.025 eV.
# **********************************************************
# **********************************************************
# Assessing which structures to remove to comply with the Energy Diversity Scheme
# Start assessing for Energy Diversity
# Removing offspring that violate the Energy Diversity Scheme
# 1. Clusters in the Population that have been replaced by Offspring, due to the cluster in the offspring being energetically similar and having a lower energy than a offspring.
# 1. Clusters in the Population that have been replaced by Offspring, due to the cluster in the offspring being energetically similar and having a lower energy than a offspring.
#  --> Population Cluster removed 20 (Energy: -104.750257 eV, fitness = 0.656367) {Replaced with Offspring 22 (Energy: -104.759773 eV, fitness = 0.664192)}.
#  --> Population Cluster removed 18 (Energy: -104.080476 eV, fitness = 0.285048) {Replaced with Offspring 29 (Energy: -104.089072 eV, fitness = 0.288116)}.
#  --> Population Cluster removed 7 (Energy: -105.083945 eV, fitness = 0.994515) {Replaced with Offspring 35 (Energy: -105.088362 eV, fitness = 1.0)}.
# *****************************
# 2. These offspring have a better energy and are energetically similar to two or more clusters in the population.
# 2. No offspring need to be removed from the offsprings list
# *****************************
# 3. The following offspring were removed from the offspring pool (and because they are energetically similar and have a lower energy to which cluster in the population):
# 3. The following offspring were removed from the offspring pool (and because they are energetically similar and have a lower energy to which cluster in the population):
#  --> Offspring 26 (Energy: -104.6022103651 eV, fitness = 0.545859) {Similar to Population Cluster 5 (Energy: -104.603831 eV, fitness = 0.546962)}.
#  --> Offspring 24 (Energy: -103.6805894714 eV, fitness = 0.173242) {Similar to Population Cluster 15 (Energy: -103.690231 eV, fitness = 0.175334)}.
#  --> Offspring 28 (Energy: -103.6109155858 eV, fitness = 0.158844) {Similar to Population Cluster 2 (Energy: -103.632971 eV, fitness = 0.163267)}.
# *****************************
# 4. Offspring that have have been removed for being energetically similar and have a lower energy to the rest of the other Offspring
# 4. Offspring that have have been removed for being energetically similar and have a lower energy to the rest of the other Offspring
#  --> Offspring 23 (Energy: -105.0873901829eV, fitness = 0.998791) {Similar to Offspring 35 (Energy: -105.0883618415 eV, fitness = 1.0)}.
#  --> Offspring 32 (Energy: -104.7237726692eV, fitness = 0.635073) {Similar to Offspring 31 (Energy: -104.7249756149 eV, fitness = 0.636025)}.
#  --> Offspring 33 (Energy: -104.7161177986eV, fitness = 0.629048) {Similar to Offspring 31 (Energy: -104.7249756149 eV, fitness = 0.636025)}.
#  --> Offspring 36 (Energy: -104.6751725663eV, fitness = 0.597778) {Similar to Offspring 30 (Energy: -104.6978578998 eV, fitness = 0.614906)}.
# **********************************************************
# **********************************************************
# -----------------------------
# ****---------------------****
# Natural Selection for Generation 1
# --------------------------------------------------------------------------
# <Collection: Population> current size: 20
# Cluster: 1; Energy: -103.5638271845; Fitness: 0.14979773323013218
# Cluster: 2; Energy: -103.6329709058; Fitness: 0.16326735765896092
# Cluster: 3; Energy: -103.2389139749; Fitness: 0.09995086293532618
# Cluster: 4; Energy: -103.5209070178; Fitness: 0.14200161109360107
# Cluster: 5; Energy: -104.6038307661; Fitness: 0.5469620553373852
# Cluster: 6; Energy: -104.5571546461; Fitness: 0.5160763346569619
# Cluster: 35; Energy: -105.0883618415; Fitness: 1.0
# Cluster: 8; Energy: -102.8709408127; Fitness: 0.06320919886001193
# Cluster: 9; Energy: -103.1223652328; Fitness: 0.08644800370385294
# Cluster: 10; Energy: -104.2123617334; Fitness: 0.3359262662737684
# Cluster: 11; Energy: -103.3741008029; Fitness: 0.11827635360074744
# Cluster: 12; Energy: -104.1847130319; Fitness: 0.32455706404204876
# Cluster: 13; Energy: -104.2802192802; Fitness: 0.36554639056537513
# Cluster: 14; Energy: -102.6792610598; Fitness: 0.049787068367863944
# Cluster: 15; Energy: -103.6902314529; Fitness: 0.17533429044641877
# Cluster: 16; Energy: -103.4705327905; Fitness: 0.13336750198436997
# Cluster: 17; Energy: -104.5267146524; Fitness: 0.4968799452259693
# Cluster: 29; Energy: -104.0890721857; Fitness: 0.2881156434472304
# Cluster: 19; Energy: -103.0935867282; Fitness: 0.0834048018397187
# Cluster: 22; Energy: -104.7597733744; Fitness: 0.6641920353772339
# --------------------------------------------------------------------------
#
# --------------------------------------------------------------------------
# <Collection: Offspring> current size: 6
# Cluster: 21; Energy: -104.4916771224; Fitness: 0.47566649869873184
# Cluster: 25; Energy: -104.9343853835; Fitness: 0.8255186011566683
# Cluster: 27; Energy: -104.4182415761; Fitness: 0.4340975644244184
# Cluster: 30; Energy: -104.6978578998; Fitness: 0.6149059593037355
# Cluster: 31; Energy: -104.7249756149; Fitness: 0.6360253596124793
# Cluster: 34; Energy: -104.6578871929; Fitness: 0.5850484742928471
# --------------------------------------------------------------------------
#
# Offspring that replace clusters in population due to fitness.
# Replacing Cluster 14(fitness = 0.049) with Offspring 25(fitness = 0.825)
# Replacing Cluster 8(fitness = 0.063) with Offspring 31(fitness = 0.636)
# Replacing Cluster 19(fitness = 0.083) with Offspring 30(fitness = 0.614)
# Replacing Cluster 9(fitness = 0.086) with Offspring 34(fitness = 0.585)
# Replacing Cluster 3(fitness = 0.099) with Offspring 21(fitness = 0.475)
# Replacing Cluster 11(fitness = 0.118) with Offspring 27(fitness = 0.434)
# ****---------------------****
# <Collection: Population> current size: 20; Clusters: [Cluster_1, Cluster_2, Cluster_21, Cluster_4, Cluster_5, Cluster_6, Cluster_35, Cluster_31, Cluster_34, Cluster_10, Cluster_27, Cluster_12, Cluster_13, Cluster_25, Cluster_15, Cluster_16, Cluster_17, Cluster_29, Cluster_30, Cluster_22]
# Time Information
# fitness_timer_1   = 0.0001595020294189453 seconds
# memory_operator_timer_1   = 1.1205673217773438e-05 seconds
# predation_timer_1 = 2.6569418907165527 seconds
# fitness_timer_2   = 0.00015091896057128906 seconds
# ending_timer      = 0.06608700752258301 seconds
# The amount of time required for generation 1 is 5.159561634063721 seconds
# ----------------------------------------------------------
# Time elapsed: 00:00
# --------------------------------------------------------------------------
#
# --------------------------------------------------------------------------
# <Collection: Offspring> current size: 7
# Cluster: 40; Energy: -103.9629551388; Fitness: 0.10879879379918134
# Cluster: 42; Energy: -103.9263262749; Fitness: 0.10265256230754488
# Cluster: 43; Energy: -104.8656655829; Fitness: 0.45604795800229725
# Cluster: 44; Energy: -105.1534745707; Fitness: 0.7201856727619367
# Cluster: 47; Energy: -104.4599857936; Fitness: 0.2395018479520856
# Cluster: 48; Energy: -105.3602373662; Fitness: 1.0
# Cluster: 52; Energy: -105.2623266033; Fitness: 0.856039973617498
# --------------------------------------------------------------------------
#
# Offspring that replace clusters in population due to fitness.
# Replacing Cluster 16(fitness = 0.049) with Offspring 48(fitness = 1.0)
# Replacing Cluster 4(fitness = 0.053) with Offspring 52(fitness = 0.856)
# Replacing Cluster 1(fitness = 0.057) with Offspring 44(fitness = 0.72)
# Replacing Cluster 2(fitness = 0.064) with Offspring 43(fitness = 0.456)
# Replacing Cluster 15(fitness = 0.07) with Offspring 47(fitness = 0.239)
# ****---------------------****
# <Collection: Population> current size: 20; Clusters: [Cluster_44, Cluster_43, Cluster_21, Cluster_52, Cluster_5, Cluster_6, Cluster_41, Cluster_45, Cluster_50, Cluster_10, Cluster_27, Cluster_12, Cluster_13, Cluster_38, Cluster_47, Cluster_48, Cluster_17, Cluster_29, Cluster_30, Cluster_22]
# Time Information
# fitness_timer_1   = 0.0001964569091796875 seconds
# memory_operator_timer_1   = 1.3113021850585938e-05 seconds
# predation_timer_1 = 2.509697437286377 seconds
# fitness_timer_2   = 7.462501525878906e-05 seconds
# ending_timer      = 0.02346491813659668 seconds
# The amount of time required for generation 2 is 4.6616904735565186 seconds
# ----------------------------------------------------------
# Time elapsed: 00:00:17
# Date and Time: 2021-02-08 03:20:50.033652
#
#
# ----------------------------------------------------------
# ####################
# RUNNING GENERATION 3
# ####################
# -----------------------
# Making Offspring
# -----------------------
# Time taken to make offspring: 1.3568575382232666 s.
# Details of created offsprings
# Time taken to add offspring to Offspring_Pool: 3.409385681152344e-05 s.
# -----------------------
# **********************************************************
# **********************************************************
# Offspring removed from the Offspring Pool due to violating the Comprehensive Energy Diversity Scheme.
# NOTE: energy difference minimum = 0.025 eV.
# **********************************************************
# **********************************************************
# Assessing which structures to remove to comply with the Energy Diversity Scheme
# Start assessing for Energy Diversity
# Removing offspring that violate the Energy Diversity Scheme
# 1. Clusters in the Population that have been replaced by Offspring, due to the cluster in the offspring being energetically similar and having a lower energy than a offspring.
# 1. Clusters in the Population that have been replaced by Offspring, due to the cluster in the offspring being energetically similar and having a lower energy than a offspring.
#  --> Population Cluster removed 43 (Energy: -104.865666 eV, fitness = 0.492661) {Replaced with Offspring 59 (Energy: -104.876198 eV, fitness = 0.500145)}.
#  --> Population Cluster removed 52 (Energy: -105.262327 eV, fitness = 0.869228) {Replaced with Offspring 62 (Energy: -105.262704 eV, fitness = 0.869698)}.
# *****************************
# 2. These offspring have a better energy and are energetically similar to two or more clusters in the population.
# 2. No offspring need to be removed from the offsprings list
# *****************************
# 3. The following offspring were removed from the offspring pool (and because they are energetically similar and have a lower energy to which cluster in the population):
# 3. The following offspring were removed from the offspring pool (and because they are energetically similar and have a lower energy to which cluster in the population):
#  --> Offspring 54 (Energy: -104.7386483354 eV, fitness = 0.41076) {Similar to Population Cluster 22 (Energy: -104.759773 eV, fitness = 0.42337)}.
#  --> Offspring 67 (Energy: -104.7385998382 eV, fitness = 0.410731) {Similar to Population Cluster 22 (Energy: -104.759773 eV, fitness = 0.42337)}.
#  --> Offspring 65 (Energy: -104.7361768637 eV, fitness = 0.409309) {Similar to Population Cluster 22 (Energy: -104.759773 eV, fitness = 0.42337)}.
#  --> Offspring 56 (Energy: -104.5917618598 eV, fitness = 0.332871) {Similar to Population Cluster 5 (Energy: -104.603831 eV, fitness = 0.338671)}.
#  --> Offspring 57 (Energy: -104.5796418751 eV, fitness = 0.327146) {Similar to Population Cluster 5 (Energy: -104.603831 eV, fitness = 0.338671)}.
# *****************************
# 4. Offspring that have have been removed for being energetically similar and have a lower energy to the rest of the other Offspring
# 4. Offspring that have have been removed for being energetically similar and have a lower energy to the rest of the other Offspring
#  --> Offspring 53 (Energy: -105.2910989238eV, fitness = 0.905774) {Similar to Offspring 55 (Energy: -105.301911348 eV, fitness = 0.919902)}.
#  --> Offspring 61 (Energy: -105.1877281554eV, fitness = 0.781195) {Similar to Offspring 58 (Energy: -105.1881512228 eV, fitness = 0.781668)}.
# **********************************************************
# **********************************************************
# -----------------------------
# ****---------------------****
# Natural Selection for Generation 3
# --------------------------------------------------------------------------
# <Collection: Population> current size: 20
# Cluster:
# --------------------------------------------------------------------------
#
# --------------------------------------------------------------------------
# <Collection: Offspring> current size: 3
# Cluster: 73; Energy: -105.2247479592; Fitness: 0.44499421498820935
# Cluster: 79; Energy: -105.5962663332; Fitness: 1.0
# Cluster: 82; Energy: -104.2197523338; Fitness: 0.049787068367863944
# --------------------------------------------------------------------------
#
# Offspring that replace clusters in population due to fitness.
# Replacing Cluster 21(fitness = 0.09) with Offspring 79(fitness = 1.0)
# Replacing Cluster 17(fitness = 0.097) with Offspring 73(fitness = 0.444)
# ****---------------------****
# <Collection: Population> current size: 20; Clusters: [Cluster_44, Cluster_59, Cluster_79, Cluster_62, Cluster_5, Cluster_81, Cluster_74, Cluster_75, Cluster_69, Cluster_60, Cluster_68, Cluster_58, Cluster_63, Cluster_38, Cluster_66, Cluster_84, Cluster_73, Cluster_55, Cluster_30, Cluster_78]
# Time Information
# fitness_timer_1   = 0.0001933574676513672 seconds
# memory_operator_timer_1   = 9.5367431640625e-06 seconds
# predation_timer_1 = 2.857344150543213 seconds
# fitness_timer_2   = 9.584426879882812e-05 seconds
# ending_timer      = 0.019912004470825195 seconds
# The amount of time required for generation 4 is 4.687470197677612 seconds
# ----------------------------------------------------------
# Time elapsed: 00:00:27
# Date and Time: 2021-02-08 03:20:59.423913
#
#
# ----------------------------------------------------------
# ####################
# RUNNING GENERATION 5
# ####################
# -----------------------
# Making Offspring
# -----------------------
# Time taken to make offspring: 1.6111459732055664 s.
# Details of created offsprings
# Time taken to add offspring to Offspring_Pool: 0.0007278919219970703 s.
# -----------------------
# **********************************************************
# **********************************************************
# Offspring removed from the Offspring Pool due to violating the Comprehensive Energy Diversity Scheme.
# NOTE: energy difference minimum = 0.025 eV.
# **********************************************************
# **********************************************************
# Assessing which structures to remove to comply with the Energy Diversity Scheme
# Start assessing for Energy Diversity
# Removing offspring that violate the Energy Diversity Scheme
# 1. Clusters in the Population that have been replaced by Offspring, due to the cluster in the offspring being energetically similar and having a lower energy than a offspring.
# 1. Clusters in the Population that have been replaced by Offspring, due to the cluster in the offspring being energetically similar and having a lower energy than a offspring.
#  --> Population Cluster removed 84 (Energy: -105.360353 eV, fitness = 0.652383) {Replaced with Offspring 87 (Energy: -105.383601 eV, fitness = 0.680429)}.
#  --> Population Cluster removed 66 (Energy: -104.837457 eV, fitness = 0.253136) {Replaced with Offspring 90 (Energy: -104.849394 eV, fitness = 0.258667)}.
#  --> Population Cluster removed 78 (Energy: -104.782105 eV, fitness = 0.228998) {Replaced with Offspring 94 (Energy: -104.801512 eV, fitness = 0.237187)}.
#  --> Population Cluster removed 44 (Energy: -105.153475 eV, fitness = 0.448576) {Replaced with Offspring 96 (Energy: -105.157361 eV, fitness = 0.451744)}.
# *****************************
# 2. These offspring have a better energy and are energetically similar to two or more clusters in the population.
# 2. No offspring need to be removed from the offsprings list
# *****************************
# 3. The following offspring were removed from the offspring pool (and because they are energetically similar and have a lower energy to which cluster in the population):
# 3. The following offspring were removed from the offspring pool (and because they are energetically similar and have a lower energy to which cluster in the population):
#  --> Offspring 99 (Energy: -105.1002544428 eV, fitness = 0.407371) {Similar to Population Cluster 74 (Energy: -105.100551 eV, fitness = 0.407589)}.
#  --> Offspring 98 (Energy: -104.9373003148 eV, fitness = 0.303291) {Similar to Population Cluster 38 (Energy: -104.958592 eV, fitness = 0.315211)}.
#  --> Offspring 93 (Energy: -104.9170364347 eV, fitness = 0.292366) {Similar to Population Cluster 68 (Energy: -104.91882 eV, fitness = 0.293312)}.
#  --> Offspring 100 (Energy: -104.9080179581 eV, fitness = 0.287631) {Similar to Population Cluster 68 (Energy: -104.91882 eV, fitness = 0.293312)}.
#  --> Offspring 86 (Energy: -104.8694483504 eV, fitness = 0.268231) {Similar to Population Cluster 59 (Energy: -104.876198 eV, fitness = 0.271529)}.
# *****************************
# 4. Offspring that have have been removed for being energetically similar and have a lower energy to the rest of the other Offspring
# 4. Offspring that have have been removed for being energetically similar and have a lower energy to the rest of the other Offspring
#  --> Offspring 97 (Energy: -105.1039226824eV, fitness = 0.410085) {Similar to Offspring 95 (Energy: -105.1272885306 eV, fitness = 0.427806)}.
#  --> Offspring 89 (Energy: -104.8463180252eV, fitness = 0.25723) {Similar to Offspring 90 (Energy: -104.8493942039 eV, fitness = 0.258667)}.
# **********************************************************
# **********************************************************
# -----------------------------
# ****---------------------****
# Natural Selection for Generation
s.
# -----------------------
# **********************************************************
# **********************************************************
# Offspring removed from the Offspring Pool due to violating the Comprehensive Energy Diversity Scheme.
# NOTE: energy difference minimum = 0.025 eV.
# **********************************************************
# **********************************************************
# Assessing which structures to remove to comply with the Energy Diversity Scheme
# Start assessing for Energy Diversity
# Removing offspring that violate the Energy Diversity Scheme
# 1. Clusters in the Population that have been replaced by Offspring, due to the cluster in the offspring being energetically similar and having a lower energy than a offspring.
# 1. Clusters in the Population that have been replaced by Offspring, due to the cluster in the offspring being energetically similar and having a lower energy than a offspring.
#  --> Population Cluster removed 69 (Energy: -104.666949 eV, fitness = 0.057986) {Replaced with Offspring 101 (Energy: -104.667887 eV, fitness = 0.058153)}.
#  --> Population Cluster removed 63 (Energy: -105.028397 eV, fitness = 0.175515) {Replaced with Offspring 102 (Energy: -105.037887 eV, fitness = 0.180693)}.
#  --> Population Cluster removed 55 (Energy: -105.301911 eV, fitness = 0.40578) {Replaced with Offspring 108 (Energy: -105.312287 eV, fitness = 0.418888)}.
#  --> Population Cluster removed 38 (Energy: -104.958592 eV, fitness = 0.141717) {Replaced with Offspring 112 (Energy: -104.974166 eV, fitness = 0.148644)}.
#  --> Population Cluster removed 30 (Energy: -104.697858 eV, fitness = 0.063746) {Replaced with Offspring 114 (Energy: -104.709926 eV, fitness = 0.066147)}.
#  --> Population Cluster removed 94 (Energy: -104.801512 eV, fitness = 0.087577) {Replaced with Offspring 115 (Energy: -104.813122 eV, fitness = 0.090748)}.
# *****************************
# 2. These offspring have a better energy and are energetically similar to two or more clusters in the population.
# 2. No offspring need to be removed from the offsprings list
# *****************************
# 3. The following offspring were removed from the offspring pool (and because they are energetically similar and have a lower energy to which cluster in the population):
# ...
# Cluster: 147; Energy: -105.5338292066; Fitness: 0.8372345665259138
# Cluster: 336; Energy: -105.4956444882; Fitness: 0.7528868226283546
# --------------------------------------------------------------------------
#
# --------------------------------------------------------------------------
# <Collection: Offspring> current size: 6
# Cluster: 455; Energy: -104.9276034097; Fitness: 0.15512441343665237
# Cluster: 457; Energy: -104.8435849477; Fitness: 0.12280248661147922
# Cluster: 458; Energy: -104.5189384654; Fitness: 0.049787068367863944
# Cluster: 459; Energy: -104.686092434; Fitness: 0.07924943069621226
# Cluster: 462; Energy: -104.8902795786; Fitness: 0.13983066764380908
# Cluster: 464; Energy: -104.7461404419; Fitness: 0.09365240054295804
# --------------------------------------------------------------------------
#
# Offspring that replace clusters in population due to fitness.
# ****---------------------****
# <Collection: Population> current size: 20; Clusters: [Cluster_217, Cluster_293, Cluster_257, Cluster_406, Cluster_260, Cluster_254, Cluster_422, Cluster_416, Cluster_372, Cluster_437, Cluster_423, Cluster_400, Cluster_325, Cluster_373, Cluster_335, Cluster_290, Cluster_367, Cluster_180, Cluster_147, Cluster_336]
# Time Information
# fitness_timer_1   = 0.0001385211944580078 seconds
# memory_operator_timer_1   = 1.0967254638671875e-05 seconds
# predation_timer_1 = 2.3083384037017822 seconds
# fitness_timer_2   = 0.00029349327087402344 seconds
# ending_timer      = 0.017084360122680664 seconds
# The amount of time required for generation 28 is 3.5608179569244385 seconds
# ----------------------------------------------------------
# Time elapsed: 00:01:59
# Date and Time: 2021-02-08 03:22:31.708425
#
#
# ----------------------------------------------------------
# #####################
# RUNNING GENERATION 29
# #####################
# -----------------------
# Making Offspring
# -----------------------
# Time taken to make offspring: 1.2368290424346924 s.
# Details of created offsprings
# Time taken to add offspring to Offspring_Pool: 0.0002522468566894531 s.
# -----------------------
# **********************************************************
# **********************************************************
# Offspring removed from the Offspring Pool due to violating the Comprehensive Energy Diversity Scheme.
# NOTE: energy difference minimum = 0.025 eV.
# **********************************************************
# **********************************************************
# Assessing which structures to remove to comply with the Energy Diversity Scheme
# Start assessing for Energy Diversity
# Removing offspring that violate the Energy Diversity Scheme
# 1. Clusters in the Population that have been replaced by Offspring, due to the cluster in the offspring being energetically similar and having a lower energy than a offspring.
# 1. Clusters in the Population that have been replaced by Offspring, due to the cluster in the offspring being energetically similar and having a lower energy than a offspring.
#  --> Population Cluster removed 437 (Energy: -105.083149 eV, fitness = 0.519247) {Replaced with Offspring 472 (Energy: -105.087533 eV, fitness = 0.522155)}.
#  --> Population Cluster removed 325 (Energy: -105.047775 eV, fitness = 0.496373) {Replaced with Offspring 479 (Energy: -105.060369 eV, fitness = 0.504398)}.
# *****************************
# 2. These offspring have a better energy and are energetically similar to two or more clusters in the population.
# 2. No offspring need to be removed from the offsprings list
# *****************************
# 3. The following offspring were removed from the offspring pool (and because they are energetically similar and have a lower energy to which cluster in the population):
# 3. The following offspring were removed from the offspring pool (and because they are energetically similar and have a lower energy to which cluster in the population):
#  --> Offspring 474 (Energy: -105.5972031148 eV, fitness = 0.999354) {Similar to Population Cluster 257 (Energy: -105.597711 eV, fitness = 1.0)}.
#  --> Offspring 478 (Energy: -105.404640364 eV, fitness = 0.781996) {Similar to Population Cluster 293 (Energy: -105.429232 eV, fitness = 0.806877)}.
#  --> Offspring 484 (Energy: -105.2444602082 eV, fitness = 0.63768) {Similar to Population Cluster 416 (Energy: -105.268243 eV, fitness = 0.657291)}.
#  --> Offspring 473 (Energy: -105.1565963924 eV, fitness = 0.570166) {Similar to Population Cluster 217 (Energy: -105.169968 eV, fitness = 0.579959)}.
#  --> Offspring 471 (Energy: -104.9549944298 eV, fitness = 0.441049) {Similar to Population Cluster 423 (Energy: -104.961918 eV, fitness = 0.444955)}.
# *****************************
# 4. Offspring that have have been removed for being energetically similar and have a lower energy to the rest of the other Offspring
# 4. Offspring that have have been removed for being energetically similar and have a lower energy to the rest of the other Offspring
#  --> Offspring 477 (Energy: -104.5716786406eV, fitness = 0.270682) {Similar to Offspring 476 (Energy: -104.5756486692 eV, fitness = 0.272054)}.
# **********************************************************
# **********************************************************
# -----------------------------
# ****---------------------****
# Natural Selection for Generation 29
# --------------------------------------------------------------------------
# <Collection: Population> current size: 20
# Cluster: 217; Energy: -105.1699675809; Fitness: 0.5799593110945201
# Cluster: 293; Energy: -105.4292317365; Fitness: 0.8068768101296934
# Cluster: 257; Energy: -105.5977108726; Fitness: 1.0
# Cluster: 406; Energy: -105.2980176377; Fitness: 0.6826959059938464
# Cluster: 260; Energy: -105.1436138046; Fitness: 0.560815700523977
# Cluster: 254; Energy: -105.4543602208; Fitness: 0.8331186105584002
# Cluster: 422; Energy: -105.1174201213; Fitness: 0.5424145814141327
# Cluster: 416; Energy: -105.2682432122; Fitness: 0.6572912250971257
# Cluster: 372; Energy: -105.3775253452; Fitness: 0.7554509889977389
# Cluster: 472; Energy: -105.0875329397; Fitness: 0.5221550971280212
# Cluster: 423; Energy: -104.961917618; Fitness: 0.44495541988042625
# Cluster: 400; Energy: -105.196641848; Fitness: 0.6000012618378452
# Cluster: 479; Energy: -105.0603685229; Fitness: 0.5043984709412963
# Cluster: 373; Energy: -104.9934743011; Fitness: 0.4632034713709832
# Cluster: 335; Energy: -105.0209748544; Fitness: 0.47971521919459115
# Cluster: 290; Energy: -105.403880405; Fitness: 0.7812398100914318
# Cluster: 367; Energy: -105.2265806161; Fitness: 0.6233221104492942
# Cluster: 180; Energy: -105.3263813866; Fitness: 0.7078096168955454
# Cluster: 147; Energy: -105.5338292066; Fitness: 0.9218588154848915
# Cluster: 336; Energy: -105.4956444882; Fitness: 0.878097759059318
# --------------------------------------------------------------------------
#
# --------------------------------------------------------------------------
# <Collection: Offspring> current size: 8
# Cluster: 469; Energy: -104.1987828734; Fitness: 0.16834304044649084
# Cluster: 470; Energy: -104.6045323775; Fitness: 0.2822487124343868
# Cluster: 475; Energy: -104.6465349828; Fitness: 0.2977593066902339
# Cluster: 476; Energy: -104.5756486692; Fitness: 0.2720540514654746
# Cluster: 480; Energy: -104.3326344047; Fitness: 0.19963375465974414
# Cluster: 481; Energy: -104.9190714977; Fitness: 0.42132433409632697
# Cluster: 482; Energy: -104.7764479678; Fitness: 0.35133836848897027
# Cluster: 483; Energy: -103.2422847322; Fitness: 0.049787068367863944
# --------------------------------------------------------------------------
#
# Offspring that replace clusters in population due to fitness.
# ****---------------------****
# <Collection: Population> current size: 20; Clusters: [Cluster_217, Cluster_293, Cluster_257, Cluster_406, Cluster_260, Cluster_254, Cluster_422, Cluster_416, Cluster_372, Cluster_472, Cluster_423, Cluster_400, Cluster_479, Cluster_373, Cluster_335, Cluster_290, Cluster_367, Cluster_180, Cluster_147, Cluster_336]
# Time Information
# fitness_timer_1   = 0.0002224445343017578 seconds
# memory_operator_timer_1   = 1.9311904907226562e-05 seconds
# predation_timer_1 = 2.6107442378997803 seconds
# fitness_timer_2   = 7.915496826171875e-05 seconds
# ending_timer      = 0.0191652774810791 seconds
# The amount of time required for generation 29 is 3.8803365230560303 seconds
# ----------------------------------------------------------
# Time elapsed: 00:02:03
# Date and Time: 2021-02-08 03:22:35.623626
#
#
# ----------------------------------------------------------
# #####################
# RUNNING GENERATION 30
# #####################
# -----------------------
# Making Offspring
# -----------------------
# Time taken to make offspring: 1
# --------------------------------------------------------------------------
#
# --------------------------------------------------------------------------
# <Collection: Offspring> current size: 4
# Cluster: 494; Energy: -104.8088535887; Fitness: 0.5047348713190865
# Cluster: 497; Energy: -104.2135147739; Fitness: 0.3012838100306558
# Cluster: 499; Energy: -104.9147099303; Fitness: 0.5532328891022561
# Cluster: 500; Energy: -102.1363300983; Fitness: 0.049787068367863944
# --------------------------------------------------------------------------
#
# Offspring that replace clusters in population due to fitness.
# ****---------------------****
# <Collection: Population> current size: 20; Clusters: [Cluster_217, Cluster_293, Cluster_491, Cluster_406, Cluster_260, Cluster_254, Cluster_422, Cluster_416, Cluster_372, Cluster_496, Cluster_423, Cluster_400, Cluster_479, Cluster_373, Cluster_335, Cluster_290, Cluster_367, Cluster_180, Cluster_147, Cluster_336]
# Time Information
# fitness_timer_1   = 0.00024819374084472656 seconds
# memory_operator_timer_1   = 1.3828277587890625e-05 seconds
# predation_timer_1 = 2.5763680934906006 seconds
# fitness_timer_2   = 0.00010442733764648438 seconds
# ending_timer      = 0.018337488174438477 seconds
# The amount of time required for generation 30 is 3.8517374992370605 seconds
# ----------------------------------------------------------
# Time elapsed: 00:02:07
# Date and Time: 2021-02-08 03:22:39.501127
# ----------------------------------------------------------
# ----------------------------------------------------------
# The maximum generation set by the user has been reached! The genetic algorithm process has completed!
# The Algorithm will finish now.
# ----------------------------------------------------------
# Time elapsed: 00:02:07
# Date and Time: 2021-02-08 03:22:39.502510
# ----------------------------------------------------------
# Finishing the Garden Group Genetic Algorithm Successfully.
# ----------------------------------------------------------
# ----------------------------------------------------------
# ' ---------------- '

# %% [markdown]
# [Back To Table of Contents](../Organisms_Jupyter_Example.ipynb)

# %% [markdown]
# ## Post-processing data from your global optimisation
#
# Once the genetic algorithm is finished, we generally would like to get data from it, such as the global minimum. We can get this from the Database that is recorded based on our settings for the ``ga_recording_information`` variable. The following code is a simple way of extracting the lowest energy cluster that was obtained during the genetic algorithm. This is not to be included in the *Run.py* file, this is just so you can see the fruits of your global optimisation work!

# %%
from ase.io import read
database_path = 'Recorded_Data/GA_Recording_Database.db'
lowest_energy_cluster_found = read(database_path)
if isinstance(lowest_energy_cluster_found, list):
    lowest_energy_cluster_found = lowest_energy_cluster_found[0]
lowest_energy_cluster_found.center(about=0.)
from ase.visualize import view
view(lowest_energy_cluster_found,viewer='x3d')
# Out:
# <html>
#
#  <head>
#
#   <title>ASE atomic visualization</title>
#
#   <link rel="stylesheet" type="text/css"
#
#    href="https://www.x3dom.org/x3dom/release/x3dom.css">
#
#   </link>
#
#   <script type="text/javascript"
#
#    src="https://www.x3dom.org/x3dom/release/x3dom.js">
#
#   </script>
#
#  </head>
#
#  <body>
#
#   <X3D>
#
#    <Scene>
#
#     <Transform translation="1.61 1.35 3.25">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.32 2.86 3.18">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.79 0.41 3.11">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="1.19 -1.20 2.99">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="3.54 -0.29 2.86">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-1.21 -2.08 2.93">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-2.38 2.05 1.85">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="3.71 1.84 1.70">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-2.68 -0.49 1.59">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="3.02 -2.25 1.48">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="1.63 3.12 1.40">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="0.58 -3.14 1.50">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="1.86 0.29 1.13">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.74 4.03 1.09">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.19 1.61 1.04">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.32 -0.85 1.00">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-1.85 -2.69 0.56">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="3.99 -0.26 0.21">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-3.99 1.11 0.22">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="2.29 -4.03 -0.16">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="1.53 -1.67 -0.29">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-2.12 2.86 -0.56">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="2.70 1.86 -0.59">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-1.72 0.51 -0.51">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="0.44 3.02 -0.90">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.02 -3.82 -0.81">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-3.32 -1.18 -0.88">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="0.64 0.51 -1.01">
#
#      <Shape>

# %% [markdown]
# [Back To Table of Contents](../Organisms_Jupyter_Example.ipynb)
