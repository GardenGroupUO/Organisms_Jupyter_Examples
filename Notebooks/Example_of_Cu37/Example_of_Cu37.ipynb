# %% [markdown]
# # A Basic Example for Optimising a 37 atom Copper Cluster with Organisms

# %% [markdown]
# [Back To Table of Contents](../Organisms_Jupyter_Example.ipynb)

# %% [markdown]
# In this example, we will perform a genetic algorithm optimisation on the 38 atom Lennard-Jones (LJ<sub>38</sub>) cluster. In this example, we will perform a genetic algorithm with a simple energy predation operator, the energy fitness operator, and a population-based epoch method. We will go through step by step all the components of the *Run.py* files required to run Organisms on LJ<sub>38</sub>. See [organisms.readthedocs.io/en/latest/Using_Run](https://organisms.readthedocs.io/en/latest/Using_Run.html) for more information on the *Run.py* file.
#
# To run this notebook step by step, press the $\blacktriangleright$ button sequentially on the python code you want to run. You can find the $\blacktriangleright$ button in the menu bar above. Make sure you have run $\blacktriangleright$ on every cell before running the final cell. Equivalently, press the $\blacktriangleright\blacktriangleright$ button to completely run this *Run.py* file beginning to end. You can also find the $\blacktriangleright\blacktriangleright$ button in the menu bar above.
#
# Note: These are the vanilla settings for running Organisms on a Cu<sub>37</sub> nanocluster, but feel free to change the settings as you wish.
#
# Also note: This program makes files which are created and stored on the Binder server. If you want to rerun this example, you will need to remove these files. The following block code will do this. This is only needed for this notebook and is not apart of *Run.py* script.

# %%
import os
from shutil import rmtree
to_be_removed_before_restarting_Jupyter_example = ['__pycache__','Population','epoch_data','epoch_data.backup','GA_Run_Details.txt','ga_running.lock']
for example_file_or_folder in to_be_removed_before_restarting_Jupyter_example:
    if os.path.exists(example_file_or_folder):
        if os.path.isdir(example_file_or_folder):
            rmtree(example_file_or_folder)
        else:
            os.remove(example_file_or_folder)

# %% [markdown]
# ## Setting up the *Run.py* Script for a Global Optimisation of a 37 atom Copper Nanocluster

# %% [markdown]
# The following contains all the options that you desire to set up the Organisms program to global optimise a Cu<sub>37</sub> nanocluster. These are the vanilla settings, but feel free to change them as you wish.

# %%
from Organisms import GA_Program

# This details the elemental and number of atom composition of cluster that the user would like to investigate
cluster_makeup = {"Cu": 37}

# Surface details
surface_details = None #{'surface': 'surface.xyz', 'place_cluster_where': 'center'}

# These are the main variables of the genetic algorithm that with changes could affect the results of the Genetic Algorithm.
pop_size = 20
generations = 200
no_offspring_per_generation = 16

# These setting indicate how offspring should be made using the Mating and Mutation Proceedures
creating_offspring_mode = "Either_Mating_and_Mutation" 
crossover_type = "CAS_weighted"
mutation_types = [['random', 1.0]]
chance_of_mutation = 0.1

# This parameter will tell the Organisms program if an epoch is desired, and how the user would like to proceed.
epoch_settings = {'epoch mode': 'same population', 'max repeat': 5}

# These are variables used by the algorithm to make and place clusters in.
r_ij = 3.4
cell_length = r_ij * (sum([float(noAtoms) for noAtoms in list(cluster_makeup.values())]) ** (1.0/3.0))
vacuum_to_add_length = 10.0

# The RunMinimisation.py algorithm is one set by the user. It contain the def Minimisation_Function
# That is used for local optimisations. This can be written in whatever way the user wants to perform
# the local optimisations. This is meant to be as free as possible.
from RunMinimisation_Cu import Minimisation_Function

# This dictionary includes the information required to prevent clusters being placed in the population if they are too similar to clusters in this memory_operator
memory_operator_information = {'Method': 'Off'}

# This switch tells the genetic algorithm the type of predation scheme they want to place on the genetic algoithm.
#predation_information = {'Predation Operator':'Off'}
#predation_information = {'Predation Operator':'Energy', 'mode': 'simple', 'round_energy': 2}
#predation_information = {'Predation Operator':'Energy', 'mode': 'comprehensive', 'minimum_energy_diff': 0.025, 'type_of_comprehensive_scheme': 'energy'}
predation_information = {'Predation Operator':'Energy', 'mode': 'comprehensive', 'minimum_energy_diff': 0.025, 'type_of_comprehensive_scheme': 'fitness'}
#predation_information = {'Predation Operator': 'IDCM', 'percentage_diff': 5.0}
#predation_information = {'Predation Operator': 'SCM', 'CNA Scheme': 'T-SCM', 'rCut_high': 3.2, 'rCut_low': 2.9, 'rCut_resolution': 0.05}

# This switch tells the genetic algorithm the type of fitness scheme they want to place on the genetic algoithm.
energy_fitness_function = {'function': 'exponential', 'alpha': 3.0}
#SCM_fitness_function = {'function': 'exponential', 'alpha': 1.0}
fitness_information = {'Fitness Operator': 'Energy', 'fitness_function': energy_fitness_function}
#fitness_information = {'Fitness Operator': 'SCM + Energy', 'Use Predation Information': True, 'SCM_fitness_contribution': 0.5, 'normalise_similarities': False, 'Dynamic Mode': False, 'energy_fitness_function': energy_fitness_function, 'SCM_fitness_function': SCM_fitness_function}
#fitness_information = {'Fitness Operator': 'SCM + Energy', 'CNA Scheme': 'T-SCM', 'rCut_high': 3.2, 'rCut_low': 2.9, 'rCut_resolution': 0.05, 'SCM_fitness_contribution': 0.5, 'normalise_similarities': False, 'Dynamic Mode': False, 'energy_fitness_function': energy_fitness_function, 'SCM_fitness_function': SCM_fitness_function}
#fitness_information = {'Fitness Operator': 'SCM + Energy', 'CNA Scheme': 'T-SCM', 'rCut': 3.05, 'SCM_fitness_contribution': 0.5, 'normalise_similarities': False, 'Dynamic Mode': False, 'energy_fitness_function': energy_fitness_function, 'SCM_fitness_function': SCM_fitness_function}

# Variables required for the Recording_Cluster.py class/For recording the history as required of the genetic algorithm.
ga_recording_information = {}
#ga_recording_information['ga_recording_scheme'] = 'Limit_energy_height' # float('inf')
#ga_recording_information['limit_number_of_clusters_recorded'] = 5 # float('inf')
#ga_recording_information['limit_energy_height_of_clusters_recorded'] = 1.5 #eV
#ga_recording_information['exclude_recording_cluster_screened_by_diversity_scheme'] = True
#ga_recording_information['record_initial_population'] = True
#ga_recording_information['saving_points_of_GA'] = [3,5]

# These are last techinical points that the algorithm is designed in mind
force_replace_pop_clusters_with_offspring = True
user_initialised_population_folder = None 
rounding_criteria = 10
print_details = True
no_of_cpus = 2
finish_algorithm_if_found_cluster_energy = None
total_length_of_running_time = 70.0

# %% [markdown]
# [Back To Table of Contents](../Organisms_Jupyter_Example.ipynb)

# %% [markdown]
# ## The Genetic Algorithm!
#
# You have got to the end of all the parameter setting stuff! Now on to the fun stuff! The next part of the Run.py file tells the genetic algorithm to run. This is written as follows in the Run.py:

# %%
''' ---------------- '''
# This will execute the genetic algorithm program
GA_Program(cluster_makeup=cluster_makeup,
    pop_size=pop_size,
    generations=generations,
    no_offspring_per_generation=no_offspring_per_generation,
    creating_offspring_mode=creating_offspring_mode,
    crossover_type=crossover_type,
    mutation_types=mutation_types,
    chance_of_mutation=chance_of_mutation,
    r_ij=r_ij,
    vacuum_to_add_length=vacuum_to_add_length,
    Minimisation_Function=Minimisation_Function,
    surface_details=surface_details,
    epoch_settings=epoch_settings,
    cell_length=cell_length,
    memory_operator_information=memory_operator_information,
    predation_information=predation_information,
    fitness_information=fitness_information,
    ga_recording_information=ga_recording_information,
    force_replace_pop_clusters_with_offspring=force_replace_pop_clusters_with_offspring,
    user_initialised_population_folder=user_initialised_population_folder,
    rounding_criteria=rounding_criteria,
    print_details=print_details,
    no_of_cpus=no_of_cpus,
    finish_algorithm_if_found_cluster_energy=finish_algorithm_if_found_cluster_energy,
    total_length_of_running_time=total_length_of_running_time)
''' ---------------- '''
# Out:
# ############################################################
# ############################################################
# ############################################################
# The Garden Group Genetic Algorithm for Clusters
#
# .--------------------------------------------------------------------------.
# |                             ,                                            |
# |              ,_     ,     .'<_                                           |
# |             _> `'-,'(__.-' __<                                           |
# |             >_.--(.. )  =;`                                   _          |
# |                  `V-'`'\/``                                  ('>         |
# |                                                              /))@@@@@.   |
# |         .----------------------------------.                /@"@@@@@()@  |
# |         | Welcome to the Organisms program |               .@@()@@()@@@@ |
# |         '----------------------------------'               @@@O@@@@()@@@ |
# |                  ^                                         @()@@\@@@()@@ |
# |  _     (\_/)     |                                          @()@||@@@@@' |
# | ( \    (0.o) ----'                 _                         '@@||@@@'   |
# |  ) )   (> <)                     _(_)_            wWWWw   _     ||       |
# | ( (  .-'''''-.  A.-.A      @@@@ (_)@(_)       _   (___) _(_)_   ||       |
# |  \ \/         \/ , , \    @@()@@  (_)\      _(_)_   Y  (_)@(_)  ||       |
# |   \   \        ;= t =/     @@@@      `|/   (_)@(_) \|/   (_)\   ||       |
# |    \   |'''''-   ,--'       /        \|     /(_)    |/      |   ||       |
# |     / //     | ||        \ |          | / \|/      \|      \|/  ||       |
# |    /_,))     |_'))       \\|//     \\\|// \|///   \\|//  \\\|// ||       |
# |^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^|
# '--------------------------------------------------------------------------'
#
# Version: 3.2.1
# ############################################################
# ############################################################
#
# This algorithm is designed to perform a genetic algorithm to obtain low energetic structures for a given cluster composition.
#
# This genetic algorithm will proceed with the following input parameters
#
# # This details the elemental and number of atom composition of cluster that the user would like to investigate
# cluster_makeup = {'Cu': 37}
#
# # This details the information used to perform a global optimisation upon a chosen surface
# surface_details = None
#
# # These are the main variables of the genetic algorithm that with changes could affect the results of the Genetic Algorithm.
# pop_size = 20
# generations = 200
# no_offspring_per_generation = 16
#
# # These setting indicate how offspring should be made using the Mating and Mutation Proceedures
# creating_offspring_mode = Either_Mating_and_Mutation
# crossover_type = CAS_weighted
# mutation_types = [['random', 1.0]]
# mutation_types = 0.1
#
# # These are variables used by the algorithm to make and place clusters in.
# r_ij = 3.4 Angstroms (This is the maximum possible bond length between two atoms in the cluster)
# cell_length = 11.329554295596239 Angstroms
# vacuum_to_add_length = 10.0 Angstroms
#
# # The RunMinimisation.py algorithm is one set by the user. It contain the def Minimisation_Function
# # That is used for local optimisations. This can be written in whatever way the user wants to perform
# # the local optimisations. This is meant to be as free as possible.
# Minimisation_Function = <function Minimisation_Function at 0x7fbfa86cd730>
# Path of Minimisation_Function: /mnt/hgfs/GoogleDrive/PhDWork/Programs/OptimisationAlgorithms/GeneticAlgorithm/Organisms/Organisms_Jupyter_Examples/Notebooks/Example_of_Cu37/RunMinimisation_Cu.py
#
# # This details the information about the memory operator used in this genetic algorithm.
# memory_operator = {'method': 'Off'}
#
# # This details the information about the predation operator used in this genetic algorithm.
# predation_operator = {'predation_information': {'Predation Operator': 'Energy', 'mode': 'comprehensive', 'minimum_energy_diff': 0.025, 'type_of_comprehensive_scheme': 'fitness'}, 'Predation_Switch': 'Energy', 'population': <Collection: Population> current size: 0; Clusters: [], 'print_details': False, 'mode': 'comprehensive', 'type_of_comprehensive_scheme': 'fitness', 'minimum_energy_diff': 0.025, 'check_initial_population_imported': <function check_initial_population at 0x7fbfa86cd620>, 'assess_for_violations_force_replacement_imported': <function assess_for_violations_force_replacement at 0x7fbf741e6158>, 'assess_for_violations_no_force_replacement_imported': <function assess_for_violations_no_force_replacement at 0x7fbf741e60d0>}
#
# # This details the information about the fitness operator used in this genetic algorithm.
# fitness_operator = {'fitness_switch': 'Energy', 'fitness_information': {'Fitness Operator': 'Energy', 'fitness_function': {'function': 'exponential', 'alpha': 3.0}, 'Use Predation Information': False}, 'population': <Collection: Population> current size: 0; Clusters: [], 'print_details': False, 'previous_max_energy': -inf, 'previous_min_energy': inf, 'energy_fitness_function': <Organisms.GA.Fitness_Operators.Fitness_Function.Fitness_Function object at 0x7fbfa86b5860>}
#
# # This parameter will tell the Organisms program if an epoch is desired, and how the user would like to proceed.
# epoch_settings: {'path': '/mnt/hgfs/GoogleDrive/PhDWork/Programs/OptimisationAlgorithms/GeneticAlgorithm/Organisms/Organisms_Jupyter_Examples/Notebooks/Example_of_Cu37', 'epoch_data_name': 'epoch_data', 'backup_epoch_data_name': 'epoch_data.backup', 'epoch_settings': {'epoch mode': 'same population', 'max repeat': 5}, 'epoch_mode': 'same population', 'max_number_of_times_non_changing_population': 5, 'epoch_function': <bound method Epoch.should_epoch_using_same_population_epoch of {...}>, 'perform_epoch_function': <bound method Epoch.perform_epoch_same_population of {...}>, 'first_epoch_to_change_fitness_function': False}
#
# # Variables required for the GA_Recording_System.py class/For recording the history as required of the genetic algorithm.
# ga_recording_system = {'ga_recording_information': {'ga_recording_scheme': 'None'}, 'ga_recording_scheme': 'None', 'ga_recording_system_name': 'Recorded_Data', 'path_to_write_to': '/mnt/hgfs/GoogleDrive/PhDWork/Programs/OptimisationAlgorithms/GeneticAlgorithm/Organisms/Organisms_Jupyter_Examples/Notebooks/Example_of_Cu37/Recorded_Data', 'exclude_recording_cluster_screened_by_diversity_scheme': True, 'limit_number_of_clusters_recorded': None, 'limit_size_of_database': None, 'show_GA_Recording_Database_check_percentage': False, 'RC_Information_TXT_name': 'Recorded_Data_Information.txt', 'record_initial_population': False, 'saving_points_of_GA': []}
#
# # These are last techinical points that the algorithm is designed in mind
# force_replace_pop_clusters_with_offspring = True
# user_initialised_population_folder = None
# rounding_criteria = 10
# print_details = False
# no_of_cpus = 2
# finish_algorithm_if_found_cluster_energy = None
# total_length_of_running_time: 70.0 hours
#
# ############################################################
# ############################################################
# ############################################################
# ################################################################################################################
# ################################################################################################################
# Initalising a Starting Population of Clusters if required to take pool up to a size of 20
# Pool size to begin = 0
# Checking to see if the user has any clusters in the folder None that the user would like to have inputted into the initalise population.
# ################################################################################################################
# Will now population the next 20 with randomly generated clusters.
# -----------------------------
# Checking that the clusters in the population satisfies the Diversity Scheme
# *****************************
# *****************************
# Diversity Scheme located "duplicates" in creating population.
# Recreating clusters: [4, 5, 13]
# -----------------------------
# Checking that the clusters in the population satisfies the Diversity Scheme
# *****************************
# *****************************
# Diversity Scheme located "duplicates" in creating population.
# Recreating clusters: [4]
# -----------------------------
# Checking that the clusters in the population satisfies the Diversity Scheme
# *****************************
# *****************************
# Diversity Scheme located "duplicates" in creating population.
# Recreating clusters: [7]
# -----------------------------
# Checking that the clusters in the population satisfies the Diversity Scheme
# *****************************
# *****************************
# Diversity Scheme located "duplicates" in creating population.
# Recreating clusters: [7]
# -----------------------------
# Checking that the clusters in the population satisfies the Diversity Scheme
# *****************************
# *****************************
# Diversity Scheme located "duplicates" in creating population.
# Recreating clusters: [5]
# -----------------------------
# Checking that the clusters in the population satisfies the Diversity Scheme
# Have finished populating the rest of the population with 0 randomly generated clusters.
# The population has been successfully initalised.
# ################################################################################################################
# ################################################################################################################
# Time elapsed: 00:00:05
# Date and Time: 2021-02-07 23:17:45.129169
# -----------------------------
# -----------------------------
# Starting Genetic Algorithm
# -----------------------------
# -----------------------------
#
#
#
# ----------------------------------------------------------
# ####################
# RUNNING GENERATION 1
# ####################
# -----------------------
# Making Offspring
# -----------------------
# Time taken to make offspring: 0.6552190780639648 s.
# Time taken to add offspring to Offspring_Pool: 2.384185791015625e-05 s.
# -----------------------
# **********************************************************
# **********************************************************
# Offspring removed from the Offspring Pool due to violating the Comprehensive Energy Diversity Scheme.
# NOTE: energy difference minimum = 0.025 eV.
# **********************************************************
# **********************************************************
# Assessing which structures to remove to comply with the Energy Diversity Scheme
# Start assessing for Energy Diversity
# Removing offspring that violate the Energy Diversity Scheme
# 1. Clusters in the Population that have been replaced by Offspring, due to the cluster in the offspring being energetically similar and having a lower energy than a offspring.
# 1. Clusters in the Population that have been replaced by Offspring, due to the cluster in the offspring being energetically similar and having a lower energy than a offspring.
#  --> Population Cluster removed 8 (Energy: -103.582096 eV, fitness = 0.241469) {Replaced with Offspring 22 (Energy: -103.583095 eV, fitness = 0.241664)}.
#  --> Population Cluster removed 13 (Energy: -104.579234 eV, fitness = 0.541179) {Replaced with Offspring 26 (Energy: -104.588802 eV, fitness = 0.545386)}.
# *****************************
# 2. These offspring have a better energy and are energetically similar to two or more clusters in the population.
# 2. No offspring need to be removed from the offsprings list
# *****************************
# 3. The following offspring were removed from the offspring pool (and because they are energetically similar and have a lower energy to which cluster in the population):
# 3. The following offspring were removed from the offspring pool (and because they are energetically similar and have a lower energy to which cluster in the population):
#  --> Offspring 24 (Energy: -105.1002065206 eV, fitness = 0.825002) {Similar to Population Cluster 14 (Energy: -105.119244 eV, fitness = 0.837812)}.
#  --> Offspring 34 (Energy: -104.0846347812 eV, fitness = 0.362657) {Similar to Population Cluster 15 (Energy: -104.085648 eV, fitness = 0.362955)}.
# *****************************
# 4. Offspring that have have been removed for being energetically similar and have a lower energy to the rest of the other Offspring
# 4. Offspring that have have been removed for being energetically similar and have a lower energy to the rest of the other Offspring
#  --> Offspring 31 (Energy: -104.7125514717eV, fitness = 0.602837) {Similar to Offspring 29 (Energy: -104.7348525633 eV, fitness = 0.613816)}.
#  --> Offspring 32 (Energy: -104.6964074233eV, fitness = 0.595012) {Similar to Offspring 27 (Energy: -104.7009226567 eV, fitness = 0.59719)}.
# **********************************************************
# **********************************************************
# Time Information
# fitness_timer_1   = 0.0004353523254394531 seconds
# memory_operator_timer_1   = 4.410743713378906e-05 seconds
# predation_timer_1 = 0.19414091110229492 seconds
# fitness_timer_2   = 0.00011467933654785156 seconds
# ending_timer      = 0.04198908805847168 seconds
# The amount of time required for generation 1 is 1.893073558807373 seconds
# ----------------------------------------------------------
# Time elapsed: 00:00:07
# Date and Time: 2021-02-07 23:17:47.060646
#
#
# ----------------------------------------------------------
# ####################
# RUNNING GENERATION 2
# ####################
# -----------------------
# Making Offspring
# -----------------------
# Time taken to make offspring: 0.6331899166107178 s.
# Time taken to add offspring to Offspring_Pool: 3.3855438232421875e-05 s.
# -----------------------
# **********************************************************
# **********************************************************
# Offspring removed from the Offspring Pool due to violating the Comprehensive Energy Diversity Scheme.
# NOTE: energy difference minimum = 0.025 eV.
# **********************************************************
# **********************************************************
# Assessing which structures to remove to comply with the Energy Diversity Scheme
# Start assessing for Energy Diversity
# Removing offspring that violate the Energy Diversity Scheme
# 1. Clusters in the Population that have been replaced by Offspring, due to the cluster in the offspring being energetically similar and having a lower energy than a offspring.
# 1. Clusters in the Population that have been replaced by Offspring, due to the cluster in the offspring being energetically similar and having a lower energy than a offspring.
#  --> Population Cluster removed 23 (Energy: -104.913707 eV, fitness = 0.329835) {Replaced with Offspring 38 (Energy: -104.937229 eV, fitness = 0.346921)}.
#  --> Population Cluster removed 20 (Energy: -104.43822 eV, fitness = 0.118823) {Replaced with Offspring 40 (Energy: -104.44019 eV, fitness = 0.119327)}.
#  --> Population Cluster removed 26 (Energy: -104.588802 eV, fitness = 0.16418) {Replaced with Offspring 44 (Energy: -104.594415 eV, fitness = 0.16617)}.
#  --> Population Cluster removed 16 (Energy: -104.826912 eV, fitness = 0.273753) {Replaced with Offspring 45 (Energy: -104.828037 eV, fitness = 0.274415)}.
#  --> Population Cluster removed 18 (Energy: -105.181663 eV, fitness = 0.586365) {Replaced with Offspring 50 (Energy: -105.192962 eV, fitness = 0.600765)}.
# *****************************
# 2. These offspring have a better energy and are energetically similar to two or more clusters in the population.
# 2. No offspring need to be removed from the offsprings list
# *****************************
# 3. The following offspring were removed from the offspring pool (and because they are energetically similar and have a lower energy to which cluster in the population):
# 3. The following offspring were removed from the offspring pool (and because they are energetically similar and have a lower energy to which cluster in the population):
#  --> Offspring 43 (Energy: -104.8676363532 eV, fitness = 0.298769) {Similar to Population Cluster 5 (Energy: -104.873081 eV, fitness = 0.302282)}.
#  --> Offspring 42 (Energy: -104.623776649 eV, fitness = 0.176984) {Similar to Population Cluster 33 (Energy: -104.644075 eV, fitness = 0.184868)}.
#  --> Offspring 39 (Energy: -104.2853023011 eV, fitness = 0.085566) {Similar to Population Cluster 28 (Energy: -104.296952 eV, fitness = 0.087734)}.
# *****************************
# 4. Offspring that have have been removed for being energetically similar and have a lower energy to the rest of the other Offspring
# 4. Offspring that have have been removed for being energetically similar and have a lower energy to the rest of the other Offspring
#  --> Offspring 37 (Energy: -105.3595884634eV, fitness = 0.859184) {Similar to Offspring 41 (Energy: -105.3784005618 eV, fitness = 0.894599)}.
#  --> Offspring 48 (Energy: -104.810612786eV, fitness = 0.264338) {Similar to Offspring 45 (Energy: -104.8280365391 eV, fitness = 0.274415)}.
#  --> Offspring 49 (Energy: -104.1060658618eV, fitness = 0.058232) {Similar to Offspring 47 (Energy: -104.1068692317 eV, fitness = 0.058333)}.
# **********************************************************
# **********************************************************
# Time Information
# fitness_timer_1   = 0.0002789497375488281 seconds
# memory_operator_timer_1   = 4.601478576660156e-05 seconds
# predation_timer_1 = 0.539849042892456 seconds
# fitness_timer_2   = 0.0001652240753173828 seconds
# ending_timer      = 0.025513648986816406 seconds
# The amount of time required for generation 2 is 1.5240283012390137 seconds
# ----------------------------------------------------------
# Time elapsed: 00:00:09
# Date and Time: 2021-02-07 23:17:48.604309
#
#
# ----------------------------------------------------------
# ####################
# RUNNING GENERATION 3
# ####################
# -----------------------
# Making Offspring
# -----------------------
# Time taken to make offspring: 0.729841947555542 s.
# Time taken to add offspring to Offspring_Pool: 3.7670135498046875e-05 s.
# -----------------------
# **********************************************************
# **********************************************************
# Offspring removed from the Offspring Pool due to violating the Comprehensive Energy Diversity Scheme.
# NOTE: energy difference minimum = 0.025 eV.
# **********************************************************
# **********************************************************
# Assessing which structures to remove to comply with the Energy Diversity Scheme
# Start assessing for Energy Diversity
# Removing offspring that violate the Energy Diversity Scheme
# 1. Clusters in the Population that have been replaced by Offspring, due to the cluster in the offspring being energetically similar and having a lower energy than a offspring.
# 1. Clusters in the Population that have been replaced by Offspring, due to the cluster in the offspring being energetically similar and having a lower energy than a offspring.
#  --> Population Cluster removed 41 (Energy: -105.378401 eV, fitness = 0.850335) {Replaced with Offspring 53 (Energy: -105.398948 eV, fitness = 0.88893)}.
#  --> Population Cluster removed 45 (Energy: -104.828037 eV, fitness = 0.258972) {Replaced with Offspring 56 (Energy: -104.834569 eV, fitness = 0.262652)}.
#  --> Population Cluster removed 51 (Energy: -105.430273 eV, fitness = 0.951164) {Replaced with Offspring 62 (Energy: -105.45345 eV, fitness = 1.0)}.
#  --> Population Cluster removed 2 (Energy: -104.390781 eV, fitness = 0.1007) {Replaced with Offspring 66 (Energy: -104.414848 eV, fitness = 0.106074)}.
#  --> Population Cluster removed 52 (Energy: -105.263976 eV, fitness = 0.66411) {Replaced with Offspring 67 (Energy: -105.264895 eV, fitness = 0.66543)}.
# *****************************
# 2. These offspring have a better energy and are energetically similar to two or more clusters in the population.
# 2. No offspring need to be removed from the offsprings list
# *****************************
# 3. The following offspring were removed from the offspring pool (and because they are energetically similar and have a lower energy to which cluster in the population):
# 3. The following offspring were removed from the offspring pool (and because they are energetically similar and have a lower energy to which cluster in the population):
#  --> Offspring 60 (Energy: -105.1153887067 eV, fitness = 0.481769) {Similar to Population Cluster 14 (Energy: -105.119244 eV, fitness = 0.485798)}.
#  --> Offspring 63 (Energy: -104.6863108861 eV, fitness = 0.190673) {Similar to Population Cluster 27 (Energy: -104.700923 eV, fitness = 0.196787)}.
#  --> Offspring 65 (Energy: -104.6329708379 eV, fitness = 0.169921) {Similar to Population Cluster 33 (Energy: -104.644075 eV, fitness = 0.174046)}.
#  --> Offspring 55 (Energy: -104.5162749627 eV, fitness = 0.132058) {Similar to Population Cluster 9 (Energy: -104.523796 eV, fitness = 0.134221)}.
# *****************************
# 4. Offspring that have have been removed for being energetically similar and have a lower energy to the rest of the other Offspring
# 4. Offspring that have have been removed for being energetically similar and have a lower energy to the rest of the other Offspring
#  --> Offspring 61 (Energy: -105.4304694776eV, fitness = 0.951568) {Similar to Offspring 62 (Energy: -105.4534502773 eV, fitness = 1.0)}.
#  --> Offspring 58 (Energy: -105.0713087534eV, fitness = 0.43801) {Similar to Offspring 68 (Energy: -105.0859438242 eV, fitness = 0.452079)}.
# **********************************************************
# **********************************************************
# Time Information
# fitness_timer_1   = 0.0001914501190185547 seconds
# memory_operator_timer_1   = 2.1219253540039062e-05 seconds
# predation_timer_1 = 0.6558022499084473 seconds
# fitness_timer_2   = 0.0001518726348876953 seconds
# ending_timer      = 0.02450847625732422 seconds
# The amount of time required for generation 3 is 1.8024191856384277 seconds
# ----------------------------------------------------------
# Time elapsed: 00:00:11
# Date and Time: 2021-02-07 23:17:50.436035
#
#
# ----------------------------------------------------------
# ####################
# RUNNING GENERATION 4
# ####################
# -----------------------
# Making Offspring
# -----------------------
# Time taken to make offspring: 0.7199201583862305 s.
# Time taken to add offspring to Offspring_Pool: 2.4080276489257812e-05 s.
# -----------------------
# **********************************************************
# **********************************************************
# Offspring removed from the Offspring Pool due to violating the Comprehensive Energy Diversity Scheme.
# NOTE: energy difference minimum = 0.025 eV.
# **********************************************************
# **********************************************************
# Assessing which structures to remove to comply with the Energy Diversity Scheme
# Start assessing for Energy Diversity
# Removing offspring that violate the Energy Diversity Scheme
# 1. Clusters in the Population that have been replaced by Offspring, due to the cluster in the offspring being energetically similar and having a lower energy than a offspring.
# 1. Clusters in the Population that have been replaced by Offspring, due to the cluster in the offspring being energetically similar and having a lower energy than a offspring.
#  --> Population Cluster removed 9 (Energy: -104.523796 eV, fitness = 0.126056) {Replaced with Offspring 75 (Energy: -104.536978 eV, fitness = 0.129813)}.
#  --> Population Cluster removed 14 (Energy: -105.119244 eV, fitness = 0.47496) {Replaced with Offspring 77 (Energy: -105.12492 eV, fitness = 0.481005)}.
# *****************************
# 2. These offspring have a better energy and are energetically similar to two or more clusters in the population.
# 2. No offspring need to be removed from the offsprings list
# *****************************
# 3. The following offspring were removed from the offspring pool (and because they are energetically similar and have a lower energy to which cluster in the population):
# 3. The following offspring were removed from the offspring pool (and because they are energetically similar and have a lower energy to which cluster in the population):
#  --> Offspring 83 (Energy: -105.398832302 eV, fitness = 0.885437) {Similar to Population Cluster 53 (Energy: -105.398948 eV, fitness = 0.885666)}.
#  --> Offspring 71 (Energy: -105.3180464078 eV, fitness = 0.739601) {Similar to Population Cluster 25 (Energy: -105.337897 eV, fitness = 0.773042)}.
#  --> Offspring 78 (Energy: -105.2519340627 eV, fitness = 0.638314) {Similar to Population Cluster 67 (Energy: -105.264895 eV, fitness = 0.657013)}.
#  --> Offspring 72 (Energy: -104.7808082409 eV, fitness = 0.223472) {Similar to Population Cluster 35 (Energy: -104.798214 eV, fitness = 0.232307)}.
#  --> Offspring 76 (Energy: -104.7533191443 eV, fitness = 0.210197) {Similar to Population Cluster 21 (Energy: -104.761818 eV, fitness = 0.214215)}.
#  --> Offspring 80 (Energy: -104.6787092545 eV, fitness = 0.178009) {Similar to Population Cluster 27 (Energy: -104.700923 eV, fitness = 0.18704)}.
# *****************************
# 4. Offspring that have have been removed for being energetically similar and have a lower energy to the rest of the other Offspring
# 4. Offspring that have have been removed for being energetically similar and have a lower energy to the rest of the other Offspring
#  --> Offspring 69 (Energy: -105.1129316858eV, fitness = 0.468328) {Similar to Offspring 77 (Energy: -105.1249204692 eV, fitness = 0.481005)}.
#  --> Offspring 82 (Energy: -104.4891788286eV, fitness = 0.116701) {Similar to Offspring 73 (Energy: -104.4951371414 eV, fitness = 0.11826)}.
#  --> Offspring 74 (Energy: -104.1628858364eV, fitness = 0.056414) {Similar to Offspring 84 (Energy: -104.172292625 eV, fitness = 0.057609)}.
# **********************************************************
# **********************************************************
# Time Information
# fitness_timer_1   = 0.0002048015594482422 seconds
# memory_operator_timer_1   = 3.4809112548828125e-05 seconds
# predation_timer_1 = 0.42035937309265137 seconds
# fitness_timer_2   = 0.000118255615234375 seconds
# ending_timer      = 0.019390106201171875 seconds
# The amount of time required for generation 4 is 1.2781565189361572 seconds
# ----------------------------------------------------------
# Time elapsed: 00:00:12
# Date and Time: 2021-02-07 23:17:51.735547
#
#
# ----------------------------------------------------------
# ####################
# RUNNING GENERATION 5
# ####################
# -----------------------
# Making Offspring
# -----------------------
# Time taken to make offspring: 0.7189013957977295 s.
# Time taken to add offspring to Offspring_Pool: 1.71661376953125e-05 s.
# -----------------------
# **********************************************************
# **********************************************************
# Offspring removed from the Offspring Pool due to violating the Comprehensive Energy Diversity Scheme.
# NOTE: energy difference minimum = 0.025 eV.
# **********************************************************
# **********************************************************
# Assessing which structures to remove to comply with the Energy Diversity Scheme
# Start assessing for Energy Diversity
# Removing offspring that violate the Energy Diversity Scheme
# 1. Clusters in the Population that have been replaced by Offspring, due to the cluster in the offspring being energetically similar and having a lower energy than a offspring.
# 1. Clusters in the Population that have been replaced by Offspring, due to the cluster in the offspring being energetically similar and having a lower energy than a offspring.
#  --> Population Cluster removed 53 (Energy: -105.398948 eV, fitness = 0.900786) {Replaced with Offspring 93 (Energy: -105.404485 eV, fitness = 0.910398)}.
# *****************************
# 2. These offspring have a better energy and are energetically similar to two or more clusters in the population.
# 2. No offspring need to be removed from the offsprings list
# *****************************
# 3. The following offspring were removed from the offspring pool (and because they are energetically similar and have a lower energy to which cluster in the population):
# 3. The following offspring were removed from the offspring pool (and because they are energetically similar and have a lower energy to which cluster in the population):
#  --> Offspring 98 (Energy: -105.3254942403 eV, fitness = 0.782463) {Similar to Population Cluster 25 (Energy: -105.337897 eV, fitness = 0.801291)}.
#  --> Offspring 86 (Energy: -105.17892347 eV, fitness = 0.590785) {Similar to Population Cluster 50 (Energy: -105.192962 eV, fitness = 0.606901)}.
#  --> Offspring 87 (Energy: -105.1050442955 eV, fitness = 0.512764) {Similar to Population Cluster 77 (Energy: -105.12492 eV, fitness = 0.53268)}.
#  --> Offspring 90 (Energy: -104.9308241754 eV, fitness = 0.367166) {Similar to Population Cluster 38 (Energy: -104.937229 eV, fitness = 0.371701)}.
#  --> Offspring 96 (Energy: -104.8625857694 eV, fitness = 0.322142) {Similar to Population Cluster 5 (Energy: -104.873081 eV, fitness = 0.328689)}.
#  --> Offspring 89 (Energy: -104.7856095771 eV, fitness = 0.277943) {Similar to Population Cluster 35 (Energy: -104.798214 eV, fitness = 0.284742)}.
#  --> Offspring 94 (Energy: -104.7825510695 eV, fitness = 0.276319) {Similar to Population Cluster 35 (Energy: -104.798214 eV, fitness = 0.284742)}.
#  --> Offspring 100 (Energy: -104.6222122246 eV, fitness = 0.203195) {Similar to Population Cluster 33 (Energy: -104.644075 eV, fitness = 0.211892)}.
# *****************************
# 4. Offspring that have have been removed for being energetically similar and have a lower energy to the rest of the other Offspring
# 4. Offspring that have have been removed for being energetically similar and have a lower energy to the rest of the other Offspring
#  --> Offspring 85 (Energy: -105.3990859975eV, fitness = 0.901024) {Similar to Offspring 93 (Energy: -105.4044847031 eV, fitness = 0.910398)}.
#  --> Offspring 95 (Energy: -105.3955850775eV, fitness = 0.894997) {Similar to Offspring 93 (Energy: -105.4044847031 eV, fitness = 0.910398)}.
#  --> Offspring 88 (Energy: -105.3867602909eV, fitness = 0.879982) {Similar to Offspring 93 (Energy: -105.4044847031 eV, fitness = 0.910398)}.
#  --> Offspring 91 (Energy: -105.3842221555eV, fitness = 0.875711) {Similar to Offspring 93 (Energy: -105.4044847031 eV, fitness = 0.910398)}.
# **********************************************************
# **********************************************************
# Time Information
# fitness_timer_1   = 0.00016188621520996094 seconds
# memory_operator_timer_1   = 2.0503997802734375e-05 seconds
# predation_timer_1 = 0.11260366439819336 seconds
# fitness_timer_2   = 7.891654968261719e-05 seconds
# ending_timer      = 0.02019977569580078 seconds
# The amount of time required for generation 5 is 0.9666171073913574 seconds
# ----------------------------------------------------------
# Time elapsed: 00:00:13
# Date and Time: 2021-02-07 23:17:52.721754
#
#
# ----------------------------------------------------------
# ####################
# RUNNING GENERATION 6
# ####################
# -----------------------
# Making Offspring
# -----------------------
# Time taken to make offspring: 0.6271641254425049 s.
# Time taken to add offspring to Offspring_Pool: 6.604194641113281e-05 s.
# -----------------------
# **********************************************************
# **********************************************************
# Offspring removed from the Offspring Pool due to violating the Comprehensive Energy Diversity Scheme.
# NOTE: energy difference minimum = 0.025 eV.
# **********************************************************
# **********************************************************
# Assessing which structures to remove to comply with the Energy Diversity Scheme
# Start assessing for Energy Diversity
# Removing offspring that violate the Energy Diversity Scheme
# 1. Clusters in the Population that have been replaced by Offspring, due to the cluster in the offspring being energetically similar and having a lower energy than a offspring.
# 1. Clusters in the Population that have been replaced by Offspring, due to the cluster in the offspring being energetically similar and having a lower energy than a offspring.
#  --> Population Cluster removed 38 (Energy: -104.937229 eV, fitness = 0.373482) {Replaced with Offspring 102 (Energy: -104.940521 eV, fitness = 0.375835)}.
#  --> Population Cluster removed 62 (Energy: -105.45345 eV, fitness = 0.999785) {Replaced with Offspring 106 (Energy: -105.453563 eV, fitness = 1.0)}.
#  --> Population Cluster removed 21 (Energy: -104.761818 eV, fitness = 0.267276) {Replaced with Offspring 110 (Energy: -104.762426 eV, fitness = 0.267586)}.
#  --> Population Cluster removed 35 (Energy: -104.798214 eV, fitness = 0.286491) {Replaced with Offspring 112 (Energy: -104.803718 eV, fitness = 0.289514)}.
#  --> Population Cluster removed 56 (Energy: -104.834569 eV, fitness = 0.307063) {Replaced with Offspring 114 (Energy: -104.835249 eV, fitness = 0.307461)}.
# *****************************
# 2. These offspring have a better energy and are energetically similar to two or more clusters in the population.
# 2. No offspring need to be removed from the offsprings list
# *****************************
# 3. The following offspring were removed from the offspring pool (and because they are energetically similar and have a lower energy to which cluster in the population):
# 3. The following offspring were removed from the offspring pool (and because they are energetically similar and have a lower energy to which cluster in the population):
#  --> Offspring 113 (Energy: -105.081037381 eV, fitness = 0.491361) {Similar to Population Cluster 68 (Energy: -105.085944 eV, fitness = 0.495981)}.
#  --> Offspring 109 (Energy: -105.0720086281 eV, fitness = 0.482971) {Similar to Population Cluster 68 (Energy: -105.085944 eV, fitness = 0.495981)}.
#  --> Offspring 108 (Energy: -104.696667774 eV, fitness = 0.236042) {Similar to Population Cluster 27 (Energy: -104.700923 eV, fitness = 0.237966)}.
#  --> Offspring 111 (Energy: -104.6457357383 eV, fitness = 0.214189) {Similar to Population Cluster 1 (Energy: -104.669104 eV, fitness = 0.223952)}.
# *****************************
# 4. Offspring that have have been removed for being energetically similar and have a lower energy to the rest of the other Offspring
# 4. Offspring that have have been removed for being energetically similar and have a lower energy to the rest of the other Offspring
#  --> Offspring 115 (Energy: -104.7441587022eV, fitness = 0.258423) {Similar to Offspring 110 (Energy: -104.7624263927 eV, fitness = 0.267586)}.
# **********************************************************
# **********************************************************
# Time Information
# fitness_timer_1   = 0.00024056434631347656 seconds
# memory_operator_timer_1   = 7.843971252441406e-05 seconds
# predation_timer_1 = 0.5071427822113037 seconds
# fitness_timer_2   = 0.0001220703125 seconds
# ending_timer      = 0.021097421646118164 seconds
# The amount of time required for generation 6 is 1.4168076515197754 seconds
# ----------------------------------------------------------
# Time elapsed: 00:00:14
# Date and Time: 2021-02-07 23:17:54.161247
#
#
# ----------------------------------------------------------
# ####################
# RUNNING GENERATION 7
# ####################
# -----------------------
# Making Offspring
# -----------------------
# Time taken to make offspring: 0.618952751159668 s.
# Time taken to add offspring to Offspring_Pool: 5.602836608886719e-05 s.
# -----------------------
# **********************************************************
# **********************************************************
# Offspring removed from the Offspring Pool due to violating the Comprehensive Energy Diversity Scheme.
# NOTE: energy difference minimum = 0.025 eV.
# **********************************************************
# **********************************************************
# Assessing which structures to remove to comply with the Energy Diversity Scheme
# Start assessing for Energy Diversity
# Removing offspring that violate the Energy Diversity Scheme
# 1. Clusters in the Population that have been replaced by Offspring, due to the cluster in the offspring being energetically similar and having a lower energy than a offspring.
# 1. Clusters in the Population that have been replaced by Offspring, due to the cluster in the offspring being energetically similar and having a lower energy than a offspring.
#  --> Population Cluster removed 102 (Energy: -104.940521 eV, fitness = 0.39467) {Replaced with Offspring 117 (Energy: -104.950691 eV, fitness = 0.402011)}.
#  --> Population Cluster removed 116 (Energy: -104.977688 eV, fitness = 0.422167) {Replaced with Offspring 120 (Energy: -104.984051 eV, fitness = 0.427064)}.
#  --> Population Cluster removed 5 (Energy: -104.873081 eV, fitness = 0.349268) {Replaced with Offspring 128 (Energy: -104.884624 eV, fitness = 0.35665)}.
#  --> Population Cluster removed 77 (Energy: -105.12492 eV, fitness = 0.551261) {Replaced with Offspring 129 (Energy: -105.126466 eV, fitness = 0.552807)}.
#  --> Population Cluster removed 79 (Energy: -105.045138 eV, fitness = 0.477054) {Replaced with Offspring 132 (Energy: -105.059133 eV, fitness = 0.489308)}.
# *****************************
# 2. These offspring have a better energy and are energetically similar to two or more clusters in the population.
# 2. No offspring need to be removed from the offsprings list
# *****************************
# 3. The following offspring were removed from the offspring pool (and because they are energetically similar and have a lower energy to which cluster in the population):
# 3. The following offspring were removed from the offspring pool (and because they are energetically similar and have a lower energy to which cluster in the population):
#  --> Offspring 130 (Energy: -105.3137974829 eV, fitness = 0.776254) {Similar to Population Cluster 25 (Energy: -105.337897 eV, fitness = 0.810906)}.
#  --> Offspring 122 (Energy: -105.0689730777 eV, fitness = 0.498111) {Similar to Population Cluster 68 (Energy: -105.085944 eV, fitness = 0.513668)}.
#  --> Offspring 118 (Energy: -104.9904142216 eV, fitness = 0.432016) {Similar to Population Cluster 97 (Energy: -105.012034 eV, fitness = 0.449278)}.
#  --> Offspring 125 (Energy: -104.8103112387 eV, fitness = 0.311715) {Similar to Population Cluster 114 (Energy: -104.835249 eV, fitness = 0.326125)}.
# *****************************
# 4. Offspring that have have been removed for being energetically similar and have a lower energy to the rest of the other Offspring
# 4. Offspring that have have been removed for being energetically similar and have a lower energy to the rest of the other Offspring
#  --> Offspring 127 (Energy: -105.2833575329eV, fitness = 0.734594) {Similar to Offspring 121 (Energy: -105.301541757 eV, fitness = 0.759204)}.
#  --> Offspring 124 (Energy: -104.9594604604eV, fitness = 0.40845) {Similar to Offspring 120 (Energy: -104.9840514354 eV, fitness = 0.427064)}.
#  --> Offspring 131 (Energy: -104.8817383224eV, fitness = 0.35479) {Similar to Offspring 128 (Energy: -104.8846238343 eV, fitness = 0.35665)}.
# **********************************************************
# **********************************************************
# Time Information
# fitness_timer_1   = 0.00023674964904785156 seconds
# memory_operator_timer_1   = 4.363059997558594e-05 seconds
# predation_timer_1 = 0.4544358253479004 seconds
# fitness_timer_2   = 0.00011944770812988281 seconds
# ending_timer      = 0.02689385414123535 seconds
# The amount of time required for generation 7 is 1.266983985900879 seconds
# ----------------------------------------------------------
# Time elapsed: 00:00:16
# Date and Time: 2021-02-07 23:17:55.451140
#
#
# ----------------------------------------------------------
# ####################
# RUNNING GENERATION 8
# ####################
# -----------------------
# Making Offspring
# -----------------------
# Time taken to make offspring: 0.9322762489318848 s.
# Time taken to add offspring to Offspring_Pool: 5.626678466796875e-05 s.
# -----------------------
# **********************************************************
# **********************************************************
# Offspring removed from the Offspring Pool due to violating the Comprehensive Energy Diversity Scheme.
# NOTE: energy difference minimum = 0.025 eV.
# **********************************************************
# **********************************************************
# Assessing which structures to remove to comply with the Energy Diversity Scheme
# Start assessing for Energy Diversity
# Removing offspring that violate the Energy Diversity Scheme
# 1. Clusters in the Population that have been replaced by Offspring, due to the cluster in the offspring being energetically similar and having a lower energy than a offspring.
# 1. Clusters in the Population that have been replaced by Offspring, due to the cluster in the offspring being energetically similar and having a lower energy than a offspring.
#  --> Population Cluster removed 129 (Energy: -105.126466 eV, fitness = 0.349083) {Replaced with Offspring 135 (Energy: -105.130456 eV, fitness = 0.353593)}.
#  --> Population Cluster removed 117 (Energy: -104.950691 eV, fitness = 0.198294) {Replaced with Offspring 140 (Energy: -104.955886 eV, fitness = 0.201636)}.
#  --> Population Cluster removed 97 (Energy: -105.012034 eV, fitness = 0.241561) {Replaced with Offspring 144 (Energy: -105.023401 eV, fitness = 0.250559)}.
#  --> Population Cluster removed 112 (Energy: -104.803718 eV, fitness = 0.123576) {Replaced with Offspring 147 (Energy: -104.806638 eV, fitness = 0.124742)}.
# *****************************
# 2. These offspring have a better energy and are energetically similar to two or more clusters in the population.
# 2. No offspring need to be removed from the offsprings list
# *****************************
# 3. The following offspring were removed from the offspring pool (and because they are energetically similar and have a lower energy to which cluster in the population):
# 3. The following offspring were removed from the offspring pool (and because they are energetically similar and have a lower energy to which cluster in the population):
#  --> Offspring 136 (Energy: -105.2983292625 eV, fitness = 0.606852) {Similar to Population Cluster 121 (Energy: -105.301542 eV, fitness = 0.613157)}.
#  --> Offspring 146 (Energy: -105.2544776096 eV, fitness = 0.526995) {Similar to Population Cluster 67 (Energy: -105.264895 eV, fitness = 0.544959)}.
#  --> Offspring 141 (Energy: -105.1876311429 eV, fitness = 0.425009) {Similar to Population Cluster 50 (Energy: -105.192962 eV, fitness = 0.432361)}.
#  --> Offspring 138 (Energy: -105.0441849355 eV, fitness = 0.267888) {Similar to Population Cluster 132 (Energy: -105.059133 eV, fitness = 0.281087)}.
#  --> Offspring 143 (Energy: -104.9695193001 eV, fitness = 0.210678) {Similar to Population Cluster 120 (Energy: -104.984051 eV, fitness = 0.220762)}.
#  --> Offspring 148 (Energy: -104.9693991192 eV, fitness = 0.210596) {Similar to Population Cluster 120 (Energy: -104.984051 eV, fitness = 0.220762)}.
# *****************************
# 4. Offspring that have have been removed for being energetically similar and have a lower energy to the rest of the other Offspring
# 4. Offspring that have have been removed for being energetically similar and have a lower energy to the rest of the other Offspring
#  --> Offspring 139 (Energy: -105.0079741263eV, fitness = 0.238426) {Similar to Offspring 144 (Energy: -105.0234009102 eV, fitness = 0.250559)}.
#  --> Offspring 134 (Energy: -104.6486153371eV, fitness = 0.075024) {Similar to Offspring 133 (Energy: -104.6655227179 eV, fitness = 0.079219)}.
#  --> Offspring 145 (Energy: -104.5211715168eV, fitness = 0.049787) {Similar to Offspring 137 (Energy: -104.5437055491 eV, fitness = 0.053531)}.
# **********************************************************
# **********************************************************
# Time Information
# fitness_timer_1   = 0.00018930435180664062 seconds
# memory_operator_timer_1   = 5.5789947509765625e-05 seconds
# predation_timer_1 = 0.6699404716491699 seconds
# fitness_timer_2   = 0.0002148151397705078 seconds
# ending_timer      = 0.025811195373535156 seconds
# The amount of time required for generation 8 is 1.6401114463806152 seconds
# ----------------------------------------------------------
# Time elapsed: 00:00:17
# Date and Time: 2021-02-07 23:17:57.121875
#
#
# ----------------------------------------------------------
# ####################
# RUNNING GENERATION 9
# ####################
# -----------------------
# Making Offspring
# -----------------------
# Time taken to make offspring: 0.6328377723693848 s.
# Time taken to add offspring to Offspring_Pool: 3.790855407714844e-05 s.
# -----------------------
# **********************************************************
# **********************************************************
# Offspring removed from the Offspring Pool due to violating the Comprehensive Energy Diversity Scheme.
# NOTE: energy difference minimum = 0.025 eV.
# **********************************************************
# **********************************************************
# Assessing which structures to remove to comply with the Energy Diversity Scheme
# Start assessing for Energy Diversity
# Removing offspring that violate the Energy Diversity Scheme
# 1. Clusters in the Population that have been replaced by Offspring, due to the cluster in the offspring being energetically similar and having a lower energy than a offspring.
# 1. Clusters in the Population that have been replaced by Offspring, due to the cluster in the offspring being energetically similar and having a lower energy than a offspring.
#  --> Population Cluster removed 50 (Energy: -105.192962 eV, fitness = 0.32265) {Replaced with Offspring 151 (Energy: -105.201262 eV, fitness = 0.334487)}.
#  --> Population Cluster removed 59 (Energy: -105.223006 eV, fitness = 0.367595) {Replaced with Offspring 155 (Energy: -105.232515 eV, fitness = 0.383084)}.
#  --> Population Cluster removed 114 (Energy: -104.835249 eV, fitness = 0.068296) {Replaced with Offspring 161 (Energy: -104.85288 eV, fitness = 0.073728)}.
#  --> Population Cluster removed 120 (Energy: -104.984051 eV, fitness = 0.130289) {Replaced with Offspring 164 (Energy: -104.993393 eV, fitness = 0.135681)}.
# *****************************
# 2. These offspring have a better energy and are energetically similar to two or more clusters in the population.
# 2. No offspring need to be removed from the offsprings list
# *****************************
# 3. The following offspring were removed from the offspring pool (and because they are energetically similar and have a lower energy to which cluster in the population):
# 3. The following offspring were removed from the offspring pool (and because they are energetically similar and have a lower energy to which cluster in the population):
#  --> Offspring 150 (Energy: -105.4535615089 eV, fitness = 0.999993) {Similar to Population Cluster 106 (Energy: -105.453563 eV, fitness = 1.0)}.
#  --> Offspring 158 (Energy: -105.3619767911 eV, fitness = 0.671966) {Similar to Population Cluster 101 (Energy: -105.36307 eV, fitness = 0.675162)}.
#  --> Offspring 149 (Energy: -105.2927142633 eV, fitness = 0.497483) {Similar to Population Cluster 121 (Energy: -105.301542 eV, fitness = 0.516916)}.
#  --> Offspring 157 (Energy: -105.0769453626 eV, fitness = 0.194996) {Similar to Population Cluster 68 (Energy: -105.085944 eV, fitness = 0.202763)}.
#  --> Offspring 154 (Energy: -105.0398030373 eV, fitness = 0.165962) {Similar to Population Cluster 132 (Energy: -105.059133 eV, fitness = 0.180488)}.
#  --> Offspring 153 (Energy: -105.0396603573 eV, fitness = 0.165859) {Similar to Population Cluster 132 (Energy: -105.059133 eV, fitness = 0.180488)}.
#  --> Offspring 160 (Energy: -104.9016791033 eV, fitness = 0.091123) {Similar to Population Cluster 104 (Energy: -104.913049 eV, fitness = 0.095732)}.
# ...
# Time taken to add offspring to Offspring_Pool: 1.9550323486328125e-05 s.
# -----------------------
# **********************************************************
# **********************************************************
# Offspring removed from the Offspring Pool due to violating the Comprehensive Energy Diversity Scheme.
# NOTE: energy difference minimum = 0.025 eV.
# **********************************************************
# **********************************************************
# Assessing which structures to remove to comply with the Energy Diversity Scheme
# Start assessing for Energy Diversity
# Removing offspring that violate the Energy Diversity Scheme
# 1. Clusters in the Population that have been replaced by Offspring, due to the cluster in the offspring being energetically similar and having a lower energy than a offspring.
# 1. Clusters in the Population that have been replaced by Offspring, due to the cluster in the offspring being energetically similar and having a lower energy than a offspring.
#  --> Population Cluster removed 106 (Energy: -105.453563 eV, fitness = 0.999274) {Replaced with Offspring 168 (Energy: -105.453912 eV, fitness = 1.0)}.
#  --> Population Cluster removed 121 (Energy: -105.301542 eV, fitness = 0.728309) {Replaced with Offspring 170 (Energy: -105.308401 eV, fitness = 0.738777)}.
#  --> Population Cluster removed 93 (Energy: -105.404485 eV, fitness = 0.90227) {Replaced with Offspring 178 (Energy: -105.404488 eV, fitness = 0.902275)}.
#  --> Population Cluster removed 144 (Energy: -105.023401 eV, fitness = 0.408304) {Replaced with Offspring 180 (Energy: -105.03134 eV, fitness = 0.415105)}.
# *****************************
# 2. These offspring have a better energy and are energetically similar to two or more clusters in the population.
# 2. No offspring need to be removed from the offsprings list
# *****************************
# 3. The following offspring were removed from the offspring pool (and because they are energetically similar and have a lower energy to which cluster in the population):
# 3. The following offspring were removed from the offspring pool (and because they are energetically similar and have a lower energy to which cluster in the population):
#  --> Offspring 175 (Energy: -105.3395264295 eV, fitness = 0.788205) {Similar to Population Cluster 101 (Energy: -105.36307 eV, fitness = 0.827777)}.
#  --> Offspring 179 (Energy: -105.2260166218 eV, fitness = 0.622401) {Similar to Population Cluster 155 (Energy: -105.232515 eV, fitness = 0.630873)}.
#  --> Offspring 173 (Energy: -105.2193014465 eV, fitness = 0.613765) {Similar to Population Cluster 155 (Energy: -105.232515 eV, fitness = 0.630873)}.
#  --> Offspring 174 (Energy: -105.1257415216 eV, fitness = 0.505196) {Similar to Population Cluster 135 (Energy: -105.130456 eV, fitness = 0.510176)}.
#  --> Offspring 171 (Energy: -105.0462193247 eV, fitness = 0.428157) {Similar to Population Cluster 132 (Energy: -105.059133 eV, fitness = 0.439817)}.
#  --> Offspring 172 (Energy: -104.9797866273 eV, fitness = 0.372884) {Similar to Population Cluster 164 (Energy: -104.993393 eV, fitness = 0.383591)}.
# *****************************
# 4. Offspring that have have been removed for being energetically similar and have a lower energy to the rest of the other Offspring
# 4. Offspring that have have been removed for being energetically similar and have a lower energy to the rest of the other Offspring
#  --> Offspring 177 (Energy: -105.0239365355eV, fitness = 0.408759) {Similar to Offspring 180 (Energy: -105.0313400923 eV, fitness = 0.415105)}.
# **********************************************************
# **********************************************************
# Time Information
# fitness_timer_1   = 0.00040030479431152344 seconds
# memory_operator_timer_1   = 2.6226043701171875e-05 seconds
# predation_timer_1 = 0.5294637680053711 seconds
# fitness_timer_2   = 0.00010728836059570312 seconds
# ending_timer      = 0.018238067626953125 seconds
# The amount of time required for generation 10 is 1.395050048828125 seconds
# ----------------------------------------------------------
# Time elapsed: 00:00:20
# Date and Time: 2021-02-07 23:17:59.765568
#
#
# ----------------------------------------------------------
# #####################
# RUNNING GENERATION 11
# #####################
# -----------------------
# Making Offspring
# -----------------------
# Time taken to make offspring: 0.6365923881530762 s.
# Time taken to add offspring to Offspring_Pool: 2.0265579223632812e-05 s.
# -----------------------
# **********************************************************
# **********************************************************
# Offspring removed from the Offspring Pool due to violating the Comprehensive Energy Diversity Scheme.
# NOTE: energy difference minimum = 0.025 eV.
# **********************************************************
# **********************************************************
# Assessing which structures to remove to comply with the Energy Diversity Scheme
# Start assessing for Energy Diversity
# Removing offspring that violate the Energy Diversity Scheme
# 1. Clusters in the Population that have been replaced by Offspring, due to the cluster in the offspring being energetically similar and having a lower energy than a offspring.
# 1. Clusters in the Population that have been replaced by Offspring, due to the cluster in the offspring being energetically similar and having a lower energy than a offspring.
#  --> Population Cluster removed 104 (Energy: -104.913049 eV, fitness = 0.192919) {Replaced with Offspring 192 (Energy: -104.916899 eV, fitness = 0.19511)}.
#  --> Population Cluster removed 168 (Energy: -105.453912 eV, fitness = 0.942616) {Replaced with Offspring 194 (Energy: -105.474061 eV, fitness = 1.0)}.
# *****************************
# 2. These offspring have a better energy and are energetically similar to two or more clusters in the population.
# 2. No offspring need to be removed from the offsprings list
# *****************************
# 3. The following offspring were removed from the offspring pool (and because they are energetically similar and have a lower energy to which cluster in the population):
# 3. The following offspring were removed from the offspring pool (and because they are energetically similar and have a lower energy to which cluster in the population):
#  --> Offspring 187 (Energy: -105.2645943135 eV, fitness = 0.540977) {Similar to Population Cluster 67 (Energy: -105.264895 eV, fitness = 0.541454)}.
#  --> Offspring 189 (Energy: -105.1239171401 eV, fitness = 0.358081) {Similar to Population Cluster 135 (Energy: -105.130456 eV, fitness = 0.365015)}.
#  --> Offspring 184 (Energy: -105.0300356087 eV, fitness = 0.27189) {Similar to Population Cluster 180 (Energy: -105.03134 eV, fitness = 0.272933)}.
#  --> Offspring 181 (Energy: -105.0279632015 eV, fitness = 0.270243) {Similar to Population Cluster 180 (Energy: -105.03134 eV, fitness = 0.272933)}.
#  --> Offspring 182 (Energy: -104.8298376476 eV, fitness = 0.15114) {Similar to Population Cluster 161 (Energy: -104.85288 eV, fitness = 0.161707)}.
#  --> Offspring 186 (Energy: -104.797261553 eV, fitness = 0.137367) {Similar to Population Cluster 147 (Energy: -104.806638 eV, fitness = 0.141197)}.
#  --> Offspring 191 (Energy: -104.7916606882 eV, fitness = 0.135129) {Similar to Population Cluster 147 (Energy: -104.806638 eV, fitness = 0.141197)}.
# *****************************
# 4. Offspring that have have been removed for being energetically similar and have a lower energy to the rest of the other Offspring
# 4. Offspring that have have been removed for being energetically similar and have a lower energy to the rest of the other Offspring
#  --> Offspring 190 (Energy: -105.4331080596eV, fitness = 0.886817) {Similar to Offspring 195 (Energy: -105.4334585295 eV, fitness = 0.887729)}.
#  --> Offspring 193 (Energy: -104.6873618153eV, fitness = 0.099515) {Similar to Offspring 188 (Energy: -104.709308297 eV, fitness = 0.106132)}.
#  --> Offspring 183 (Energy: -104.5832062079eV, fitness = 0.073319) {Similar to Offspring 196 (Energy: -104.6066673499 eV, fitness = 0.078542)}.
# **********************************************************
# **********************************************************
# Time Information
# fitness_timer_1   = 0.00017786026000976562 seconds
# memory_operator_timer_1   = 2.7418136596679688e-05 seconds
# predation_timer_1 = 0.18833708763122559 seconds
# fitness_timer_2   = 8.630752563476562e-05 seconds
# ending_timer      = 0.017681598663330078 seconds
# The amount of time required for generation 11 is 0.9427294731140137 seconds
# ----------------------------------------------------------
# Time elapsed: 00:00:21
# Date and Time: 2021-02-07 23:18:00.725527
#
#
# ----------------------------------------------------------
# #####################
# RUNNING GENERATION 12
# #####################
# -----------------------
# Making Offspring
# -----------------------
# Time taken to make offspring: 0.9352872371673584 s.
# Time taken to add offspring to Offspring_Pool: 2.0742416381835938e-05 s.
# -----------------------
# **********************************************************
# **********************************************************
# Offspring removed from the Offspring Pool due to violating the Comprehensive Energy Diversity Scheme.
# NOTE: energy difference minimum = 0.025 eV.
# **********************************************************
# **********************************************************
# Assessing which structures to remove to comply with the Energy Diversity Scheme
# Start assessing for Energy Diversity
# Removing offspring that violate the Energy Diversity Scheme
# 1. Clusters in the Population that have been replaced by Offspring, due to the cluster in the offspring being energetically similar and having a lower energy than a offspring.
# 1. Clusters in the Population that have been replaced by Offspring, due to the cluster in the offspring being energetically similar and having a lower energy than a offspring.
#  --> Population Cluster removed 194 (Energy: -105.474061 eV, fitness = 0.999427) {Replaced with Offspring 205 (Energy: -105.474436 eV, fitness = 1.0)}.
#  --> Population Cluster removed 192 (Energy: -104.916899 eV, fitness = 0.42644) {Replaced with Offspring 210 (Energy: -104.930697 eV, fitness = 0.43553)}.
# *****************************
# 2. These offspring have a better energy and are energetically similar to two or more clusters in the population.
# 2. No offspring need to be removed from the offsprings list
# *****************************
# 3. The following offspring were removed from the offspring pool (and because they are energetically similar and have a lower energy to which cluster in the population):
# 3. The following offspring were removed from the offspring pool (and because they are energetically similar and have a lower energy to which cluster in the population):
#  --> Offspring 202 (Energy: -105.3453987525 eV, fitness = 0.820982) {Similar to Population Cluster 101 (Energy: -105.36307 eV, fitness = 0.843462)}.
#  --> Offspring 211 (Energy: -105.3000381522 eV, fitness = 0.765984) {Similar to Population Cluster 170 (Energy: -105.308401 eV, fitness = 0.775838)}.
#  --> Offspring 208 (Energy: -105.1600928712 eV, fitness = 0.61846) {Similar to Population Cluster 64 (Energy: -105.163713 eV, fitness = 0.621891)}.
#  --> Offspring 204 (Energy: -105.1099270238 eV, fitness = 0.572805) {Similar to Population Cluster 135 (Energy: -105.130456 eV, fitness = 0.591066)}.
#  --> Offspring 197 (Energy: -104.8792485369 eV, fitness = 0.402589) {Similar to Population Cluster 128 (Energy: -104.884624 eV, fitness = 0.405911)}.
# *****************************
# 4. Offspring that have have been removed for being energetically similar and have a lower energy to the rest of the other Offspring
# 4. Offspring that have have been removed for being energetically similar and have a lower energy to the rest of the other Offspring
#  --> Offspring 212 (Energy: -104.779763961eV, fitness = 0.345792) {Similar to Offspring 209 (Energy: -104.7812378803 eV, fitness = 0.346572)}.
# **********************************************************
# **********************************************************
# Time Information
# fitness_timer_1   = 0.00020241737365722656 seconds
# memory_operator_timer_1   = 2.2411346435546875e-05 seconds
# predation_timer_1 = 0.23466706275939941 seconds
# fitness_timer_2   = 9.393692016601562e-05 seconds
# ending_timer      = 0.025016307830810547 seconds
# The amount of time required for generation 12 is 1.205702781677246 seconds
# ----------------------------------------------------------
# Time elapsed: 00:00:22
# Date and Time: 2021-02-07 23:18:01.953405
#
#
# ----------------------------------------------------------
# #####################
# RUNNING GENERATION 13
# #####################
# -----------------------
# Making Offspring
# Process ForkPoolWorker-26:
# Local Optimiser Failed for some reason.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-a9c28b2557b0> in <module>
#      25     no_of_cpus=no_of_cpus,
#      26     finish_algorithm_if_found_cluster_energy=finish_algorithm_if_found_cluster_energy,
# ---> 27     total_length_of_running_time=total_length_of_running_time)
#      28 ''' ---------------- '''
#
# ~/Desktop/Organisms/Organisms_v3.2.1/Organisms/GA/GA_Program.py in __init__(self, cluster_makeup, pop_size, generations, no_offspring_per_generation, creating_offspring_mode, crossover_type, mutation_types, chance_of_mutation, r_ij, vacuum_to_add_length, Minimisation_Function, surface_details, epoch_settings, cell_length, memory_operator_information, predation_information, fitness_information, ga_recording_information, force_replace_pop_clusters_with_offspring, user_initialised_population_folder, rounding_criteria, print_details, no_of_cpus, finish_algorithm_if_found_cluster_energy, total_length_of_running_time)
#      88                 GA_Initiate(self)
#      89                 # Run the main component of the GA
# ---> 90                 self.run_GA()
#      91                 ##########################################################################################################
#      92                 ##########################################################################################################
#
# ~/Desktop/Organisms/Organisms_v3.2.1/Organisms/GA/GA_Program.py in run_GA(self)
#     123                         start_time = time()
#     124                         # Get all offspring for this generation
# --> 125                         self.previous_cluster_name = self.get_offsprings(self.previous_cluster_name,generation_number)
#     126                         all_energies_of_offpsring = self.offspring_pool.get_cluster_energies()
#     127                         check_names_2(self.population,self.offspring_pool)
#
# ~/Desktop/Organisms/Organisms_v3.2.1/Organisms/GA/GA_Program.py in get_offsprings(self, previous_cluster_name, generation_number)
#     326                         with mp.Pool(processes=self.no_of_cpus) as pool: # pool = mp.Pool()
#     327                                 results = pool.map_async(Create_An_Offspring, tasks)
# --> 328                                 results.wait()
#     329                         offsprings = results.get()
#     330                 end_time = time()
#
# /usr/lib/python3.6/multiprocessing/pool.py in wait(self, timeout)
#     633
#     634     def wait(self, timeout=None):
# --> 635         self._event.wait(timeout)
#     636
#     637     def get(self, timeout=None):
#
# /usr/lib/python3.6/threading.py in wait(self, timeout)
#     549             signaled = self._flag
#     550             if not signaled:
# --> 551                 signaled = self._cond.wait(timeout)
#     552             return signaled
#     553
#
# /usr/lib/python3.6/threading.py in wait(self, timeout)
#     293         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#     297             else:
#
# KeyboardInterrupt:

# %%
[Back To Table of Contents](../Organisms_Jupyter_Example.ipynb)
