# %% [markdown]
# # A Basic Example for Optimising a 37 atom Copper Cluster with Organisms

# %% [markdown]
# [Back To Table of Contents](../Organisms_Jupyter_Example.ipynb)

# %% [markdown]
# In this example, we will perform a genetic algorithm optimisation on the 37 atom Lennard-Jones (Cu<sub>37</sub>) cluster. In this example, we will perform a genetic algorithm with a simple energy predation operator, the energy fitness operator, and a population-based epoch method. We will go through step by step all the components of the *Run.py* files required to run Organisms on LJ<sub>38</sub>. See [organisms.readthedocs.io/en/latest/Using_Run](https://organisms.readthedocs.io/en/latest/Using_Run.html) for more information on the *Run.py* file.
#
# To run this notebook step by step, press the $\blacktriangleright$ button sequentially on the python code you want to run. You can find the $\blacktriangleright$ button in the menu bar above. Make sure you have run $\blacktriangleright$ on every cell before running the ``GA_Program`` execution cell. Equivalently, press the $\blacktriangleright\blacktriangleright$ button to completely run this *Run.py* file beginning to end. You can also find the $\blacktriangleright\blacktriangleright$ button in the menu bar above.
#
# Note: These are the vanilla settings for running Organisms on a Cu<sub>37</sub> nanocluster, but feel free to change the settings as you wish.
#
# Also note: This program makes files which are created and stored on the Binder server. If you want to rerun this example, you will need to remove these files. The following block code will do this. This is only needed for this notebook and is not apart of *Run.py* script.

# %%
import os
from shutil import rmtree
to_be_removed_before_restarting_Jupyter_example = []
to_be_removed_before_restarting_Jupyter_example += ['epoch_data','epoch_data.backup','GA_Run_Details.txt','ga_running.lock']
to_be_removed_before_restarting_Jupyter_example += ['Population','Recorded_Data','Initial_Population','Saved_Points_In_GA_Run','Memory_Operator_Data','Diversity_Information']
to_be_removed_before_restarting_Jupyter_example += ['__pycache__']
for example_file_or_folder in to_be_removed_before_restarting_Jupyter_example:
    if os.path.exists(example_file_or_folder):
        if os.path.isdir(example_file_or_folder):
            rmtree(example_file_or_folder)
        else:
            os.remove(example_file_or_folder)

# %% [markdown]
# ## Setting up the *Run.py* Script for a Global Optimisation of a 37 atom Copper Nanocluster

# %% [markdown]
# The following contains all the options that you desire to set up the Organisms program to global optimise a Cu<sub>37</sub> nanocluster. These are the vanilla settings, but feel free to change them as you wish.

# %%
from Organisms import GA_Program

# This details the elemental and number of atom composition of cluster that the user would like to investigate
cluster_makeup = {"Cu": 37}

# Surface details
surface_details = None #{'surface': 'surface.xyz', 'place_cluster_where': 'center'}

# These are the main variables of the genetic algorithm that with changes could affect the results of the Genetic Algorithm.
pop_size = 20
generations = 50
no_offspring_per_generation = 16

# These setting indicate how offspring should be made using the Mating and Mutation Proceedures
creating_offspring_mode = "Either_Mating_and_Mutation" 
crossover_type = "CAS_weighted"
mutation_types = [['random', 1.0]]
chance_of_mutation = 0.1

# This parameter will tell the Organisms program if an epoch is desired, and how the user would like to proceed.
epoch_settings = {'epoch mode': 'same population', 'max repeat': 5}

# These are variables used by the algorithm to make and place clusters in.
r_ij = 3.4
cell_length = r_ij * (sum([float(noAtoms) for noAtoms in list(cluster_makeup.values())]) ** (1.0/3.0))
vacuum_to_add_length = 10.0

# The RunMinimisation.py algorithm is one set by the user. It contain the def Minimisation_Function
# That is used for local optimisations. This can be written in whatever way the user wants to perform
# the local optimisations. This is meant to be as free as possible.
from RunMinimisation_Cu import Minimisation_Function

# This dictionary includes the information required to prevent clusters being placed in the population if they are too similar to clusters in this memory_operator
memory_operator_information = {'Method': 'Off'}

# This switch tells the genetic algorithm the type of predation scheme they want to place on the genetic algoithm.
#predation_information = {'Predation Operator':'Off'}
#predation_information = {'Predation Operator':'Energy', 'mode': 'simple', 'round_energy': 2}
#predation_information = {'Predation Operator':'Energy', 'mode': 'comprehensive', 'minimum_energy_diff': 0.025, 'type_of_comprehensive_scheme': 'energy'}
predation_information = {'Predation Operator':'Energy', 'mode': 'comprehensive', 'minimum_energy_diff': 0.025, 'type_of_comprehensive_scheme': 'fitness'}
#predation_information = {'Predation Operator': 'IDCM', 'percentage_diff': 5.0}
#predation_information = {'Predation Operator': 'SCM', 'CNA Scheme': 'T-SCM', 'rCut_high': 3.2, 'rCut_low': 2.9, 'rCut_resolution': 0.05}

# This switch tells the genetic algorithm the type of fitness scheme they want to place on the genetic algoithm.
energy_fitness_function = {'function': 'exponential', 'alpha': 3.0}
#SCM_fitness_function = {'function': 'exponential', 'alpha': 1.0}
fitness_information = {'Fitness Operator': 'Energy', 'fitness_function': energy_fitness_function}
#fitness_information = {'Fitness Operator': 'SCM + Energy', 'Use Predation Information': True, 'SCM_fitness_contribution': 0.5, 'normalise_similarities': False, 'Dynamic Mode': False, 'energy_fitness_function': energy_fitness_function, 'SCM_fitness_function': SCM_fitness_function}
#fitness_information = {'Fitness Operator': 'SCM + Energy', 'CNA Scheme': 'T-SCM', 'rCut_high': 3.2, 'rCut_low': 2.9, 'rCut_resolution': 0.05, 'SCM_fitness_contribution': 0.5, 'normalise_similarities': False, 'Dynamic Mode': False, 'energy_fitness_function': energy_fitness_function, 'SCM_fitness_function': SCM_fitness_function}
#fitness_information = {'Fitness Operator': 'SCM + Energy', 'CNA Scheme': 'T-SCM', 'rCut': 3.05, 'SCM_fitness_contribution': 0.5, 'normalise_similarities': False, 'Dynamic Mode': False, 'energy_fitness_function': energy_fitness_function, 'SCM_fitness_function': SCM_fitness_function}

# Variables required for the Recording_Cluster.py class/For recording the history as required of the genetic algorithm.
ga_recording_information = {}
#ga_recording_information['ga_recording_scheme'] = 'Limit_energy_height' # float('inf')
#ga_recording_information['limit_number_of_clusters_recorded'] = 5 # float('inf')
#ga_recording_information['limit_energy_height_of_clusters_recorded'] = 1.5 #eV
#ga_recording_information['exclude_recording_cluster_screened_by_diversity_scheme'] = True
#ga_recording_information['record_initial_population'] = True
#ga_recording_information['saving_points_of_GA'] = [3,5]
ga_recording_information = {'ga_recording_scheme': 'Limit_energy_height', 'limit_number_of_clusters_recorded': 1, 'limit_energy_height_of_clusters_recorded': 1.0, 'exclude_recording_cluster_screened_by_diversity_scheme': False}

# These are last techinical points that the algorithm is designed in mind
force_replace_pop_clusters_with_offspring = True
user_initialised_population_folder = None 
rounding_criteria = 10
print_details = True
no_of_cpus = 1
finish_algorithm_if_found_cluster_energy = None
total_length_of_running_time = None

# %% [markdown]
# [Back To Table of Contents](../Organisms_Jupyter_Example.ipynb)

# %% [markdown]
# ## The Genetic Algorithm!
#
# You have got to the end of all the parameter setting stuff! Now on to the fun stuff! The next part of the Run.py file tells the genetic algorithm to run. This is written as follows in the Run.py. Note this may take a bit of time to run depending on your settings. Running the below code and good and get yourself a tea or coffee.

# %%
''' ---------------- '''
# This will execute the genetic algorithm program
GA_Program(cluster_makeup=cluster_makeup,
    pop_size=pop_size,
    generations=generations,
    no_offspring_per_generation=no_offspring_per_generation,
    creating_offspring_mode=creating_offspring_mode,
    crossover_type=crossover_type,
    mutation_types=mutation_types,
    chance_of_mutation=chance_of_mutation,
    r_ij=r_ij,
    vacuum_to_add_length=vacuum_to_add_length,
    Minimisation_Function=Minimisation_Function,
    surface_details=surface_details,
    epoch_settings=epoch_settings,
    cell_length=cell_length,
    memory_operator_information=memory_operator_information,
    predation_information=predation_information,
    fitness_information=fitness_information,
    ga_recording_information=ga_recording_information,
    force_replace_pop_clusters_with_offspring=force_replace_pop_clusters_with_offspring,
    user_initialised_population_folder=user_initialised_population_folder,
    rounding_criteria=rounding_criteria,
    print_details=print_details,
    no_of_cpus=no_of_cpus,
    finish_algorithm_if_found_cluster_energy=finish_algorithm_if_found_cluster_energy,
    total_length_of_running_time=total_length_of_running_time)
''' ---------------- '''
# Out:
# ############################################################
# ############################################################
# ############################################################
# The Otago Research Genetic Algorithm for Nanoclusters, Including Structural Methods and Similarity (Organisms) Program
#
# .--------------------------------------------------------------------------.
# |                             ,                                            |
# |              ,_     ,     .'<_                                           |
# |             _> `'-,'(__.-' __<                                           |
# |             >_.--(.. )  =;`                                   _          |
# |                  `V-'`'\/``                                  ('>         |
# |                                                              /))@@@@@.   |
# |         .----------------------------------.                /@"@@@@@()@  |
# |         | Welcome to the Organisms program |               .@@()@@()@@@@ |
# |         '----------------------------------'               @@@O@@@@()@@@ |
# |                  ^                                         @()@@\@@@()@@ |
# |  _     (\_/)     |                                          @()@||@@@@@' |
# | ( \    (0.o) ----'                 _                         '@@||@@@'   |
# |  ) )   (> <)                     _(_)_            wWWWw   _     ||       |
# | ( (  .-'''''-.  A.-.A      @@@@ (_)@(_)       _   (___) _(_)_   ||       |
# |  \ \/         \/ , , \    @@()@@  (_)\      _(_)_   Y  (_)@(_)  ||       |
# |   \   \        ;= t =/     @@@@      `|/   (_)@(_) \|/   (_)\   ||       |
# |    \   |'''''-   ,--'       /        \|     /(_)    |/      |   ||       |
# |     / //     | ||        \ |          | / \|/      \|      \|/  ||       |
# |    /_,))     |_'))       \\|//     \\\|// \|///   \\|//  \\\|// ||       |
# |^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^|
# '--------------------------------------------------------------------------'
#
# Version: 3.2.7
# ############################################################
# ############################################################
#
# This algorithm is designed to perform a genetic algorithm to obtain low energetic structures for a given cluster composition.
#
# This genetic algorithm will proceed with the following input parameters
#
# # This details the elemental and number of atom composition of cluster that the user would like to investigate
# cluster_makeup = {'Cu': 37}
#
# # This details the information used to perform a global optimisation upon a chosen surface
# surface_details = None
#
# # These are the main variables of the genetic algorithm that with changes could affect the results of the Genetic Algorithm.
# pop_size = 20
# generations = 30
# no_offspring_per_generation = 16
#
# # These setting indicate how offspring should be made using the Mating and Mutation Proceedures
# creating_offspring_mode = Either_Mating_and_Mutation
# crossover_type = CAS_weighted
# mutation_types = [['random', 1.0]]
# mutation_types = 0.1
#
# # These are variables used by the algorithm to make and place clusters in.
# r_ij = 3.4 Angstroms (This is the maximum possible bond length between two atoms in the cluster)
# cell_length = 11.329554295596239 Angstroms
# vacuum_to_add_length = 10.0 Angstroms
#
# # The RunMinimisation.py algorithm is one set by the user. It contain the def Minimisation_Function
# # That is used for local optimisations. This can be written in whatever way the user wants to perform
# # the local optimisations. This is meant to be as free as possible.
# Minimisation_Function = <function Minimisation_Function at 0x7fc958508af0>
# Path of Minimisation_Function: /mnt/hgfs/GoogleDrive/PhDWork/Programs/OptimisationAlgorithms/GeneticAlgorithm/Organisms/Organisms_Jupyter_Examples/Notebooks/Example_of_Cu37/RunMinimisation_Cu.py
#
# # This details the information about the memory operator used in this genetic algorithm.
# memory_operator = {'method': 'Off'}
#
# # This details the information about the predation operator used in this genetic algorithm.
# predation_operator = {'predation_information': {'Predation Operator': 'Energy', 'mode': 'comprehensive', 'minimum_energy_diff': 0.025, 'type_of_comprehensive_scheme': 'fitness'}, 'Predation_Switch': 'Energy', 'population': <Collection: Population> current size: 0; Clusters: [], 'print_details': False, 'mode': 'comprehensive', 'type_of_comprehensive_scheme': 'fitness', 'minimum_energy_diff': 0.025, 'check_initial_population_imported': <function check_initial_population at 0x7fc92849c790>, 'assess_for_violations_force_replacement_imported': <function assess_for_violations_force_replacement at 0x7fc9284a11f0>, 'assess_for_violations_no_force_replacement_imported': <function assess_for_violations_no_force_replacement at 0x7fc9284a1160>}
#
# # This details the information about the fitness operator used in this genetic algorithm.
# fitness_operator = {'fitness_switch': 'Energy', 'fitness_information': {'Fitness Operator': 'Energy', 'fitness_function': {'function': 'exponential', 'alpha': 3.0}, 'Use Predation Information': False}, 'population': <Collection: Population> current size: 0; Clusters: [], 'print_details': False, 'previous_max_energy': -inf, 'previous_min_energy': inf, 'energy_fitness_function': <Organisms.GA.Fitness_Operators.Fitness_Function.Fitness_Function object at 0x7fc928484ac0>}
#
# # This parameter will tell the Organisms program if an epoch is desired, and how the user would like to proceed.
# epoch_settings: {'path': '/mnt/hgfs/GoogleDrive/PhDWork/Programs/OptimisationAlgorithms/GeneticAlgorithm/Organisms/Organisms_Jupyter_Examples/Notebooks/Example_of_Cu37', 'epoch_data_name': 'epoch_data', 'backup_epoch_data_name': 'epoch_data.backup', 'epoch_settings': {'epoch mode': 'same population', 'max repeat': 5}, 'epoch_mode': 'same population', 'max_number_of_times_non_changing_population': 5, 'epoch_function': <bound method Epoch.should_epoch_using_same_population_epoch of {...}>, 'perform_epoch_function': <bound method Epoch.perform_epoch_same_population of {...}>, 'first_epoch_to_change_fitness_function': False}
#
# # Variables required for the GA_Recording_System.py class/For recording the history as required of the genetic algorithm.
# ga_recording_system = {'ga_recording_information': {'ga_recording_scheme': 'Limit_energy_height', 'limit_number_of_clusters_recorded': 1, 'limit_energy_height_of_clusters_recorded': 1.0, 'exclude_recording_cluster_screened_by_diversity_scheme': False}, 'ga_recording_scheme': 'Limit_energy_height', 'ga_recording_system_name': 'Recorded_Data', 'path_to_write_to': '/mnt/hgfs/GoogleDrive/PhDWork/Programs/OptimisationAlgorithms/GeneticAlgorithm/Organisms/Organisms_Jupyter_Examples/Notebooks/Example_of_Cu37/Recorded_Data', 'exclude_recording_cluster_screened_by_diversity_scheme': False, 'limit_number_of_clusters_recorded': 1, 'limit_size_of_database': None, 'show_GA_Recording_Database_check_percentage': False, 'limit_energy_height_of_clusters_recorded': 1.0, 'clusters_database': <Collection: GA_Recording_Database> current size: 0; Clusters: [], 'directory': '/mnt/hgfs/GoogleDrive/PhDWork/Programs/OptimisationAlgorithms/GeneticAlgorithm/Organisms/Organisms_Jupyter_Examples/Notebooks/Example_of_Cu37/Recorded_Data', 'RC_Information_TXT_name': 'Recorded_Data_Information.txt', 'record_initial_population': False, 'saving_points_of_GA': []}
#
# # These are last techinical points that the algorithm is designed in mind
# force_replace_pop_clusters_with_offspring = True
# user_initialised_population_folder = None
# rounding_criteria = 10
# print_details = True
# no_of_cpus = 1
# finish_algorithm_if_found_cluster_energy = None
# total_length_of_running_time: Indefinitely
#
# ############################################################
# ############################################################
# ############################################################
# ################################################################################################################
# ################################################################################################################
# Initalising a Starting Population of Clusters if required to take pool up to a size of 20
# Pool size to begin = 0
# Checking to see if the user has any clusters in the folder None that the user would like to have inputted into the initalise population.
# ################################################################################################################
# Will now population the next 20 with randomly generated clusters.
# -----------------------------
# Checking that the clusters in the population satisfies the Diversity Scheme
# *****************************
# *****************************
# Diversity Scheme located "duplicates" in creating population.
# Recreating clusters: [3, 17, 18]
# -----------------------------
# Checking that the clusters in the population satisfies the Diversity Scheme
# Have finished populating the rest of the population with 0 randomly generated clusters.
# The population has been successfully initialised.
# ################################################################################################################
# ################################################################################################################
# Time elapsed: 00:00:11
# Date and Time: 2021-03-23 03:02:22.250496
# -----------------------------
# -----------------------------
# Starting Genetic Algorithm
# -----------------------------
# -----------------------------
#
#
#
# ----------------------------------------------------------
# ####################
# RUNNING GENERATION 1
# ####################
# -----------------------
# Making Offspring
# -----------------------
# Time taken to make offspring: 2.006643533706665 s.
# Details of created offsprings
# Time taken to add offspring to Offspring_Pool: 0.0005688667297363281 s.
# -----------------------
# **********************************************************
# **********************************************************
# Offspring removed from the Offspring Pool due to violating the Comprehensive Energy Diversity Scheme.
# NOTE: energy difference minimum = 0.025 eV.
# **********************************************************
# **********************************************************
# Assessing which structures to remove to comply with the Energy Diversity Scheme
# Start assessing for Energy Diversity
# Removing offspring that violate the Energy Diversity Scheme
# 1. Clusters in the Population that have been replaced by Offspring, due to the cluster in the offspring being energetically similar and having a lower energy than a offspring.
# 1. Clusters in the Population that have been replaced by Offspring, due to the cluster in the offspring being energetically similar and having a lower energy than a offspring.
#  --> Population Cluster removed 12 (Energy: -105.019701 eV, fitness = 0.550432) {Replaced with Offspring 23 (Energy: -105.024346 eV, fitness = 0.553649)}.
#  --> Population Cluster removed 7 (Energy: -104.748521 eV, fitness = 0.391682) {Replaced with Offspring 29 (Energy: -104.758219 eV, fitness = 0.396478)}.
#  --> Population Cluster removed 13 (Energy: -105.306093 eV, fitness = 0.788429) {Replaced with Offspring 35 (Energy: -105.317056 eV, fitness = 0.799349)}.
# *****************************
# 2. These offspring have a better energy and are energetically similar to two or more clusters in the population.
# 2. No offspring need to be removed from the offsprings list
# *****************************
# 3. The following offspring were removed from the offspring pool (and because they are energetically similar and have a lower energy to which cluster in the population):
# 3. The following offspring were removed from the offspring pool (and because they are energetically similar and have a lower energy to which cluster in the population):
#  --> Offspring 36 (Energy: -104.4208219609 eV, fitness = 0.259637) {Similar to Population Cluster 16 (Energy: -104.431038 eV, fitness = 0.262986)}.
#  --> Offspring 34 (Energy: -103.9327130037 eV, fitness = 0.140731) {Similar to Population Cluster 18 (Energy: -103.937231 eV, fitness = 0.141531)}.
# *****************************
# 4. Offspring that have have been removed for being energetically similar and have a lower energy to the rest of the other Offspring
# 4. Offspring that have have been removed for being energetically similar and have a lower energy to the rest of the other Offspring
#  --> Offspring 30 (Energy: -105.2926157185eV, fitness = 0.775208) {Similar to Offspring 35 (Energy: -105.3170559896 eV, fitness = 0.799349)}.
#  --> Offspring 25 (Energy: -105.1198058959eV, fitness = 0.624097) {Similar to Offspring 22 (Energy: -105.1248079506 eV, fitness = 0.628026)}.
#  --> Offspring 32 (Energy: -104.6773165925eV, fitness = 0.358207) {Similar to Offspring 27 (Energy: -104.6842963252 eV, fitness = 0.361357)}.
#  --> Offspring 26 (Energy: -104.5284455888eV, fitness = 0.297175) {Similar to Offspring 33 (Energy: -104.5485186099 eV, fitness = 0.304754)}.
# **********************************************************
# **********************************************************
# -----------------------------
# ****---------------------****
# Natural Selection for Generation 1
# --------------------------------------------------------------------------
# <Collection: Population> current size: 20
# Cluster:
# --------------------------------------------------------------------------
#
# Offspring that replace clusters in population due to fitness.
# Replacing Cluster 18(fitness = 0.049) with Offspring 47(fitness = 0.837)
# Replacing Cluster 10(fitness = 0.052) with Offspring 52(fitness = 0.31)
# Replacing Cluster 20(fitness = 0.055) with Offspring 41(fitness = 0.282)
# Replacing Cluster 5(fitness = 0.069) with Offspring 45(fitness = 0.228)
# Replacing Cluster 8(fitness = 0.088) with Offspring 43(fitness = 0.14)
# ****---------------------****
# <Collection: Population> current size: 20; Clusters: [Cluster_38, Cluster_2, Cluster_21, Cluster_28, Cluster_45, Cluster_22, Cluster_29, Cluster_43, Cluster_31, Cluster_52, Cluster_50, Cluster_23, Cluster_49, Cluster_14, Cluster_33, Cluster_39, Cluster_17, Cluster_47, Cluster_24, Cluster_41]
# Time Information
# fitness_timer_1   = 0.0003273487091064453 seconds
# memory_operator_timer_1   = 1.5974044799804688e-05 seconds
# predation_timer_1 = 5.693798780441284 seconds
# fitness_timer_2   = 0.00011181831359863281 seconds
# ending_timer      = 0.04722023010253906 seconds
# The amount of time required for generation 2 is 10.08029556274414 seconds
# ----------------------------------------------------------
# Time elapsed: 00:00:29
# Date and Time: 2021-03-23 03:02:40.502264
#
#
# ----------------------------------------------------------
# ####################
# RUNNING GENERATION 3
# ####################
# -----------------------
# Making Offspring
# -----------------------
# Time taken to make offspring: 2.612196207046509 s.
# Details of created offsprings
# Time taken to add offspring to Offspring_Pool: 0.0002455711364746094 s.
# -----------------------
# **********************************************************
# **********************************************************
# Offspring removed from the Offspring Pool due to violating the Comprehensive Energy Diversity Scheme.
# NOTE: energy difference minimum = 0.025 eV.
# **********************************************************
# **********************************************************
# Assessing which structures to remove to comply with the Energy Diversity Scheme
# Start assessing for Energy Diversity
# Removing offspring that violate the Energy Diversity Scheme
# 1. Clusters in the Population that have been replaced by Offspring, due to the cluster in the offspring being energetically similar and having a lower energy than a offspring.
# 1. Clusters in the Population that have been replaced by Offspring, due to the cluster in the offspring being energetically similar and having a lower energy than a offspring.
#  --> Population Cluster removed 2 (Energy: -104.61727 eV, fitness = 0.368566) {Replaced with Offspring 54 (Energy: -104.624109 eV, fitness = 0.371442)}.
#  --> Population Cluster removed 29 (Energy: -104.758219 eV, fitness = 0.432596) {Replaced with Offspring 56 (Energy: -104.770003 eV, fitness = 0.438429)}.
#  --> Population Cluster removed 49 (Energy: -105.324899 eV, fitness = 0.823708) {Replaced with Offspring 57 (Energy: -105.330122 eV, fitness = 0.828612)}.
#  --> Population Cluster removed 47 (Energy: -105.403633 eV, fitness = 0.900811) {Replaced with Offspring 66 (Energy: -105.404361 eV, fitness = 0.901556)}.
#  --> Population Cluster removed 41 (Energy: -104.83853 eV, fitness = 0.473937) {Replaced with Offspring 68 (Energy: -104.858544 eV, fitness = 0.48484)}.
# *****************************
# 2. These offspring have a better energy and are energetically similar to two or more clusters in the population.
# 2. No offspring need to be removed from the offsprings list
# *****************************
# 3. The following offspring were removed from the offspring pool (and because they are energetically similar and have a lower energy to which cluster in the population):
# 3. The following offspring were removed from the offspring pool (and because they are energetically similar and have a lower energy to which cluster in the population):
#  --> Offspring 63 (Energy: -105.475483607 eV, fitness = 0.977453) {Similar to Population Cluster 28 (Energy: -105.49555 eV, fitness = 1.0)}.
#  --> Offspring 60 (Energy: -105.1245269243 eV, fitness = 0.65596) {Similar to Population Cluster 22 (Energy: -105.124808 eV, fitness = 0.65617)}.
#  --> Offspring 64 (Energy: -105.0315695869 eV, fitness = 0.590198) {Similar to Population Cluster 21 (Energy: -105.05474 eV, fitness = 0.605946)}.
#  --> Offspring 55 (Energy: -105.0153130431 eV, fitness = 0.579394) {Similar to Population Cluster 23 (Energy: -105.024346 eV, fitness = 0.585373)}.
#  --> Offspring 67 (Energy: -104.9248452941 eV, fitness = 0.522784) {Similar to Population Cluster 50 (Energy: -104.938487 eV, fitness = 0.530953)}.
# *****************************
# 4. Offspring that have have been removed for being energetically similar and have a lower energy to the rest of the other Offspring
# 4. No offspring have been removed from the rest of the offsprings list for being too similar
# **********************************************************
# **********************************************************
# -----------------------------
# ****---------------------****
# Natural Selection for Generation 3
# --------------------------------------------------------------------------
# <Collection: Population> current size: 20
# Cluster: 38; Energy: -104.7015337556; Fitness: 0.4056064553893576
# Cluster: 54; Energy: -104.6241092393; Fitness: 0.3714421300696445
# Cluster: 21; Energy: -105.0547400385; Fitness: 0.6059455393143491
# Cluster: 28; Energy: -105.4955498812; Fitness: 1.0
# Cluster: 45; Energy: -104.7279096553; Fitness: 0.41794868720805
# Cluster: 22; Energy: -105.1248079506; Fitness: 0.656169982950103
# Cluster: 56; Energy: -104.7700034769; Fitness: 0.4384285435419682
# Cluster: 43; Energy: -104.4757152107; Fitness: 0.3137976616421487
# Cluster: 31; Energy: -104.5066696996; Fitness: 0.32503312375166243
# Cluster: 52; Energy: -104.8873036511; Fitness: 0.500949070299787
# Cluster: 50; Energy: -104.9384874293; Fitness: 0.5309527512012978
# Cluster: 23; Energy: -105.0243461159; Fitness: 0.5853725424878533
# Cluster: 57; Energy: -105.3301222089; Fitness: 0.8286123558524154
# Cluster: 14; Energy: -104.3602231604; Fitness: 0.2751993271306003
# Cluster: 33; Energy: -104.5485186099; Fitness: 0.34086514776917204
# Cluster: 39; Energy: -104.4313523877; Fitness: 0.2983691779471711
# Cluster: 17; Energy: -104.3300790351; Fitness: 0.2659312730594775
# Cluster: 66; Energy: -105.4043613535; Fitness: 0.9015564565281591
# Cluster: 24; Energy: -104.3914596941; Fitness: 0.28514416744693966
# Cluster: 68; Energy: -104.8585437017; Fitness: 0.4848403930838837
# --------------------------------------------------------------------------
#
# --------------------------------------------------------------------------
# <Collection: Offspring> current size: 6
# Cluster: 53; Energy: -104.0331783429; Fitness: 0.18977146227722716
# Cluster: 58; Energy: -105.0839549354; Fitness: 0.6264016849174606
# Cluster: 59; Energy: -103.8547520081; Fitness: 0.15494111619341014
# Cluster: 61; Energy: -102.8557864452; Fitness: 0.049787068367863944
# Cluster: 62; Energy: -104.9742484856; Fitness: 0.5529758016416768
# Cluster: 65; Energy: -105.2677273637; Fitness: 0.771890618445991
# --------------------------------------------------------------------------
#
# Offspring that replace clusters in population due to fitness.
# Replacing Cluster 17(fitness = 0.265) with Offspring 65(fitness = 0.771)
# Replacing Cluster 14(fitness = 0.275) with Offspring 58(fitness = 0.626)
# Replacing Cluster 24(fitness = 0.285) with Offspring 62(fitness = 0.552)
# ****---------------------****
# <Collection: Population> current size: 20; Clusters: [Cluster_38, Cluster_54, Cluster_21, Cluster_28, Cluster_45, Cluster_22, Cluster_56, Cluster_43, Cluster_31, Cluster_52, Cluster_50, Cluster_23, Cluster_57, Cluster_58, Cluster_33, Cluster_39, Cluster_65, Cluster_66, Cluster_62, Cluster_68]
# Time Information
# fitness_timer_1   = 0.000362396240234375 seconds
# memory_operator_timer_1   = 1.6927719116210938e-05 seconds
# predation_timer_1 = 8.069278478622437 seconds
# fitness_timer_2   = 9.679794311523438e-05 seconds
# ending_timer      = 0.05649113655090332 seconds
# The amount of time required for generation 3 is 11.680915355682373 seconds
# ----------------------------------------------------------
# Time elapsed: 00:00:41
# Date and Time: 2021-03-23 03:02:52.244813
#
#
# ----------------------------------------------------------
# ####################
# RUNNING GENERATION 4
# ####################
# -----------------------
# Making Offspring
# -----------------------
# Time taken to make offspring: 2.267793893814087 s.
# Details of created offsprings
# Time taken to add offspring to Offspring_Pool: 0.00014519691467285156 s.
# -----------------------
# **********************************************************
# **********************************************************
# Offspring removed from the Offspring Pool due to violating the Comprehensive Energy Diversity Scheme.
# NOTE: energy difference minimum = 0.025 eV.
# **********************************************************
# **********************************************************
# Assessing which structures to remove to comply with the Energy Diversity Scheme
# Start assessing for Energy Diversity
# Removing offspring that violate the Energy Diversity Scheme
# 1. Clusters in the Population that have been replaced by Offspring, due to the cluster in the offspring being energetically similar and having a lower energy than a offspring.
# 1. Clusters in the Population that have been replaced by Offspring, due to the cluster in the offspring being energetically similar and having a lower energy than a offspring.
#  --> Population Cluster removed 39 (Energy: -104.431352 eV, fitness = 0.049787) {Replaced with Offspring 69 (Energy: -104.448099 eV, fitness = 0.052194)}.
#  --> Population Cluster removed 62 (Energy: -104.974248 eV, fitness = 0.230026) {Replaced with Offspring 76 (Energy: -104.989226 eV, fitness = 0.239946)}.
#  --> Population Cluster removed 50 (Energy: -104.938487 eV, fitness = 0.207968) {Replaced with Offspring 81 (Energy: -104.960324 eV, fitness = 0.221172)}.
# *****************************
# 2. These offspring have a better energy and are energetically similar to two or more clusters in the population.
# 2. No offspring need to be removed from the offsprings list
# *****************************
# 3. The following offspring were removed from the offspring pool (and because they are energetically similar and have a lower energy to which cluster in the population):
# 3. The following offspring were removed from the offspring pool (and because they are energetically similar and have a lower energy to which cluster in the population):
#  --> Offspring

# ****---------------------****
# <Collection: Population> current size: 20; Clusters: [Cluster_38, Cluster_54, Cluster_21, Cluster_28, Cluster_45, Cluster_22, Cluster_56, Cluster_75, Cluster_72, Cluster_52, Cluster_81, Cluster_23, Cluster_57, Cluster_58, Cluster_70, Cluster_77, Cluster_65, Cluster_66, Cluster_76, Cluster_68]
# Time Information
# fitness_timer_1   = 0.0002281665802001953 seconds
# memory_operator_timer_1   = 1.621246337890625e-05 seconds
# predation_timer_1 = 4.930523633956909 seconds
# fitness_timer_2   = 0.0001747608184814453 seconds
# ending_timer      = 0.035019636154174805 seconds
# The amount of time required for generation 4 is 8.85834550857544 seconds
# ----------------------------------------------------------
# Time elapsed: 00:00:49
# Date and Time: 2021-03-23 03:03:01.140870
#
#
# ----------------------------------------------------------
# ####################
# RUNNING GENERATION 5
# ####################
# -----------------------
# Making Offspring
# -----------------------
# Time taken to make offspring: 3.0717198848724365 s.
# Details of created offsprings
# Time taken to add offspring to Offspring_Pool: 0.00015091896057128906 s.
# -----------------------
# **********************************************************
# **********************************************************
# Offspring removed from the Offspring Pool due to violating the Comprehensive Energy Diversity Scheme.
# NOTE: energy difference minimum = 0.025 eV.
# **********************************************************
# **********************************************************
# Assessing which structures to remove to comply with the Energy Diversity Scheme
# Start assessing for Energy Diversity
# Removing offspring that violate the Energy Diversity Scheme
# 1. Clusters in the Population that have been replaced by Offspring, due to the cluster in the offspring being energetically similar and having a lower energy than a offspring.
# 1. Clusters in the Population that have been replaced by Offspring, due to the cluster in the offspring being energetically similar and having a lower energy than a offspring.
#  --> Population Cluster removed 52 (Energy: -104.887304 eV, fitness = 0.461637) {Replaced with Offspring 89 (Energy: -104.902593 eV, fitness = 0.470695)}.
#  --> Population Cluster removed 77 (Energy: -105.358123 eV, fitness = 0.839755) {Replaced with Offspring 93 (Energy: -105.365334 eV, fitness = 0.847485)}.
#  --> Population Cluster removed 76 (Energy: -104.989226 eV, fitness = 0.525476) {Replaced with Offspring 100 (Energy: -104.997109 eV, fitness = 0.530767)}.
# *****************************
# 2. These offspring have a better energy and are energetically similar to two or more clusters in the population.
# 2. No offspring need to be removed from the offsprings list
# *****************************
# 3. The following offspring were removed from the offspring pool (and because they are energetically similar and have a lower energy to which cluster in the population):
# 3. The following offspring were removed from the offspring pool (and because they are energetically similar and have a lower energy to which cluster in the population):
#  --> Offspring 85 (Energy: -105.2646258241 eV, fitness = 0.745676) {Similar to Population Cluster 65 (Energy: -105.267727 eV, fitness = 0.748621)}.
#  --> Offspring 97 (Energy: -105.246884836 eV, fitness = 0.729052) {Similar to Population Cluster 65 (Energy: -105.267727 eV, fitness = 0.748621)}.
#  --> Offspring 94 (Energy: -104.9377484322 eV, fitness = 0.492201) {Similar to Population Cluster 81 (Energy: -104.960324 eV, fitness = 0.506526)}.
#  --> Offspring 87 (Energy: -104.7456666231 eV, fitness = 0.385593) {Similar to Population Cluster 56 (Energy: -104.770003 eV, fitness = 0.397705)}.
#  --> Offspring 92 (Energy: -104.6855940525 eV, fitness = 0.357252) {Similar to Population Cluster 38 (Energy: -104.701534 eV, fitness = 0.364563)}.
#  --> Offspring 90 (Energy: -104.5529911751 eV, fitness = 0.301849) {Similar to Population Cluster 70 (Energy: -104.57572 eV, fitness = 0.310695)}.
# *****************************
# 4. Offspring that have have been removed for being energetically similar and have a lower energy to the rest of the other Offspring
# 4. Offspring that have have been removed for being energetically similar and have a lower energy to the rest of the other Offspring
#  --> Offspring 99 (Energy: -105.1519766192eV, fitness = 0.646216) {Similar to Offspring 95 (Energy: -105.1630138638 eV, fitness = 0.655344)}.
#  --> Offspring 98 (Energy: -105.1517478184eV, fitness = 0.646028) {Similar to Offspring 95 (Energy: -105.1630138638 eV, fitness = 0.655344)}.
# **********************************************************
# **********************************************************
# -----------------------------
# ****---------------------****
# Natural Selection for Generation 5
# --------------------------------------------------------------------------
# <Collection: Population> current size: 20
# Cluster: 38; Energy: -104.7015337556; Fitness: 0.36456262337954265
# Cluster: 54; Energy: -104.6241092393; Fitness: 0.3304003814532486
# Cluster: 21; Energy: -105.0547400385; Fitness: 0.5710988643658153
# Cluster: 28; Energy: -105.4955498812; Fitness: 1.0
# Cluster: 45; Energy: -104.7279096553; Fitness: 0.376989577795966
# Cluster: 22; Energy: -105.1248079506; Fitness: 0.6242847001159761
# Cluster: 56; Energy: -104.7700034769; Fitness: 0.3977053866616486
# Cluster: 75; Energy: -105.193327844; Fitness: 0.6810824891550469
# Cluster: 72; Energy: -104.6734455273; Fitness: 0.3517789765774515
# Cluster: 89; Energy: -104.9025926273; Fitness: 0.47069453424202656
# Cluster: 81; Energy: -104.9603241941; Fitness: 0.5065262537658853
# Cluster: 23; Energy: -105.0243461159; Fitness: 0.5494605216582606
# Cluster: 57; Energy: -105.3301222089; Fitness: 0.8103979044130362
# Cluster: 58; Energy: -105.0839549354; Fitness: 0.5927006169931481
# Cluster: 70; Energy: -104.5757197234; Fitness: 0.31069462130645087
# Cluster: 93; Energy: -105.3653336898; Fitness: 0.8474849314209791
# Cluster: 65; Energy: -105.2677273637; Fitness: 0.7486206114583067
# Cluster: 66; Energy: -105.4043613535; Fitness: 0.8905777935008626
# Cluster: 100; Energy: -104.9971085324; Fitness: 0.5307667596085209
# Cluster: 68; Energy: -104.8585437017; Fitness: 0.4450696484080085
# --------------------------------------------------------------------------
#
# --------------------------------------------------------------------------
# <Collection: Offspring> current size: 5
# Cluster: 86; Energy: -105.4324622404; Fitness: 0.92295623483543
# Cluster: 88; Energy: -103.1348819231; Fitness: 0.049787068367863944
# Cluster: 91; Energy: -104.541713412; Fitness: 0.29755359926702435
# Cluster: 95; Energy: -105.1630138638; Fitness: 0.6553435560535681
# Cluster: 96; Energy: -104.3003837642; Fitness: 0.21896375224329737
# --------------------------------------------------------------------------
#
# Offspring that replace clusters in population due to fitness.
# Replacing Cluster 70(fitness = 0.31) with Offspring 86(fitness = 0.922)
# Replacing Cluster 54(fitness = 0.33) with Offspring 95(fitness = 0.655)
# ****---------------------****
# <Collection: Population> current size: 20; Clusters: [Cluster_38, Cluster_95, Cluster_21, Cluster_28, Cluster_45, Cluster_22, Cluster_56, Cluster_75, Cluster_72, Cluster_89, Cluster_81, Cluster_23, Cluster_57, Cluster_58, Cluster_86, Cluster_93, Cluster_65, Cluster_66, Cluster_100, Cluster_68]
# Time Information
# fitness_timer_1   = 0.0001926422119140625 seconds
# memory_operator_timer_1   = 1.1920928955078125e-05 seconds
# predation_timer_1 = 4.278567552566528 seconds
# fitness_timer_2   = 0.00010037422180175781 seconds
# ending_timer      = 0.03326702117919922 seconds
# The amount of time required for generation 5 is 7.815812587738037 seconds
# ----------------------------------------------------------
# Time elapsed: 00:00:57
# Date and Time: 2021-03-23 03:03:09.006177
#
#
# ----------------------------------------------------------
# ####################
# RUNNING GENERATION 6
# ####################
# -----------------------
# Making Offspring
# -----------------------
# Time taken to make offspring: 1.7981901168823242 s.
# Details of created offsprings
# Time taken to add offspring to Offspring_Pool: 6.127357482910156e-05 s.
# -----------------------
# **********************************************************
# **********************************************************
# Offspring removed from the Offspring Pool due to violating the Comprehensive Energy Diversity Scheme.
# NOTE: energy difference minimum = 0.025 eV.
# **********************************************************
# **********************************************************
# Assessing which structures to remove to comply with the Energy Diversity Scheme
# Start assessing for Energy Diversity
# Removing offspring that violate the Energy Diversity Scheme
# 1. Clusters in the Population that have been replaced by Offspring, due to the cluster in the offspring being energetically similar and having a lower energy than a offspring.
# 1. Clusters in the Population that have been replaced by Offspring, due to the cluster in the offspring being energetically similar and having a lower energy than a offspring.
#  --> Population Cluster removed 89 (Energy: -104.902593 eV, fitness = 0.150033) {Replaced with Offspring 102 (Energy: -104.904974 eV, fitness = 0.151013)}.
#  --> Population Cluster removed 21 (Energy: -105.05474 eV, fitness = 0.227444) {Replaced with Offspring 106 (Energy: -105.057025 eV, fitness = 0.22887)}.
#  --> Population Cluster removed 68 (Energy: -104.858544 eV, fitness = 0.133007) {Replaced with Offspring 107 (Energy: -104.868284 eV, fitness = 0.136597)}.
# *****************************
# 2. These offspring have a better energy and are energetically similar to two or more clusters in the population.
# 2. No offspring need to be removed from the offsprings list
# *****************************
# 3. The following offspring were removed from the offspring pool (and because they are energetically similar and have a lower energy to which cluster in the population):
# 3. The following offspring were removed from the offspring pool (and because they are energetically similar and have a lower energy to which cluster in the population):
#  --> Offspring 103 (Energy: -105.3407505013 eV, fitness = 0.497207) {Similar to Population Cluster 93 (Energy: -105.365334 eV, fitness = 0.531779)}.
#  --> Offspring 115 (Energy: -105.3069547292 eV, fitness = 0.453316) {Similar to Population Cluster 57 (Energy: -105.330122 eV, fitness = 0.482964)}.
#  --> Offspring 108 (Energy: -105.2461580676 eV, fitness = 0.383884) {Similar to Population Cluster 65 (Energy: -105.267727 eV, fitness = 0.407207)}.
# ...
# Cluster: 382; Energy: -105.270660256; Fitness: 0.38942644696577766
# --------------------------------------------------------------------------
#
# --------------------------------------------------------------------------
# <Collection: Offspring> current size: 4
# Cluster: 460; Energy: -104.8826430738; Fitness: 0.12714943446993096
# Cluster: 461; Energy: -104.7842562463; Fitness: 0.09573144922846694
# Cluster: 462; Energy: -104.6238606889; Fitness: 0.06027119531048566
# Cluster: 466; Energy: -104.5576149004; Fitness: 0.049787068367863944
# --------------------------------------------------------------------------
#
# Offspring that replace clusters in population due to fitness.
# ****---------------------****
# <Collection: Population> current size: 20; Clusters: [Cluster_388, Cluster_192, Cluster_456, Cluster_204, Cluster_440, Cluster_250, Cluster_428, Cluster_396, Cluster_136, Cluster_365, Cluster_244, Cluster_298, Cluster_345, Cluster_359, Cluster_243, Cluster_93, Cluster_468, Cluster_66, Cluster_320, Cluster_382]
# Time Information
# fitness_timer_1   = 0.0002200603485107422 seconds
# memory_operator_timer_1   = 1.3828277587890625e-05 seconds
# predation_timer_1 = 4.124362230300903 seconds
# fitness_timer_2   = 0.000141143798828125 seconds
# ending_timer      = 0.03712749481201172 seconds
# The amount of time required for generation 28 is 5.89565372467041 seconds
# ----------------------------------------------------------
# Time elapsed: 00:03:07
# Date and Time: 2021-03-23 03:05:18.445897
#
#
# ----------------------------------------------------------
# #####################
# RUNNING GENERATION 29
# #####################
# -----------------------
# Making Offspring
# -----------------------
# Time taken to make offspring: 1.5424771308898926 s.
# Details of created offsprings
# Time taken to add offspring to Offspring_Pool: 4.863739013671875e-05 s.
# -----------------------
# **********************************************************
# **********************************************************
# Offspring removed from the Offspring Pool due to violating the Comprehensive Energy Diversity Scheme.
# NOTE: energy difference minimum = 0.025 eV.
# **********************************************************
# **********************************************************
# Assessing which structures to remove to comply with the Energy Diversity Scheme
# Start assessing for Energy Diversity
# Removing offspring that violate the Energy Diversity Scheme
# 1. Clusters in the Population that have been replaced by Offspring, due to the cluster in the offspring being energetically similar and having a lower energy than a offspring.
# 1. No clusters in the population have been replaced by offspring in the offsprings list
# *****************************
# 2. These offspring have a better energy and are energetically similar to two or more clusters in the population.
# 2. No offspring need to be removed from the offsprings list
# *****************************
# 3. The following offspring were removed from the offspring pool (and because they are energetically similar and have a lower energy to which cluster in the population):
# 3. The following offspring were removed from the offspring pool (and because they are energetically similar and have a lower energy to which cluster in the population):
#  --> Offspring 481 (Energy: -105.5968210139 eV, fitness = 0.998638) {Similar to Population Cluster 136 (Energy: -105.597586 eV, fitness = 1.0)}.
#  --> Offspring 479 (Energy: -105.4948083821 eV, fitness = 0.832609) {Similar to Population Cluster 204 (Energy: -105.495668 eV, fitness = 0.833885)}.
#  --> Offspring 477 (Energy: -105.3955993197 eV, fitness = 0.69766) {Similar to Population Cluster 66 (Energy: -105.404361 eV, fitness = 0.708642)}.
#  --> Offspring 482 (Energy: -105.3413946137 eV, fitness = 0.63341) {Similar to Population Cluster 93 (Energy: -105.365334 eV, fitness = 0.661022)}.
#  --> Offspring 475 (Energy: -105.2236161823 eV, fitness = 0.513468) {Similar to Population Cluster 428 (Energy: -105.236 eV, fitness = 0.524928)}.
#  --> Offspring 484 (Energy: -105.221077834 eV, fitness = 0.51115) {Similar to Population Cluster 428 (Energy: -105.236 eV, fitness = 0.524928)}.
#  --> Offspring 476 (Energy: -105.188667895 eV, fitness = 0.482459) {Similar to Population Cluster 396 (Energy: -105.201002 eV, fitness = 0.493183)}.
#  --> Offspring 471 (Energy: -105.146651278 eV, fitness = 0.447647) {Similar to Population Cluster 250 (Energy: -105.149584 eV, fitness = 0.449993)}.
#  --> Offspring 469 (Energy: -105.1384298673 eV, fitness = 0.441135) {Similar to Population Cluster 250 (Energy: -105.149584 eV, fitness = 0.449993)}.
#  --> Offspring 483 (Energy: -105.1114282233 eV, fitness = 0.420407) {Similar to Population Cluster 359 (Energy: -105.11986 eV, fitness = 0.426773)}.
#  --> Offspring 472 (Energy: -105.0095465023 eV, fitness = 0.350593) {Similar to Population Cluster 298 (Energy: -105.03326 eV, fitness = 0.36573)}.
#  --> Offspring 480 (Energy: -104.9332367862 eV, fitness = 0.306008) {Similar to Population Cluster 365 (Energy: -104.945226 eV, fitness = 0.312618)}.
# *****************************
# 4. Offspring that have have been removed for being energetically similar and have a lower energy to the rest of the other Offspring
# 4. No offspring have been removed from the rest of the offsprings list for being too similar
# **********************************************************
# **********************************************************
# -----------------------------
# ****---------------------****
# Natural Selection for Generation 29
# --------------------------------------------------------------------------
# <Collection: Population> current size: 20
# Cluster: 388; Energy: -105.5338136401; Fitness: 0.8925544112011078
# Cluster: 192; Energy: -105.1749197207; Fitness: 0.4707797414826077
# Cluster: 456; Energy: -105.0849495089; Fitness: 0.4010260080622828
# Cluster: 204; Energy: -105.4956677865; Fitness: 0.8338852619146172
# Cluster: 440; Energy: -105.4416332478; Fitness: 0.7573185428929903
# Cluster: 250; Energy: -105.1495840136; Fitness: 0.44999283241887356
# Cluster: 428; Energy: -105.2359998239; Fitness: 0.5249275772846312
# Cluster: 396; Energy: -105.2010021646; Fitness: 0.49318286467714256
# Cluster: 136; Energy: -105.5975855112; Fitness: 1.0
# Cluster: 365; Energy: -104.945226116; Fitness: 0.31261784835950973
# Cluster: 244; Energy: -104.9718700944; Fitness: 0.32782242749697826
# Cluster: 298; Energy: -105.0332600392; Fitness: 0.36572961678029536
# Cluster: 345; Energy: -105.3400085391; Fitness: 0.6318466833645685
# Cluster: 359; Energy: -105.1198600931; Fitness: 0.4267726163330166
# Cluster: 243; Energy: -105.4667025444; Fitness: 0.7919258768896941
# Cluster: 93; Energy: -105.3653336898; Fitness: 0.661021687226687
# Cluster: 468; Energy: -105.312253424; Fitness: 0.6013491422674746
# Cluster: 66; Energy: -105.4043613535; Fitness: 0.708641713483254
# Cluster: 320; Energy: -105.0025398455; Fitness: 0.34624209971856845
# Cluster: 382; Energy: -105.270660256; Fitness: 0.5583798717279288
# --------------------------------------------------------------------------
#
# --------------------------------------------------------------------------
# <Collection: Offspring> current size: 4
# Cluster: 470; Energy: -104.7147264936; Fitness: 0.20729357493047798
# Cluster: 473; Energy: -103.9144737636; Fitness: 0.049787068367863944
# Cluster: 474; Energy: -104.6352427549; Fitness: 0.17991116260915263
# Cluster: 478; Energy: -104.1831305143; Fitness: 0.08036771353349234
# --------------------------------------------------------------------------
#
# Offspring that replace clusters in population due to fitness.
# ****---------------------****
# <Collection: Population> current size: 20; Clusters: [Cluster_388, Cluster_192, Cluster_456, Cluster_204, Cluster_440, Cluster_250, Cluster_428, Cluster_396, Cluster_136, Cluster_365, Cluster_244, Cluster_298, Cluster_345, Cluster_359, Cluster_243, Cluster_93, Cluster_468, Cluster_66, Cluster_320, Cluster_382]
# Time Information
# fitness_timer_1   = 0.00014710426330566406 seconds
# memory_operator_timer_1   = 1.2636184692382812e-05 seconds
# predation_timer_1 = 2.8595688343048096 seconds
# fitness_timer_2   = 0.0001552104949951172 seconds
# ending_timer      = 0.018258094787597656 seconds
# The amount of time required for generation 29 is 4.430714130401611 seconds
# ----------------------------------------------------------
# Time elapsed: 00:03:11
# Date and Time: 2021-03-23 03:05:22.911196
#
#
# ----------------------------------------------------------
# #####################
# RUNNING GENERATION 30
# #####################
# -----------------------
# Making Offspring
# -----------------------
# Time taken to make offspring: 1.1866726875305176 s.
# Details of created offsprings
# Time taken to add offspring to Offspring_Pool: 5.030632019042969e-05 s.
# -----------------------
# **********************************************************
# **********************************************************
# Offspring removed from the Offspring Pool due to violating the Comprehensive Energy Diversity Scheme.
# NOTE: energy difference minimum = 0.025 eV.
# **********************************************************
# **********************************************************
# Assessing which structures to remove to comply with the Energy Diversity Scheme
# Start assessing for Energy Diversity
# Removing offspring that violate the Energy Diversity Scheme
# 1. Clusters in the Population that have been replaced by Offspring, due to the cluster in the offspring being energetically similar and having a lower energy than a offspring.
# 1. Clusters in the Population that have been replaced by Offspring, due to the cluster in the offspring being energetically similar and having a lower energy than a offspring.
#  --> Population Cluster removed 298 (Energy: -105.03326 eV, fitness = 0.186976) {Replaced with Offspring 494 (Energy: -105.045224 eV, fitness = 0.193742)}.
#  --> Population Cluster removed 320 (Energy: -105.00254 eV, fitness = 0.170665) {Replaced with Offspring 498 (Energy: -105.012198 eV, fitness = 0.175634)}.
# *****************************
# 2. These offspring have a better energy and are energetically similar to two or more clusters in the population.
# 2. No offspring need to be removed from the offsprings list
# *****************************
# 3. The following offspring were removed from the offspring pool (and because they are energetically similar and have a lower energy to which cluster in the population):
# 3. The following offspring were removed from the offspring pool (and because they are energetically similar and have a lower energy to which cluster in the population):
#  --> Offspring 492 (Energy: -105.5336029375 eV, fitness = 0.826868) {Similar to Population Cluster 388 (Energy: -105.533814 eV, fitness = 0.827385)}.
#  --> Offspring 487 (Energy: -105.4539610607 eV, fitness = 0.652627) {Similar to Population Cluster 243 (Energy: -105.466703 eV, fitness = 0.677808)}.
#  --> Offspring 495 (Energy: -105.3971198635 eV, fitness = 0.551209) {Similar to Population Cluster 66 (Energy: -105.404361 eV, fitness = 0.563198)}.
#  --> Offspring 493 (Energy: -105.2966248572 eV, fitness = 0.408918) {Similar to Population Cluster 468 (Energy: -105.312253 eV, fitness = 0.428355)}.
#  --> Offspring 491 (Energy: -105.1058366467 eV, fitness = 0.231975) {Similar to Population Cluster 359 (Energy: -105.11986 eV, fitness = 0.241845)}.
#  --> Offspring 499 (Energy: -105.0784497117 eV, fitness = 0.213845) {Similar to Population Cluster 456 (Energy: -105.08495 eV, fitness = 0.218016)}.
#  --> Offspring 489 (Energy: -105.0610975125 eV, fitness = 0.203099) {Similar to Population Cluster 456 (Energy: -105.08495 eV, fitness = 0.218016)}.
#  --> Offspring 490 (Energy: -104.943004764 eV, fitness = 0.142995) {Similar to Population Cluster 365 (Energy: -104.945226 eV, fitness = 0.143942)}.
# *****************************
# 4. Offspring that have have been removed for being energetically similar and have a lower energy to the rest of the other Offspring
# 4. Offspring that have have been removed for being energetically similar and have a lower energy to the rest of the other Offspring
#  --> Offspring 500 (Energy: -105.0284859946eV, fitness = 0.184343) {Similar to Offspring 494 (Energy: -105.0452237196 eV, fitness = 0.193742)}.
#  --> Offspring 496 (Energy: -104.6620713803eV, fitness = 0.062058) {Similar to Offspring 485 (Energy: -104.6705149528 eV, fitness = 0.063635)}.
# **********************************************************
# **********************************************************
# -----------------------------
# ****---------------------****
# Natural Selection for Generation 30
# --------------------------------------------------------------------------
# <Collection: Population> current size: 20
# Cluster: 388; Energy: -105.5338136401; Fitness: 0.827385481702322
# Cluster: 192; Energy: -105.1749197207; Fitness: 0.28483032221785654
# Cluster: 456; Energy: -105.0849495089; Fitness: 0.21801552254248036
# Cluster: 204; Energy: -105.4956677865; Fitness: 0.7387269773404675
# Cluster: 440; Energy: -105.4416332478; Fitness: 0.6291541179267386
# Cluster: 250; Energy: -105.1495840136; Fitness: 0.2641755829816921
# Cluster: 428; Energy: -105.2359998239; Fitness: 0.3415111052981925
# Cluster: 396; Energy: -105.2010021646; Fitness: 0.30778210624493696
# Cluster: 136; Energy: -105.5975855112; Fitness: 1.0
# Cluster: 365; Energy: -104.945226116; Fitness: 0.14394163070349084
# Cluster: 244; Energy: -104.9718700944; Fitness: 0.1558002594338564
# Cluster: 494; Energy: -105.0452237196; Fitness: 0.1937424148057455
# Cluster: 345; Energy: -105.3400085391; Fitness: 0.46517794367892645
# Cluster: 359; Energy: -105.1198600931; Fitness: 0.24184466785628753
# Cluster: 243; Energy: -105.4667025444; Fitness: 0.6778081872282462
# Cluster: 93; Energy: -105.3653336898; Fitness: 0.501532451443858
# Cluster: 468; Energy: -105.312253424; Fitness: 0.42835469400326753
# Cluster: 66; Energy: -105.4043613535; Fitness: 0.5631977042684911
# Cluster: 498; Energy: -105.0121984887; Fitness: 0.17563396023046635
# Cluster: 382; Energy: -105.270660256; Fitness: 0.378556869381011
# --------------------------------------------------------------------------
#
# --------------------------------------------------------------------------
# <Collection: Offspring> current size: 4
# Cluster: 485; Energy: -104.6705149528; Fitness: 0.06363489560490097
# Cluster: 486; Energy: -104.5879222374; Fitness: 0.049787068367863944
# Cluster: 488; Energy: -104.8370008357; Fitness: 0.10435926716054285
# Cluster: 497; Energy: -104.8957870853; Fitness: 0.12427667058120638
# --------------------------------------------------------------------------
#
# Offspring that replace clusters in population due to fitness.
# ****---------------------****
# <Collection: Population> current size: 20; Clusters: [Cluster_388, Cluster_192, Cluster_456, Cluster_204, Cluster_440, Cluster_250, Cluster_428, Cluster_396, Cluster_136, Cluster_365, Cluster_244, Cluster_494, Cluster_345, Cluster_359, Cluster_243, Cluster_93, Cluster_468, Cluster_66, Cluster_498, Cluster_382]
# Time Information
# fitness_timer_1   = 0.0009303092956542969 seconds
# memory_operator_timer_1   = 1.4066696166992188e-05 seconds
# predation_timer_1 = 3.0229151248931885 seconds
# fitness_timer_2   = 0.00010728836059570312 seconds
# ending_timer      = 0.02926349639892578 seconds
# The amount of time required for generation 30 is 4.273678779602051 seconds
# ----------------------------------------------------------
# Time elapsed: 00:03:16
# Date and Time: 2021-03-23 03:05:27.207480
# ----------------------------------------------------------
# ----------------------------------------------------------
# The maximum generation set by the user has been reached! The genetic algorithm process has completed!
# The Algorithm will finish now.
# ----------------------------------------------------------
# Time elapsed: 00:03:16
# Date and Time: 2021-03-23 03:05:27.208901
# ----------------------------------------------------------
# Finishing the Garden Group Genetic Algorithm Successfully.
# ----------------------------------------------------------
# ----------------------------------------------------------
# ' ---------------- '

# %% [markdown]
# [Back To Table of Contents](../Organisms_Jupyter_Example.ipynb)

# %% [markdown]
# ## Post-processing data from your global optimisation
#
# Once the genetic algorithm is finished, we generally would like to get data from it, such as the global minimum. We can get this from the Database that is recorded based on our settings for the ``ga_recording_information`` variable. The following code is a simple way of extracting the lowest energy cluster that was obtained during the genetic algorithm. This is not to be included in the *Run.py* file, this is just so you can see the fruits of your global optimisation work!

# %%
from ase.io import read
database_path = 'Recorded_Data/GA_Recording_Database.db'
lowest_energy_cluster_found = read(database_path)
if isinstance(lowest_energy_cluster_found, list):
    lowest_energy_cluster_found = lowest_energy_cluster_found[0]
lowest_energy_cluster_found.center(about=0.)
from ase.visualize import view
view(lowest_energy_cluster_found,viewer='x3d')
# Out:
# <html>
#
#  <head>
#
#   <title>ASE atomic visualization</title>
#
#   <link rel="stylesheet" type="text/css"
#
#    href="https://www.x3dom.org/x3dom/release/x3dom.css">
#
#   </link>
#
#   <script type="text/javascript"
#
#    src="https://www.x3dom.org/x3dom/release/x3dom.js">
#
#   </script>
#
#  </head>
#
#  <body>
#
#   <X3D>
#
#    <Scene>
#
#     <Transform translation="1.73 -1.27 3.15">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="1.58 1.29 2.75">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.56 -0.05 3.14">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.36 -2.54 3.34">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.69 2.45 2.81">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="3.80 0.10 2.52">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-2.40 -1.57 2.10">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-2.45 0.98 1.70">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="1.40 -3.17 1.46">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-1.08 -3.78 1.38">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="3.62 -2.10 1.51">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.23 -1.46 1.12">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="1.08 3.19 1.18">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="1.94 -0.36 0.95">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="3.39 2.01 1.04">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.12 1.00 0.92">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-4.04 -0.54 0.56">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-1.44 2.99 0.45">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-2.45 -2.57 -0.24">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="4.04 -0.17 -0.15">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-1.78 -0.28 -0.37">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="1.70 1.52 -0.58">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-3.19 1.57 -0.75">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="0.04 -3.05 -0.75">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="2.43 -2.15 -0.69">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="2.75 3.77 -0.66">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="0.51 -0.59 -1.06">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="0.38 3.78 -1.13">
#
#      <Shape>

# %% [markdown]
# [Back To Table of Contents](../Organisms_Jupyter_Example.ipynb)
