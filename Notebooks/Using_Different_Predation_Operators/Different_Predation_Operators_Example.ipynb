# %% [markdown]
# # An Example for Optimising a 38 atom Lennard-Jones Nanocluster with Organisms using Different Predation Operators

# %% [markdown]
# [Back To Table of Contents](../Organisms_Jupyter_Example.ipynb)

# %% [markdown]
# In this example, we will perform a genetic algorithm optimisation on the 38 atom Lennard-Jones (LJ<sub>38</sub>) cluster with a variety of predation operators. See [organisms.readthedocs.io/en/latest/Using_Run](https://organisms.readthedocs.io/en/latest/Using_Run.html) for more information on the *Run.py* file.
#
# To run this notebook step by step, press the $\blacktriangleright$ button sequentially on the python code you want to run. You can find the $\blacktriangleright$ button in the menu bar above. Make sure you have run $\blacktriangleright$ on every cell before running the ``GA_Program`` execution cell. Equivalently, press the $\blacktriangleright\blacktriangleright$ button to completely run this *Run.py* file beginning to end. You can also find the $\blacktriangleright\blacktriangleright$ button in the menu bar above.
#
# Note: These are the vanilla settings for running Organisms on a LJ<sub>38</sub> nanocluster, but feel free to change the settings as you wish.
#
# Also note: This program makes files which are created and stored on the Binder server. If you want to rerun this example, you will need to remove these files. The following block code will do this. This is only needed for this notebook and is not apart of *Run.py* script.

# %%
import os
from shutil import rmtree
to_be_removed_before_restarting_Jupyter_example = []
to_be_removed_before_restarting_Jupyter_example += ['epoch_data','epoch_data.backup','GA_Run_Details.txt','ga_running.lock']
to_be_removed_before_restarting_Jupyter_example += ['Population','Recorded_Data','Initial_Population','Saved_Points_In_GA_Run','Memory_Operator_Data','Diversity_Information']
to_be_removed_before_restarting_Jupyter_example += ['__pycache__']
for example_file_or_folder in to_be_removed_before_restarting_Jupyter_example:
    if os.path.exists(example_file_or_folder):
        if os.path.isdir(example_file_or_folder):
            rmtree(example_file_or_folder)
        else:
            os.remove(example_file_or_folder)

# %% [markdown]
# The *Run.py* code begins below:

# %% [markdown]
# ## Predation Operators
#
# The types of predation operators that are available are:
# * **Off**: No predation operator will be performed.
# * **Energy Predation**: If two clusters have similar energies, one of those clusters will be removed.
# * **IDCM-based Predation**: This operator will determine if two clusters are structrally identical.
# * **SCM-based Predation**: This operator will determine if two clusters are structrally similar based on the structural comparison method, developed by the Garden group to improve the efficiency of global optimisation algorithms.
#
# You can find out more about what they do, and how to use them in your Run.py file, at [Using Predation Operators with the Genetic Algorithm](https://organisms.readthedocs.io/en/latest/Using_Predation_Operators_with_the_Genetic_Algorithm.html#using-predation-operators).
#
# Below are the various predation operators that can be used in the Organisms program. Uncomment out the version that you want to use and comment the rest with a ``#`` sign. Then run this notebook by pressing the XX button.

# %%
# This dictionary includes the information required by the predation scheme.
# predation_information = {'Predation Operator': 'Off'}
# predation_information = {'Predation Operator': 'Energy', 'mode': 'comprehensive', 'type_of_comprehensive_scheme': 'energy', 'minimum_energy_diff': 0.01}
# predation_information = {'Predation Operator': 'IDCM', 'percentage_diff': 5.0}
predation_information = {'Predation Operator': 'SCM', 'SCM Scheme': 'T-SCM', 'rCut_high': 1.422, 'rCut_low': 1.277, 'rCut_resolution': 78}

# %% [markdown]
# [Back To Table of Contents](../Organisms_Jupyter_Example.ipynb)

# %% [markdown]
# ## Running the rest of the *Run.py* Script
#
# Below is the rest of the settings for the *Run.py* script to run:

# %%
from Organisms import GA_Program

# This details the elemental and number of atom composition of cluster that the user would like to investigate

cluster_makeup = {'Ne': 38}

# Surface details
surface_details = None

# These are the main variables of the genetic algorithm that with changes could affect the results of the Genetic Algorithm.
pop_size = 20
generations = 50
no_offspring_per_generation = 16

# These setting indicate how offspring should be made using the Mating and Mutation Proceedures
creating_offspring_mode = "Either_Mating_and_Mutation"
crossover_type = "CAS_random"
mutation_types = [['move', 1]]
chance_of_mutation = 0.1

# This parameter will tell the GGA if an epoch is desired, and how the user would like to proceed.
epoch_settings = {'epoch mode': 'same population', 'max repeat': 5}

# These are variables used by the algorithm to make and place clusters in.
r_ij = 1.5
cell_length = 4.1
vacuum_to_add_length = 10.0

# The RunMinimisation.py algorithm is one set by the user. It contain the def Minimisation_Function
# That is used for local optimisations. This can be written in whatever way the user wants to perform
# the local optimisations. This is meant to be as free as possible.
from RunMinimisation_LJ import Minimisation_Function

# This dictionary includes the information required to prevent clusters being placed in the population if they are too similar to clusters in this memory_operator
memory_operator_information = {'Method': 'Off'}

# This dictionary includes the information required by the predation scheme.
# This parameter has been address in the previous code of this Jupyter notebook

# This dictionary includes the information required by the fitness scheme
fitness_information = {'Fitness Operator': 'Energy', 'fitness_function': {'function': 'exponential', 'alpha': 3.0}}

# Variables required for the Recording_Cluster.py class/For recording the history as required of the genetic algorithm.
ga_recording_information = {'ga_recording_scheme': 'Limit_energy_height', 'limit_number_of_clusters_recorded': 1, 'limit_energy_height_of_clusters_recorded': 1.0, 'exclude_recording_cluster_screened_by_diversity_scheme': False}

# These are last techinical points that the algorithm is designed in mind
force_replace_pop_clusters_with_offspring = True
user_initialised_population_folder = None
rounding_criteria = 10
print_details = True
no_of_cpus = 1
finish_algorithm_if_found_cluster_energy = {'cluster energy': -173.93, 'round': 2}
total_length_of_running_time = None

# %% [markdown]
# ## The Genetic Algorithm!
#
# You have got to the end of all the parameter setting stuff! Now on to the fun stuff! The next part of the Run.py file tells the genetic algorithm to run. This is written as follows in the Run.py. Note this may take a bit of time to run depending on your settings. Running the below code and good and get yourself a tea or coffee.

# %%
''' ---------------- '''
# This will execute the genetic algorithm program
GA_Program(cluster_makeup=cluster_makeup,
    pop_size=pop_size,
    generations=generations,
    no_offspring_per_generation=no_offspring_per_generation,
    creating_offspring_mode=creating_offspring_mode,
    crossover_type=crossover_type,
    mutation_types=mutation_types,
    chance_of_mutation=chance_of_mutation,
    r_ij=r_ij,
    vacuum_to_add_length=vacuum_to_add_length,
    Minimisation_Function=Minimisation_Function,
    surface_details=surface_details,
    epoch_settings=epoch_settings,
    cell_length=cell_length,
    memory_operator_information=memory_operator_information,
    predation_information=predation_information,
    fitness_information=fitness_information,
    ga_recording_information=ga_recording_information,
    force_replace_pop_clusters_with_offspring=force_replace_pop_clusters_with_offspring,
    user_initialised_population_folder=user_initialised_population_folder,
    rounding_criteria=rounding_criteria,
    print_details=print_details,
    no_of_cpus=no_of_cpus,
    finish_algorithm_if_found_cluster_energy=finish_algorithm_if_found_cluster_energy,
    total_length_of_running_time=total_length_of_running_time)
''' ---------------- '''
# Out:
# ######################################################
# SCM Based Predation Algorithm
#
# ############################################################
# ############################################################
# ############################################################
# The Otago Research Genetic Algorithm for Nanoclusters, Including Structural Methods and Similarity (Organisms) Program
#
# .--------------------------------------------------------------------------.
# |                             ,                                            |
# |              ,_     ,     .'<_                                           |
# |             _> `'-,'(__.-' __<                                           |
# |             >_.--(.. )  =;`                                   _          |
# |                  `V-'`'\/``                                  ('>         |
# |                                                              /))@@@@@.   |
# |         .----------------------------------.                /@"@@@@@()@  |
# |         | Welcome to the Organisms program |               .@@()@@()@@@@ |
# |         '----------------------------------'               @@@O@@@@()@@@ |
# |                  ^                                         @()@@\@@@()@@ |
# |  _     (\_/)     |                                          @()@||@@@@@' |
# | ( \    (0.o) ----'                 _                         '@@||@@@'   |
# |  ) )   (> <)                     _(_)_            wWWWw   _     ||       |
# | ( (  .-'''''-.  A.-.A      @@@@ (_)@(_)       _   (___) _(_)_   ||       |
# |  \ \/         \/ , , \    @@()@@  (_)\      _(_)_   Y  (_)@(_)  ||       |
# |   \   \        ;= t =/     @@@@      `|/   (_)@(_) \|/   (_)\   ||       |
# |    \   |'''''-   ,--'       /        \|     /(_)    |/      |   ||       |
# |     / //     | ||        \ |          | / \|/      \|      \|/  ||       |
# |    /_,))     |_'))       \\|//     \\\|// \|///   \\|//  \\\|// ||       |
# |^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^|
# '--------------------------------------------------------------------------'
#
# Version: 3.2.7
# ############################################################
# ############################################################
#
# This algorithm is designed to perform a genetic algorithm to obtain low energetic structures for a given cluster composition.
#
# This genetic algorithm will proceed with the following input parameters
#
# # This details the elemental and number of atom composition of cluster that the user would like to investigate
# cluster_makeup = {'Ne': 38}
#
# # This details the information used to perform a global optimisation upon a chosen surface
# surface_details = None
#
# # These are the main variables of the genetic algorithm that with changes could affect the results of the Genetic Algorithm.
# pop_size = 20
# generations = 50
# no_offspring_per_generation = 16
#
# # These setting indicate how offspring should be made using the Mating and Mutation Proceedures
# creating_offspring_mode = Either_Mating_and_Mutation
# crossover_type = CAS_random
# mutation_types = [['move', 1.0]]
# mutation_types = 0.1
#
# # These are variables used by the algorithm to make and place clusters in.
# r_ij = 1.5 Angstroms (This is the maximum possible bond length between two atoms in the cluster)
# cell_length = 4.1 Angstroms
# vacuum_to_add_length = 10.0 Angstroms
#
# # The RunMinimisation.py algorithm is one set by the user. It contain the def Minimisation_Function
# # That is used for local optimisations. This can be written in whatever way the user wants to perform
# # the local optimisations. This is meant to be as free as possible.
# Minimisation_Function = <function Minimisation_Function at 0x7f69fcca70d0>
# Path of Minimisation_Function: /mnt/hgfs/GoogleDrive/PhDWork/Programs/OptimisationAlgorithms/GeneticAlgorithm/Organisms/Organisms_Jupyter_Examples/Notebooks/Using_Different_Predation_Operators/RunMinimisation_LJ.py
#
# # This details the information about the memory operator used in this genetic algorithm.
# memory_operator = {'method': 'Off'}
#
# # This details the information about the predation operator used in this genetic algorithm.
# predation_operator = {'predation_information': {'Predation Operator': 'SCM', 'SCM Scheme': 'T-SCM', 'rCut_high': 1.422, 'rCut_low': 1.277, 'rCut_resolution': 78}, 'Predation_Switch': 'SCM', 'population': <Collection: Population> current size: 0; Clusters: [], 'print_details': False, 'SCM_Scheme': 'T-SCM', 'cut_off_similarity': 100.0, 'rCut_low': 1.277, 'rCut_high': 1.422, 'rCut_resolution': 78, 'rCuts': [1.277, 1.2788831169, 1.2807662338, 1.2826493506, 1.2845324675, 1.2864155844, 1.2882987013, 1.2901818182, 1.2920649351, 1.2939480519, 1.2958311688, 1.2977142857, 1.2995974026, 1.3014805195, 1.3033636364, 1.3052467532, 1.3071298701, 1.309012987, 1.3108961039, 1.3127792208, 1.3146623377, 1.3165454545, 1.3184285714, 1.3203116883, 1.3221948052, 1.3240779221, 1.325961039, 1.3278441558, 1.3297272727, 1.3316103896, 1.3334935065, 1.3353766234, 1.3372597403, 1.3391428571, 1.341025974, 1.3429090909, 1.3447922078, 1.3466753247, 1.3485584416, 1.3504415584, 1.3523246753, 1.3542077922, 1.3560909091, 1.357974026, 1.3598571429, 1.3617402597, 1.3636233766, 1.3655064935, 1.3673896104, 1.3692727273, 1.3711558442, 1.373038961, 1.3749220779, 1.3768051948, 1.3786883117, 1.3805714286, 1.3824545455, 1.3843376623, 1.3862207792, 1.3881038961, 1.389987013, 1.3918701299, 1.3937532468, 1.3956363636, 1.3975194805, 1.3994025974, 1.4012857143, 1.4031688312, 1.4050519481, 1.4069350649, 1.4088181818, 1.4107012987, 1.4125844156, 1.4144675325, 1.4163506494, 1.4182337662, 1.4201168831, 1.422], 'debug': True, 'cna_database': <Organisms.GA.SCM_Scripts.CNA_Database.CNA_Database object at 0x7f69fcc8ad90>, 'use_same_CNA_database': False}
#
# # This details the information about the fitness operator used in this genetic algorithm.
# fitness_operator = {'fitness_switch': 'Energy', 'fitness_information': {'Fitness Operator': 'Energy', 'fitness_function': {'function': 'exponential', 'alpha': 3.0}, 'Use Predation Information': False}, 'population': <Collection: Population> current size: 0; Clusters: [], 'print_details': False, 'previous_max_energy': -inf, 'previous_min_energy': inf, 'energy_fitness_function': <Organisms.GA.Fitness_Operators.Fitness_Function.Fitness_Function object at 0x7f69fcc79bb0>}
#
# # This parameter will tell the Organisms program if an epoch is desired, and how the user would like to proceed.
# epoch_settings: {'path': '/mnt/hgfs/GoogleDrive/PhDWork/Programs/OptimisationAlgorithms/GeneticAlgorithm/Organisms/Organisms_Jupyter_Examples/Notebooks/Using_Different_Predation_Operators', 'epoch_data_name': 'epoch_data', 'backup_epoch_data_name': 'epoch_data.backup', 'epoch_settings': {'epoch mode': 'same population', 'max repeat': 5}, 'epoch_mode': 'same population', 'max_number_of_times_non_changing_population': 5, 'epoch_function': <bound method Epoch.should_epoch_using_same_population_epoch of {...}>, 'perform_epoch_function': <bound method Epoch.perform_epoch_same_population of {...}>, 'first_epoch_to_change_fitness_function': False}
#
# # Variables required for the GA_Recording_System.py class/For recording the history as required of the genetic algorithm.
# ga_recording_system = {'ga_recording_information': {'ga_recording_scheme': 'Limit_energy_height', 'limit_number_of_clusters_recorded': 1, 'limit_energy_height_of_clusters_recorded': 1.0, 'exclude_recording_cluster_screened_by_diversity_scheme': False}, 'ga_recording_scheme': 'Limit_energy_height', 'ga_recording_system_name': 'Recorded_Data', 'path_to_write_to': '/mnt/hgfs/GoogleDrive/PhDWork/Programs/OptimisationAlgorithms/GeneticAlgorithm/Organisms/Organisms_Jupyter_Examples/Notebooks/Using_Different_Predation_Operators/Recorded_Data', 'exclude_recording_cluster_screened_by_diversity_scheme': False, 'limit_number_of_clusters_recorded': 1, 'limit_size_of_database': None, 'show_GA_Recording_Database_check_percentage': False, 'limit_energy_height_of_clusters_recorded': 1.0, 'clusters_database': <Collection: GA_Recording_Database> current size: 0; Clusters: [], 'directory': '/mnt/hgfs/GoogleDrive/PhDWork/Programs/OptimisationAlgorithms/GeneticAlgorithm/Organisms/Organisms_Jupyter_Examples/Notebooks/Using_Different_Predation_Operators/Recorded_Data', 'RC_Information_TXT_name': 'Recorded_Data_Information.txt', 'record_initial_population': False, 'saving_points_of_GA': []}
#
# # These are last techinical points that the algorithm is designed in mind
# force_replace_pop_clusters_with_offspring = True
# user_initialised_population_folder = None
# rounding_criteria = 10
# print_details = True
# no_of_cpus = 1
# finish_algorithm_if_found_cluster_energy = -173.93
# total_length_of_running_time: Indefinitely
#
# ############################################################
# ############################################################
# ############################################################
# ################################################################################################################
# ################################################################################################################
# Initalising a Starting Population of Clusters if required to take pool up to a size of 20
# Pool size to begin = 0
# Checking to see if the user has any clusters in the folder None that the user would like to have inputted into the initalise population.
# ################################################################################################################
# Will now population the next 20 with randomly generated clusters.
# -----------------------------
# Checking that the clusters in the population satisfies the Diversity Scheme
# Processing CNA Profiles took 2.3550400733947754 seconds.
# Processing CNA similarities took 0.5826921463012695 seconds.
# Have finished populating the rest of the population with 0 randomly generated clusters.
# The population has been successfully initialised.
# ################################################################################################################
# ################################################################################################################
# Time elapsed: 00:00:14
# Date and Time: 2021-03-23 02:56:26.885823
# -----------------------------
# -----------------------------
# Starting Genetic Algorithm
# -----------------------------
# -----------------------------
#
#
#
# ----------------------------------------------------------
# ####################
# RUNNING GENERATION 1
# ####################
# -----------------------
# Making Offspring
# -----------------------
# Time taken to make offspring: 2.805224895477295 s.
# Details of created offsprings
# Time taken to add offspring to Offspring_Pool: 6.747245788574219e-05 s.
# -----------------------
# Processing CNA Profiles took 2.11714768409729 seconds.
# Processing CNA similarities took 1.381077766418457 seconds.
# Removing offspring that violate the SCM Predation Operator
# [(21, 0)]
# -----------------------------
# ****---------------------****
# Natural Selection for Generation 1
# --------------------------------------------------------------------------
# <Collection: Population> current size: 20
# Cluster: 1; Energy: -164.1605619537; Fitness: 0.20860324307733064
# Cluster: 2; Energy: -165.0834897153; Fitness: 0.2706844749754249
# Cluster: 3; Energy: -159.0850963665; Fitness: 0.049787068367863944
# Cluster: 4; Energy: -163.9523148499; Fitness: 0.1966943627401585
# Cluster: 5; Energy: -167.0472650843; Fitness: 0.47119839092651233
# Cluster: 6; Energy: -163.3010301765; Fitness: 0.1636630037552886
# Cluster: 7; Energy: -167.4363650173; Fitness: 0.5259007654688385
# Cluster: 8; Energy: -164.6984627773; Fitness: 0.2428078114435987
# Cluster: 9; Energy: -162.4043856527; Fitness: 0.12706627673355325
# Cluster: 10; Energy: -160.6422282136; Fitness: 0.0772691832342622
# Cluster: 11; Energy: -161.7627036577; Fitness: 0.10601470453405379
# Cluster: 12; Energy: -168.0036777592; Fitness: 0.6172356855491625
# Cluster: 13; Energy: -165.271447453; Fitness: 0.285433671817301
# Cluster: 14; Energy: -166.0916420609; Fitness: 0.3597935507664445
# Cluster: 15; Energy: -165.7940616158; Fitness: 0.3308055608870169
# Cluster: 16; Energy: -166.0076218162; Fitness: 0.3513607779971466
# Cluster: 17; Energy: -162.3249530037; Fitness: 0.12424891540587425
# Cluster: 18; Energy: -166.416647095; Fitness: 0.394362803106627
# Cluster: 19; Energy: -167.1430635875; Fitness: 0.48411417285787123
# Cluster: 20; Energy: -163.9688878765; Fitness: 0.1976166855210387
# --------------------------------------------------------------------------
#
# --------------------------------------------------------------------------
# <Collection: Offspring> current size:
# --------------------------------------------------------------------------
#
# Offspring that replace clusters in population due to fitness.
# Replacing Cluster 64(fitness = 0.246) with Offspring 83(fitness = 1.0)
# Replacing Cluster 25(fitness = 0.246) with Offspring 75(fitness = 0.721)
# Replacing Cluster 58(fitness = 0.25) with Offspring 79(fitness = 0.573)
# Replacing Cluster 45(fitness = 0.25) with Offspring 69(fitness = 0.542)
# Replacing Cluster 26(fitness = 0.259) with Offspring 84(fitness = 0.417)
# Replacing Cluster 63(fitness = 0.265) with Offspring 72(fitness = 0.354)
# Replacing Cluster 37(fitness = 0.269) with Offspring 78(fitness = 0.3)
# Replacing Cluster 54(fitness = 0.275) with Offspring 76(fitness = 0.292)
# ****---------------------****
# <Collection: Population> current size: 20; Clusters: [Cluster_72, Cluster_46, Cluster_35, Cluster_59, Cluster_60, Cluster_76, Cluster_79, Cluster_78, Cluster_75, Cluster_39, Cluster_23, Cluster_83, Cluster_52, Cluster_48, Cluster_41, Cluster_47, Cluster_84, Cluster_69, Cluster_74, Cluster_62]
# Time Information
# fitness_timer_1   = 0.00017309188842773438 seconds
# memory_operator_timer_1   = 1.5497207641601562e-05 seconds
# predation_timer_1 = 7.028396844863892 seconds
# fitness_timer_2   = 0.00012922286987304688 seconds
# ending_timer      = 0.02163100242614746 seconds
# The amount of time required for generation 4 is 10.237255334854126 seconds
# ----------------------------------------------------------
# Time elapsed: 00:00:59
# Date and Time: 2021-03-23 02:57:11.936066
#
#
# ----------------------------------------------------------
# ####################
# RUNNING GENERATION 5
# ####################
# -----------------------
# Making Offspring
# -----------------------
# Time taken to make offspring: 2.344083070755005 s.
# Details of created offsprings
# Time taken to add offspring to Offspring_Pool: 0.002133607864379883 s.
# -----------------------
# Processing CNA Profiles took 3.921489715576172 seconds.
# Processing CNA similarities took 1.786102056503296 seconds.
# Removing offspring that violate the SCM Predation Operator
# -----------------------------
# ****---------------------****
# Natural Selection for Generation 5
# --------------------------------------------------------------------------
# <Collection: Population> current size: 20
# Cluster: 72; Energy: -168.9285909321; Fitness: 0.12032281706287098
# Cluster: 46; Energy: -168.8633106234; Fitness: 0.11618388599419395
# Cluster: 35; Energy: -169.7130170503; Fitness: 0.18324009877501776
# Cluster: 59; Energy: -168.4354024927; Fitness: 0.09236281858923312
# Cluster: 60; Energy: -169.5207964399; Fitness: 0.16529408610600962
# Cluster: 76; Energy: -168.5408535121; Fitness: 0.09773587125323766
# Cluster: 79; Energy: -169.9011940825; Fitness: 0.20269455115806348
# Cluster: 78; Energy: -168.5940420655; Fitness: 0.10056346415036917
# Cluster: 87; Energy: -170.3617008273; Fitness: 0.25946702220710477
# Cluster: 39; Energy: -169.5585285556; Fitness: 0.1686724480325819
# Cluster: 23; Energy: -168.6418584334; Fitness: 0.10317522362898957
# Cluster: 83; Energy: -171.0213352559; Fitness: 0.3695676439068118
# Cluster: 52; Energy: -169.2876716078; Fitness: 0.14587087239653215
# Cluster: 48; Energy: -168.9939529336; Fitness: 0.12461465186786586
# Cluster: 41; Energy: -170.7112773316; Fitness: 0.3129604670918541
# Cluster: 47; Energy: -169.2781715876; Fitness: 0.14512969135595247
# Cluster: 84; Energy: -169.2600408647; Fitness: 0.14372558860000434
# Cluster: 69; Energy: -169.7870474054; Fitness: 0.19066029888022323
# Cluster: 74; Energy: -169.6005614854; Fitness: 0.17251725083914796
# Cluster: 62; Energy: -169.4584627243; Fitness: 0.15986058862780433
# --------------------------------------------------------------------------
#
# --------------------------------------------------------------------------
# <Collection: Offspring> current size: 15
# Cluster: 85; Energy: -167.2868333746; Fitness: 0.04989134114370529
# Cluster: 86; Energy: -168.3029416425; Fitness: 0.0860301096398162
# Cluster: 88; Energy: -168.3846127815; Fitness: 0.08988134638210293
# Cluster: 89; Energy: -167.6398096842; Fitness: 0.060287075749811424
# Cluster: 90; Energy: -168.3436317961; Fitness: 0.08792779033106013
# Cluster: 91; Energy: -167.8489509329; Fitness: 0.06744158969774137
# Cluster: 92; Energy: -167.2829315916; Fitness: 0.049787068367863944
# Cluster: 93; Energy: -172.8777291602; Fitness: 1.0
# Cluster: 94; Energy: -168.6274619942; Fitness: 0.10238182365300284
# Cluster: 95; Energy: -168.4430935168; Fitness: 0.0927445114658731
# Cluster: 96; Energy: -167.3886323482; Fitness: 0.05269040330753229
# Cluster: 97; Energy: -168.7408253203; Fitness: 0.10879833358931776
# Cluster: 98; Energy: -167.8471700132; Fitness: 0.06737721700661196
# Cluster: 99; Energy: -169.4291540967; Fitness: 0.1573679138064139
# Cluster: 100; Energy: -169.2961869533; Fitness: 0.14653844669826988
# --------------------------------------------------------------------------
#
# Offspring that replace clusters in population due to fitness.
# Replacing Cluster 59(fitness = 0.092) with Offspring 93(fitness = 1.0)
# Replacing Cluster 76(fitness = 0.097) with Offspring 99(fitness = 0.157)
# Replacing Cluster 78(fitness = 0.1) with Offspring 100(fitness = 0.146)
# Replacing Cluster 23(fitness = 0.103) with Offspring 97(fitness = 0.108)
# ****---------------------****
# <Collection: Population> current size: 20; Clusters: [Cluster_72, Cluster_46, Cluster_35, Cluster_93, Cluster_60, Cluster_99, Cluster_79, Cluster_100, Cluster_87, Cluster_39, Cluster_97, Cluster_83, Cluster_52, Cluster_48, Cluster_41, Cluster_47, Cluster_84, Cluster_69, Cluster_74, Cluster_62]
# Time Information
# fitness_timer_1   = 0.00021719932556152344 seconds
# memory_operator_timer_1   = 2.2172927856445312e-05 seconds
# predation_timer_1 = 9.115514278411865 seconds
# fitness_timer_2   = 0.00012302398681640625 seconds
# ending_timer      = 0.0303494930267334 seconds
# The amount of time required for generation 5 is 12.777770757675171 seconds
# ----------------------------------------------------------
# Time elapsed: 00:01:12
# Date and Time: 2021-03-23 02:57:24.766005
#
#
# ----------------------------------------------------------
# ####################
# RUNNING GENERATION 6
# ####################
# -----------------------
# Making Offspring
# -----------------------
# Time taken to make offspring: 1.5732922554016113 s.
# Details of created offsprings
# Time taken to add offspring to Offspring_Pool: 8.654594421386719e-05 s.
# -----------------------
# Processing CNA Profiles took 2.184659004211426 seconds.
# Processing CNA similarities took 1.04966402053833 seconds.
# Removing offspring that violate the SCM Predation Operator
# [(115, 14), (110, 9), (107, 6), (105, 4), (104, 3)]
# -----------------------------
# ****---------------------****
# Natural Selection for Generation 6
# --------------------------------------------------------------------------
# <Collection: Population> current size: 20
# Cluster: 72; Energy: -168.9285909321; Fitness: 0.15586911082807056
# Cluster: 46; Energy: -168.8633106234; Fitness: 0.15115278945325775
# Cluster: 35; Energy: -169.7130170503; Fitness: 0.22547787063439387
# Cluster: 93; Energy: -172.8777291602; Fitness: 1.0
# Cluster: 60; Energy: -169.5207964399; Fitness: 0.20597393948823398
# Cluster: 99; Energy: -169.4291540967; Fitness: 0.19727849360932495
# Cluster: 79; Energy: -169.9011940825; Fitness: 0.246359338771666
# Cluster: 100; Energy: -169.2961869533; Fitness: 0.18531050682411485
# Cluster: 87; Energy: -170.3617008273; Fitness: 0.30598547883490357
# Cluster: 39; Energy: -169.5585285556; Fitness: 0.20966457818310877
# Cluster: 97; Energy: -168.7408253203; Fitness: 0.14268524031492116
# Cluster: 83; Energy: -171.0213352559; Fitness: 0.41738431230035355
# Cluster: 52; Energy: -169.2876716078; Fitness: 0.18456928483096907
# Cluster: 48; Energy: -168.9939529336; Fitness: 0.1607387728219957
# Cluster: 41; Energy: -170.7112773316; Fitness: 0.3607093905015009
# Cluster: 47; Energy: -169.2781715876; Fitness: 0.18374584974028582
# Cluster: 84; Energy: -169.2600408647; Fitness: 0.18218451173939512
# Cluster: 69; Energy: -169.7870474054; Fitness: 0.233472861344319
# Cluster: 74; Energy: -169.6005614854; Fitness: 0.21385380392139142
# Cluster: 62; Energy: -169.4584627243; Fitness: 0.20001874332236289
# --------------------------------------------------------------------------
#
# --------------------------------------------------------------------------
# <Collection: Offspring> current size: 11
# Cluster: 101; Energy: -169.6479092661; Fitness: 0.21867306827365424
# Cluster: 102; Energy: -172.1249758376; Fitness: 0.7016658532771659
# Cluster: 103; Energy: -168.1299303294; Fitness: 0.10703024815847896
# Cluster: 106; Energy: -167.1182878279; Fitness: 0.06648406423356769
# Cluster: 108; Energy: -169.1769132402; Fitness: 0.1751940719921726
# Cluster: 109; Energy: -169.3041375244; Fitness: 0.18600525466171258
# Cluster: 111; Energy: -170.869853839; Fitness: 0.38866186997258095
# Cluster: 112; Energy: -170.5130228831; Fitness: 0.3285734195974478
# Cluster: 113; Energy: -166.5038289676; Fitness: 0.049787068367863944
# Cluster: 114; Energy: -168.9687447135; Fitness: 0.15884291843182488
# Cluster: 116; Energy: -169.5080683849; Fitness: 0.20474369876507734
# --------------------------------------------------------------------------
#
# Offspring that replace clusters in population due to fitness.
# Replacing Cluster 97(fitness = 0.142) with Offspring 102(fitness = 0.701)
# Replacing Cluster 46(fitness = 0.151) with Offspring 111(fitness = 0.388)
# Replacing Cluster 72(fitness = 0.155) with Offspring 112(fitness = 0.328)
# Replacing Cluster 48(fitness = 0.16) with Offspring 101(fitness = 0.218)
# Replacing Cluster 84(fitness = 0.182) with Offspring 116(fitness = 0.204)
# Replacing Cluster 47(fitness = 0.183) with Offspring 109(fitness = 0.186)
# ****---------------------****
# <Collection: Population> current size: 20; Clusters: [Cluster_112, Cluster_111, Cluster_35, Cluster_93, Cluster_60, Cluster_99, Cluster_79, Cluster_100, Cluster_87, Cluster_39, Cluster_102, Cluster_83, Cluster_52, Cluster_101, Cluster_41, Cluster_109, Cluster_116, Cluster_69, Cluster_74, Cluster_62]
# Time Information
# fitness_timer_1   = 0.00022268295288085938 seconds
# memory_operator_timer_1   = 1.239776611328125e-05 seconds
# predation_timer_1 = 5.903093576431274 seconds
# fitness_timer_2   = 9.942054748535156e-05 seconds
# ending_timer      = 0.03501605987548828 seconds
# The amount of time required for generation 6 is 8.87009572982788 seconds
# ----------------------------------------------------------
# Time elapsed: 00:01:21
# Date and Time: 2021-03-23 02:57:33.665552
#
#
# ----------------------------------------------------------
# ####################
# RUNNING GENERATION 7
# ####################
# -----------------------
# Making Offspring
# -----------------------
# Time taken to make offspring: 1.7726163864135742 s.
# Details of created offsprings
# Time taken to add offspring to Offspring_Pool: 8.368492126464844e-05 s.
# -----------------------
# Processing CNA Profiles took 2.1983020305633545 seconds.
# Processing CNA similarities took 1.183690071105957 seconds.
# Removing offspring that violate the SCM Predation Operator
# [(130, 13), (128, 11), (118, 1)]
# -----------------------------
# ****---------------------****
# Natural Selection for Generation 7
# --------------------------------------------------------------------------
# <Collection: Population> current size: 20
# Cluster:
s.
# Details of created offsprings
# Time taken to add offspring to Offspring_Pool: 0.0006585121154785156 s.
# -----------------------
# Processing CNA Profiles took 1.9500243663787842 seconds.
# Processing CNA similarities took 1.281477451324463 seconds.
# Removing offspring that violate the SCM Predation Operator
# [(148, 15), (147, 14), (145, 12), (140, 7)]
# -----------------------------
# ****---------------------****
# Natural Selection for Generation 8
# --------------------------------------------------------------------------
# <Collection: Population> current size: 20
# Cluster: 112; Energy: -170.5130228831; Fitness: 0.36102124773666344
# Cluster: 111; Energy: -170.869853839; Fitness: 0.4210176737758901
# Cluster: 35; Energy: -169.7130170503; Fitness: 0.2557652860504229
# Cluster: 127; Energy: -172.877734078; Fitness: 1.0
# Cluster: 60; Energy: -169.5207964399; Fitness: 0.2354369932819734
# Cluster: 126; Energy: -170.4386938416; Fitness: 0.3496430204949964
# Cluster: 125; Energy: -169.9012410836; Fitness: 0.2773707658255693
# Cluster: 117; Energy: -170.9924590614; Fitness: 0.4438551957645455
# Cluster: 87; Energy: -170.3617008273; Fitness: 0.3382349652278525
# Cluster: 39; Energy: -169.5585285556; Fitness: 0.23929567910412577
# Cluster: 102; Energy: -172.1249758376; Fitness: 0.7230185764395877
# Cluster: 83; Energy: -171.0213352559; Fitness: 0.44941173412558766
# Cluster: 119; Energy: -171.2997504685; Fitness: 0.5066865770444969
# Cluster: 101; Energy: -169.6479092661; Fitness: 0.24869045277035462
# Cluster: 41; Energy: -170.7112773316; Fitness: 0.3932137231269843
# Cluster: 132; Energy: -170.8259948122; Fitness: 0.413136676247728
# Cluster: 116; Energy: -169.5080683849; Fitness: 0.23414944002886065
# Cluster: 69; Energy: -169.7870474054; Fitness: 0.26405452284637226
# Cluster: 74; Energy: -169.6005614854; Fitness: 0.24366870046555844
# Cluster: 62; Energy: -169.4584627243; Fitness: 0.2291982407712134
# --------------------------------------------------------------------------
#
# --------------------------------------------------------------------------
# <Collection: Offspring> current size: 12
# Cluster: 133; Energy: -168.0635872657; Fitness: 0.1256644745270865
# Cluster: 134; Energy: -167.4173859823; Fitness: 0.09512619455847211
# Cluster: 135; Energy: -165.9146353193; Fitness: 0.049787068367863944
# Cluster: 136; Energy: -169.3834793017; Fitness: 0.2219120765723971
# Cluster: 137; Energy: -171.6634767138; Fitness: 0.5926484586247289
# Cluster: 138; Energy: -169.1388764422; Fitness: 0.19971590965042
# Cluster: 139; Energy: -169.0789965901; Fitness: 0.19462937522147616
# Cluster: 141; Energy: -167.6185115429; Fitness: 0.1037368958072163
# Cluster: 142; Energy: -167.8219414394; Fitness: 0.11323939568623076
# Cluster: 143; Energy: -169.8670585096; Fitness: 0.27331577311413385
# Cluster: 144; Energy: -167.6287971889; Fitness: 0.10419762545883453
# Cluster: 146; Energy: -168.1552223215; Fitness: 0.1307249824540966
# --------------------------------------------------------------------------
#
# Offspring that replace clusters in population due to fitness.
# Replacing Cluster 62(fitness = 0.229) with Offspring 137(fitness = 0.592)
# Replacing Cluster 116(fitness = 0.234) with Offspring 143(fitness = 0.273)
# ****---------------------****
# <Collection: Population> current size: 20; Clusters: [Cluster_112, Cluster_111, Cluster_35, Cluster_127, Cluster_60, Cluster_126, Cluster_125, Cluster_117, Cluster_87, Cluster_39, Cluster_102, Cluster_83, Cluster_119, Cluster_101, Cluster_41, Cluster_132, Cluster_143, Cluster_69, Cluster_74, Cluster_137]
# Time Information
# fitness_timer_1   = 0.00023317337036132812 seconds
# memory_operator_timer_1   = 2.2411346435546875e-05 seconds
# predation_timer_1 = 6.26504921913147 seconds
# fitness_timer_2   = 9.918212890625e-05 seconds
# ending_timer      = 0.025864362716674805 seconds
# The amount of time required for generation 8 is 8.277074337005615 seconds
# ----------------------------------------------------------
# Time elapsed: 00:01:38
# Date and Time: 2021-03-23 02:57:51.094240
#
#
# ----------------------------------------------------------
# ####################
# RUNNING GENERATION 9
# ####################
# -----------------------
# Making Offspring
# -----------------------
# Time taken to make offspring: 1.8016128540039062 s.
# Details of created offsprings
# Time taken to add offspring to Offspring_Pool: 2.5987625122070312e-05 s.
# -----------------------
# Processing CNA Profiles took 2.4472663402557373 seconds.
# Processing CNA similarities took 1.8273804187774658 seconds.
# Removing offspring that violate the SCM Predation Operator
# [(160, 11), (157, 8), (156, 7), (153, 4)]
# -----------------------------
# ****---------------------****
# Natural Selection for Generation 9
# --------------------------------------------------------------------------
# <Collection: Population> current size: 20
# Cluster: 112; Energy: -170.5130228831; Fitness: 0.4716004843796933
# Cluster: 111; Energy: -170.869853839; Fitness: 0.5282400704479963
# ...
# Cluster: 252; Energy: -173.1343129701; Fitness: 0.9640730284738578
# Cluster: 432; Energy: -171.37208186; Fitness: 0.5583743950218644
# Cluster: 293; Energy: -171.7823016273; Fitness: 0.6340716160328533
# Cluster: 720; Energy: -173.252372868; Fitness: 1.0
# Cluster: 677; Energy: -172.1249792821; Fitness: 0.705115752159436
# Cluster: 724; Energy: -171.4736741572; Fitness: 0.5762343372033535
# Cluster: 670; Energy: -171.4034469845; Fitness: 0.5638285064132921
# Cluster: 510; Energy: -171.8906304994; Fitness: 0.6557203305556291
# Cluster: 358; Energy: -171.3595644267; Fitness: 0.5562124846365388
# Cluster: 363; Energy: -171.1590432263; Fitness: 0.5226993135569218
# Cluster: 639; Energy: -171.1780326196; Fitness: 0.5257844941009003
# Cluster: 321; Energy: -172.2266740758; Fitness: 0.727692419993666
# Cluster: 580; Energy: -171.1732095628; Fitness: 0.5249991777653734
# Cluster: 192; Energy: -171.7734072269; Fitness: 0.6323262135924903
# --------------------------------------------------------------------------
#
# --------------------------------------------------------------------------
# <Collection: Offspring> current size: 15
# Cluster: 757; Energy: -166.9128275648; Fitness: 0.14019738137884832
# Cluster: 758; Energy: -171.1211847983; Fitness: 0.516602424834981
# Cluster: 759; Energy: -165.7311736187; Fitness: 0.09720693275983248
# Cluster: 760; Energy: -170.9896837196; Fitness: 0.4959721389736957
# Cluster: 762; Energy: -164.0952200927; Fitness: 0.0585475753272789
# Cluster: 763; Energy: -168.9254621027; Fitness: 0.2615935036983239
# Cluster: 764; Energy: -168.5135408145; Fitness: 0.23024230466466458
# Cluster: 765; Energy: -169.9936290097; Fitness: 0.3642461967354712
# Cluster: 766; Energy: -167.8614975034; Fitness: 0.18811545871508684
# Cluster: 767; Energy: -168.7070991562; Fitness: 0.24447630490538327
# Cluster: 768; Energy: -166.9529244927; Fitness: 0.14195041885214163
# Cluster: 769; Energy: -167.5758670371; Fitness: 0.172179145841569
# Cluster: 770; Energy: -169.0105404752; Fitness: 0.26858263520300435
# Cluster: 771; Energy: -170.0943824576; Fitness: 0.37579912213984173
# Cluster: 772; Energy: -163.5722194806; Fitness: 0.049787068367863944
# --------------------------------------------------------------------------
#
# Offspring that replace clusters in population due to fitness.
# ****---------------------****
# <Collection: Population> current size: 20; Clusters: [Cluster_722, Cluster_375, Cluster_224, Cluster_127, Cluster_266, Cluster_654, Cluster_252, Cluster_432, Cluster_293, Cluster_720, Cluster_677, Cluster_724, Cluster_670, Cluster_510, Cluster_358, Cluster_363, Cluster_639, Cluster_321, Cluster_580, Cluster_192]
# Time Information
# fitness_timer_1   = 0.00015115737915039062 seconds
# memory_operator_timer_1   = 1.7642974853515625e-05 seconds
# predation_timer_1 = 6.828105449676514 seconds
# fitness_timer_2   = 0.0003151893615722656 seconds
# ending_timer      = 0.033921241760253906 seconds
# The amount of time required for generation 47 is 9.257985830307007 seconds
# ----------------------------------------------------------
# Time elapsed: 00:08:34
# Date and Time: 2021-03-23 03:04:47.090121
#
#
# ----------------------------------------------------------
# #####################
# RUNNING GENERATION 48
# #####################
# -----------------------
# Making Offspring
# -----------------------
# Time taken to make offspring: 2
# --------------------------------------------------------------------------
#
# Offspring that replace clusters in population due to fitness.
# ****---------------------****
# <Collection: Population> current size: 20; Clusters: [Cluster_722, Cluster_375, Cluster_224, Cluster_127, Cluster_266, Cluster_654, Cluster_780, Cluster_432, Cluster_293, Cluster_775, Cluster_677, Cluster_724, Cluster_670, Cluster_510, Cluster_358, Cluster_363, Cluster_639, Cluster_321, Cluster_580, Cluster_192]
# Time Information
# fitness_timer_1   = 0.00019097328186035156 seconds
# memory_operator_timer_1   = 1.3828277587890625e-05 seconds
# predation_timer_1 = 8.565704107284546 seconds
# fitness_timer_2   = 0.00019073486328125 seconds
# ending_timer      = 0.024889469146728516 seconds
# The amount of time required for generation 48 is 10.805427551269531 seconds
# ----------------------------------------------------------
# Time elapsed: 00:08:45
# Date and Time: 2021-03-23 03:04:57.929606
#
#
# ----------------------------------------------------------
# #####################
# RUNNING GENERATION 49
# #####################
# -----------------------
# Making Offspring
# -----------------------
# Time taken to make offspring: 1.5263733863830566 s.
# Details of created offsprings
# Time taken to add offspring to Offspring_Pool: 2.8848648071289062e-05 s.
# -----------------------
# Processing CNA Profiles took 2.8719794750213623 seconds.
# Processing CNA similarities took 1.3339238166809082 seconds.
# Removing offspring that violate the SCM Predation Operator
# [(804, 15), (798, 9)]
# -----------------------------
# ****---------------------****
# Natural Selection for Generation 49
# --------------------------------------------------------------------------
# <Collection: Population> current size: 20
# Cluster: 722; Energy: -171.3870086779; Fitness: 0.5405540939978014
# Cluster: 375; Energy: -171.1567075907; Fitness: 0.5010199725337102
# Cluster: 224; Energy: -171.9690108387; Fitness: 0.6549294538815587
# Cluster: 127; Energy: -172.877734078; Fitness: 0.8837785250150507
# Cluster: 266; Energy: -172.2349094274; Fitness: 0.7149521563629518
# Cluster: 654; Energy: -171.4205281521; Fitness: 0.5465625593087876
# Cluster: 780; Energy: -173.1343147541; Fitness: 0.9618146214681769
# Cluster: 432; Energy: -171.37208186; Fitness: 0.5378997173886895
# Cluster: 293; Energy: -171.7823016273; Fitness: 0.6158198794352778
# Cluster: 775; Energy: -173.2523738229; Fitness: 1.0
# Cluster: 677; Energy: -172.1249792821; Fitness: 0.6894973380704107
# Cluster: 724; Energy: -171.4736741572; Fitness: 0.5562263279334898
# Cluster: 670; Energy: -171.4034469845; Fitness: 0.5434924104073704
# Cluster: 510; Energy: -171.8906304994; Fitness: 0.6382175666167498
# Cluster: 358; Energy: -171.3595644267; Fitness: 0.5356838429074384
# Cluster: 363; Energy: -171.1590432263; Fitness: 0.5014060300591422
# Cluster: 639; Energy: -171.1780326196; Fitness: 0.5045558507294178
# Cluster: 321; Energy: -172.2266740758; Fitness: 0.7130130834095761
# Cluster: 580; Energy: -171.1732095628; Fitness: 0.5037539678974131
# Cluster: 192; Energy: -171.7734072269; Fitness: 0.6140162046648038
# --------------------------------------------------------------------------
#
# --------------------------------------------------------------------------
# <Collection: Offspring> current size: 14
# Cluster: 789; Energy: -170.0853465889; Fitness: 0.35189480346957497
# Cluster: 790; Energy: -166.6584274796; Fitness: 0.1136589241451989
# Cluster: 791; Energy: -170.10943506; Fitness: 0.35470135394842817
# Cluster: 792; Energy: -168.7241464202; Fitness: 0.2246256769098269
# Cluster: 793; Energy: -168.1311724911; Fitness: 0.18472796323193877
# Cluster: 794; Energy: -164.1554067077; Fitness: 0.049787068367863944
# Cluster: 795; Energy: -164.67952216; Fitness: 0.05918086117838038
# Cluster: 796; Energy: -169.3991365334; Fitness: 0.2806290695835612
# Cluster: 797; Energy: -167.3780304704; Fitness: 0.14410078021612707
# Cluster: 799; Energy: -168.9767319711; Fitness: 0.24413786402983254
# Cluster: 800; Energy: -168.4460675299; Fitness: 0.20494270153914637
# Cluster: 801; Energy: -169.1564640193; Fitness: 0.25904587259095324
# Cluster: 802; Energy: -170.0226239124; Fitness: 0.3446907291803913
# Cluster: 803; Energy: -170.1265979868; Fitness: 0.35671465378469874
# --------------------------------------------------------------------------
#
# Offspring that replace clusters in population due to fitness.
# ****---------------------****
# <Collection: Population> current size: 20; Clusters: [Cluster_722, Cluster_375, Cluster_224, Cluster_127, Cluster_266, Cluster_654, Cluster_780, Cluster_432, Cluster_293, Cluster_775, Cluster_677, Cluster_724, Cluster_670, Cluster_510, Cluster_358, Cluster_363, Cluster_639, Cluster_321, Cluster_580, Cluster_192]
# Time Information
# fitness_timer_1   = 0.00016236305236816406 seconds
# memory_operator_timer_1   = 2.5510787963867188e-05 seconds
# predation_timer_1 = 8.247743368148804 seconds
# fitness_timer_2   = 0.00011539459228515625 seconds
# ending_timer      = 0.03538322448730469 seconds
# The amount of time required for generation 49 is 9.830405235290527 seconds
# ----------------------------------------------------------
# Time elapsed: 00:08:55
# Date and Time: 2021-03-23 03:05:07.793979
#
#
# ----------------------------------------------------------
# #####################
# RUNNING GENERATION 50
# #####################
# -----------------------
# Making Offspring
# -----------------------
# Time taken to make offspring: 2.093541383743286 s.
# Details of created offsprings
# Time taken to add offspring to Offspring_Pool: 0.00027751922607421875 s.
# -----------------------
# Processing CNA Profiles took 1.3950111865997314 seconds.
# Processing CNA similarities took 0.9692542552947998 seconds.
# Removing offspring that violate the SCM Predation Operator
# [(816, 11), (811, 6)]
# -----------------------------
# ****---------------------****
# Natural Selection for Generation 50
# --------------------------------------------------------------------------
# <Collection: Population> current size: 20
# Cluster: 722; Energy: -171.3870086779; Fitness: 0.4193076907750772
# Cluster: 375; Energy: -171.1567075907; Fitness: 0.3766431752895755
# Cluster: 224; Energy: -171.9690108387; Fitness: 0.5499259988013486
# Cluster: 127; Energy: -172.877734078; Fitness: 0.8398264178354004
# Cluster: 266; Energy: -172.2349094274; Fitness: 0.6224584018707946
# Cluster: 654; Energy: -171.4205281521; Fitness: 0.4259078875780253
# Cluster: 780; Energy: -173.1343147541; Fitness: 0.9464770346276047
# Cluster: 432; Energy: -171.37208186; Fitness: 0.41640151623642907
# Cluster: 293; Energy: -171.7823016273; Fitness: 0.5041068384477461
# Cluster: 775; Energy: -173.2523738229; Fitness: 1.0
# Cluster: 677; Energy: -172.1249792821; Fitness: 0.5913782497880641
# Cluster: 724; Energy: -171.4736741572; Fitness: 0.43658627367701436
# Cluster: 670; Energy: -171.4034469845; Fitness: 0.42253161760574015
# Cluster: 510; Energy: -171.8906304994; Fitness: 0.5302046691546465
# Cluster: 358; Energy: -171.3595644267; Fitness: 0.4139799701693478
# Cluster: 815; Energy: -171.2460148938; Fitness: 0.39264668903693595
# Cluster: 639; Energy: -171.1780326196; Fitness: 0.38040423437227455
# Cluster: 809; Energy: -172.2307084364; Fitness: 0.6212411845460456
# Cluster: 580; Energy: -171.1732095628; Fitness: 0.37955032684399065
# Cluster: 192; Energy: -171.7734072269; Fitness: 0.5020220083016355
# --------------------------------------------------------------------------
#
# --------------------------------------------------------------------------
# <Collection: Offspring> current size: 12
# Cluster: 805; Energy: -170.2082967786; Fitness: 0.24211060806715953
# Cluster: 806; Energy: -168.388134376; Fitness: 0.10367968684901674
# Cluster: 807; Energy: -170.3619437094; Fitness: 0.26007891376413766
# Cluster: 808; Energy: -170.8265047765; Fitness: 0.3229324579801102
# Cluster: 810; Energy: -167.5184125661; Fitness: 0.06913541223324313
# Cluster: 812; Energy: -166.8137917454; Fitness: 0.049787068367863944
# Cluster: 813; Energy: -168.2264736928; Fitness: 0.09615695997729447
# Cluster: 814; Energy: -169.393435958; Fitness: 0.1656235653635639
# Cluster: 817; Energy: -167.2417251298; Fitness: 0.06077308620077705
# Cluster: 818; Energy: -166.837378321; Fitness: 0.050337243668390284
# Cluster: 819; Energy: -167.7619601191; Fitness: 0.07744328730011661
# Cluster: 820; Energy: -169.8776169102; Fitness: 0.2075385984584084
# --------------------------------------------------------------------------
#
# Offspring that replace clusters in population due to fitness.
# ****---------------------****
# <Collection: Population> current size: 20; Clusters: [Cluster_722, Cluster_375, Cluster_224, Cluster_127, Cluster_266, Cluster_654, Cluster_780, Cluster_432, Cluster_293, Cluster_775, Cluster_677, Cluster_724, Cluster_670, Cluster_510, Cluster_358, Cluster_815, Cluster_639, Cluster_809, Cluster_580, Cluster_192]
# Time Information
# fitness_timer_1   = 0.0001494884490966797 seconds
# memory_operator_timer_1   = 1.9073486328125e-05 seconds
# predation_timer_1 = 6.461088180541992 seconds
# fitness_timer_2   = 0.00012803077697753906 seconds
# ending_timer      = 0.028741121292114258 seconds
# The amount of time required for generation 50 is 8.59757661819458 seconds
# ----------------------------------------------------------
# Time elapsed: 00:09:03
# Date and Time: 2021-03-23 03:05:16.427397
# ----------------------------------------------------------
# ----------------------------------------------------------
# The maximum generation set by the user has been reached! The genetic algorithm process has completed!
# The Algorithm will finish now.
# ----------------------------------------------------------
# Time elapsed: 00:09:03
# Date and Time: 2021-03-23 03:05:16.429577
# ----------------------------------------------------------
# Finishing the Garden Group Genetic Algorithm Successfully.
# ----------------------------------------------------------
# ----------------------------------------------------------
# ' ---------------- '

# %% [markdown]
# [Back To Table of Contents](../Organisms_Jupyter_Example.ipynb)

# %% [markdown]
# ## Post-processing data from your global optimisation
#
# Once the genetic algorithm is finished, we generally would like to get data from it, such as the global minimum. We can get this from the Database that is recorded based on our settings for the ``ga_recording_information`` variable. The following code is a simple way of extracting the lowest energy cluster that was obtained during the genetic algorithm. This is not to be included in the *Run.py* file, this is just so you can see the fruits of your global optimisation work!

# %%
from ase.io import read
database_path = 'Recorded_Data/GA_Recording_Database.db'
lowest_energy_cluster_found = read(database_path)
if isinstance(lowest_energy_cluster_found, list):
    lowest_energy_cluster_found = lowest_energy_cluster_found[0]
lowest_energy_cluster_found.center(about=0.,vacuum=0.0)
from ase.visualize import view
view(lowest_energy_cluster_found,viewer='x3d')
# Out:
# <html>
#
#  <head>
#
#   <title>ASE atomic visualization</title>
#
#   <link rel="stylesheet" type="text/css"
#
#    href="https://www.x3dom.org/x3dom/release/x3dom.css">
#
#   </link>
#
#   <script type="text/javascript"
#
#    src="https://www.x3dom.org/x3dom/release/x3dom.js">
#
#   </script>
#
#  </head>
#
#  <body>
#
#   <X3D>
#
#    <Scene>
#
#     <Transform translation="-0.14 -0.80 1.37">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.702 0.890 0.961" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.58">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="0.32 0.21 1.34">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.702 0.890 0.961" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.58">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="0.77 1.22 1.32">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.702 0.890 0.961" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.58">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.78 0.09 1.18">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.702 0.890 0.961" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.58">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.33 1.11 1.15">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.702 0.890 0.961" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.58">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-1.43 0.97 0.99">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.702 0.890 0.961" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.58">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="0.84 -0.65 0.87">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.702 0.890 0.961" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.58">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="1.30 0.36 0.84">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.702 0.890 0.961" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.58">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.94 -0.86 0.60">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.702 0.890 0.961" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.58">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="0.26 1.83 0.53">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.702 0.890 0.961" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.58">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.07 -0.23 0.42">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.702 0.890 0.961" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.58">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="0.06 -1.32 0.41">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.702 0.890 0.961" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.58">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="1.81 -0.51 0.36">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.702 0.890 0.961" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.58">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="0.38 0.76 0.39">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.702 0.890 0.961" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.58">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-1.59 0.03 0.41">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.702 0.890 0.961" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.58">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.86 1.71 0.37">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.702 0.890 0.961" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.58">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="1.29 1.36 0.34">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.702 0.890 0.961" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.58">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.69 0.64 0.23">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.702 0.890 0.961" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.58">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="0.89 -0.09 -0.08">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.702 0.890 0.961" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.58">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="1.04 -1.17 -0.10">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.702 0.890 0.961" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.58">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="1.82 0.48 -0.15">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.702 0.890 0.961" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.58">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-1.66 1.03 -0.10">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.702 0.890 0.961" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.58">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-1.74 -0.92 -0.16">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.702 0.890 0.961" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.58">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.85 -0.28 -0.34">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.702 0.890 0.961" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.58">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.74 -1.38 -0.36">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.702 0.890 0.961" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.58">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.13 1.39 -0.40">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.702 0.890 0.961" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.58">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="0.13 -0.73 -0.53">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.702 0.890 0.961" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.58">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="0.01 0.33 -0.52">
#
#      <Shape>

# %% [markdown]
# [Back To Table of Contents](../Organisms_Jupyter_Example.ipynb)
